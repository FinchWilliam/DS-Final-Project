# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
def remove_plural_s(ingredients, letters_to_replace, replace_with):
    """
    Removes the trailing 's' from a word, handling exceptions.

    Args:
        ingredient: The ingredient string.

    Returns:
        The modified ingredient string.
    """
    list_ingredients = []
    for ingredient in ingredients:
        ingredient = ingredient.lower()
        if letters_to_replace.lower() == "s":
            if ingredient.lower().endswith(letters_to_replace):
                if len(ingredient) > 1 and ingredient[-2] not in ["a", "e", "i", "o", "u", "s"]:
                    list_ingredients.append(ingredient[:-1])
                else:
                    list_ingredients.append(ingredient)
            else:
                list_ingredients.append(ingredient)
        else:
            if len(ingredient) > len(letters_to_replace) and ingredient.endswith(letters_to_replace):
                list_ingredients.append(ingredient[:-len(letters_to_replace)] + replace_with)
            else:
                list_ingredients.append(ingredient)
    return list_ingredients

def counting(data_list, to_count):
    counts = Counter()
    for small_list in data_list:
        for item in small_list:
            if item.endswith(to_count):
                counts[item] += 1

    return counts

def remove_words(ingredient_list, words_to_remove):
    """
    Removes specified words from ingredient strings within a list.

    Args:
        ingredient_list: A list of ingredient strings.
        words_to_remove: A set of words to remove (case-insensitive).

    Returns:
        A new list with modified ingredient strings.
    """
    modified_list = []
    for ingredient in ingredient_list:
        words = ingredient.split()  # Split into words
        filtered_words = [word for word in words if word.lower() not in words_to_remove]
        modified_ingredient = " ".join(filtered_words)  # Reconstruct the string
        modified_list.append(modified_ingredient)
        modified_list = [item for item in modified_list if item !=""]
    return modified_list

# %%
df = pd.read_pickle('../Data/Raw Datasets/food.pkl')
df.head()
# Out:
#       id                                        ingredients
# 0  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213                [water, vegetable oil, wheat, salt]
# 4  13162  [black pepper, shallots, cornflour, cayenne pe...

# %%
counting(data_list = df['ingredients'], to_count="")
# Out:
# Counter({'salt': 364164,
#          'eggs': 333939,
#          'tsp salt': 260887,
#          'c sugar': 245022,
#          'teaspoon salt': 240383,
#          'butter': 206049,
#          'sugar': 176361,
#          'water': 143028,
#          'onion': 138127,
#          'egg': 135707,
#          'olive oil': 132838,
#          'tsp vanilla': 127328,
#          'c flour': 126317,
#          'c milk': 111533,
#          'garlic cloves': 109932,
#          'pepper': 103049,
#          'cup sugar': 98631,
#          'milk': 96124,
#          'flour': 95412,
#          'c water': 82444,
#          'all-purpose flour': 70577,
#          'garlic': 70182,
#          'tsp baking powder': 68563,
#          'brown sugar': 65348,
#          'cup water': 62011,
#          'baking powder': 61120,
#          'tsp pepper': 56204,
#          'lemon juice': 56197,
#          'tsp cinnamon': 54918,
#          'tablespoons olive oil': 54420,
#          'black pepper': 52711,
#          'onions': 52589,
#          'cup milk': 51397,
#          'teaspoon pepper': 51353,
#          'tomatoes': 50977,
#          'baking soda': 49669,
#          'parmesan cheese': 49659,
#          'tsp baking soda': 49251,
#          'vanilla': 48659,
#          'large eggs': 47794,
#          'teaspoon baking soda': 46681,
#          'cinnamon': 46448,
#          'teaspoon vanilla extract': 45861,
#          'sour cream': 45258,
#          'salt pepper': 45064,
#          'cups allpurpose flour': 43789,
#          'c brown sugar': 43781,
#          'tablespoons butter': 43575,
#          'cups water': 42898,
#          'lb ground beef': 41465,
#          'salt pepper taste': 41341,
#          'vanilla extract': 40933,
#          'garlic powder': 40575,
#          'unsalted butter': 39886,
#          'garlic cloves minced': 39219,
#          'tsp soda': 39092,
#          'garlic clove': 37380,
#          'soy sauce': 36220,
#          'honey': 35671,
#          'c butter': 35281,
#          'Tbsp butter': 35137,
#          'celery': 34930,
#          'cream cheese': 34906,
#          'eggs beaten': 34732,
#          'carrots': 34026,
#          'paprika': 33767,
#          'Tbsp sugar': 33560,
#          'margarine': 32997,
#          'teaspoon baking powder': 32709,
#          'Tbsp flour': 32564,
#          'cup butter': 32362,
#          'cup allpurpose flour': 32356,
#          'cups sugar': 32328,
#          'tablespoon olive oil': 32261,
#          'chicken broth': 32095,
#          'bay leaf': 31832,
#          'kosher salt': 31355,
#          'c mayonnaise': 30767,
#          'cups flour': 30644,
#          'teaspoon vanilla': 30556,
#          'mayonnaise': 30041,
#          'cheddar cheese': 29261,
#          'c sour cream': 29034,
#          'c oil': 28919,
#          'c chopped onion': 28729,
#          'chili powder': 28449,
#          'teaspoons baking powder': 28378,
#          'fresh ground black pepper': 28347,
#          'teaspoon ground cinnamon': 28014,
#          'bay leaves': 27853,
#          'cup olive oil': 27819,
#          'green onions': 27722,
#          'fresh parsley': 27667,
#          'c chopped nuts': 26904,
#          'teaspoon black pepper': 26806,
#          'extra virgin olive oil': 26794,
#          'parsley': 26747,
#          'potatoes': 26615,
#          'cloves garlic minced': 26317,
#          'ground cinnamon': 26023,
#          'cornstarch': 25997,
#          'tablespoons sugar': 25836,
#          'teaspoon cinnamon': 25789,
#          'pinch salt': 25698,
#          'cup sour cream': 25518,
#          'cup flour': 25456,
#          'teaspoons salt': 25456,
#          'c shortening': 25419,
#          'vegetable oil': 25396,
#          'granulated sugar': 25263,
#          'ground cumin': 24959,
#          'ground black pepper': 24772,
#          'bacon': 24554,
#          'cayenne pepper': 24142,
#          'carrot': 23988,
#          'powdered sugar': 23558,
#          'nutmeg': 23477,
#          'cream mushroom soup': 23026,
#          'teaspoon garlic powder': 23010,
#          'cup brown sugar': 22645,
#          'onion chopped': 22446,
#          'cups milk': 22434,
#          'medium onion chopped': 22387,
#          'egg yolks': 22181,
#          'egg whites': 22116,
#          'pecans': 22093,
#          'heavy cream': 21923,
#          'c chopped pecans': 21919,
#          'ground beef': 21539,
#          'tsp nutmeg': 21483,
#          'Tbsp lemon juice': 21467,
#          'teaspoon kosher salt': 21433,
#          'stick butter': 21176,
#          'c allpurpose flour': 21154,
#          'walnuts': 20932,
#          'red onion': 20735,
#          'fresh lemon juice': 20687,
#          'cup mayonnaise': 20593,
#          'c boiling water': 20482,
#          'cream chicken soup': 20241,
#          'cup granulated sugar': 20151,
#          'stick margarine': 20137,
#          'red bell pepper': 20063,
#          'green pepper': 19694,
#          'cup heavy cream': 19656,
#          'teaspoon sugar': 19431,
#          'c buttermilk': 19356,
#          'boneless skinless chicken breasts': 19327,
#          'egg beaten': 19276,
#          'c vinegar': 19264,
#          'dried oregano': 19169,
#          'tomato sauce': 19132,
#          'oz pkg cream cheese': 19061,
#          'green onion': 18967,
#          'salt taste': 18725,
#          'lemon': 18613,
#          'cup vegetable oil': 18609,
#          'Worcestershire sauce': 18475,
#          'canola oil': 18465,
#          'oz cream cheese': 18315,
#          'tomato paste': 18205,
#          'zucchini': 18134,
#          'tsp garlic powder': 18055,
#          'tsp sugar': 17984,
#          'teaspoon ground cumin': 17872,
#          'lime juice': 17504,
#          'chicken breasts': 17487,
#          'mozzarella cheese': 17322,
#          'cup butter softened': 17181,
#          'tablespoon butter': 16931,
#          'tablespoons vegetable oil': 16904,
#          'c margarine': 16844,
#          'garlic clove minced': 16813,
#          'raisins': 16804,
#          'c raisins': 16577,
#          'oil': 16378,
#          'cumin': 16285,
#          'sea salt': 16255,
#          'oregano': 16213,
#          'fresh ginger': 16205,
#          'teaspoons Salt': 16178,
#          'fresh cilantro': 16122,
#          'diced tomatoes': 16109,
#          'cilantro': 16087,
#          'ginger': 16065,
#          'cup chopped onion': 15654,
#          'tablespoons unsalted butter': 15471,
#          'bananas': 15459,
#          'salt and pepper': 15415,
#          'clove garlic minced': 15330,
#          'tsp vanilla extract': 15175,
#          'buttermilk': 14995,
#          'large egg': 14887,
#          'tablespoons lemon juice': 14878,
#          'c chopped celery': 14668,
#          'teaspoon cayenne pepper': 14533,
#          'cup white sugar': 14514,
#          'Tbsp cornstarch': 14454,
#          'c powdered sugar': 14416,
#          'teaspoon freshly ground black pepper': 14342,
#          'green bell pepper': 14308,
#          'fresh basil': 14301,
#          'large onion chopped': 14296,
#          'teaspoons vanilla extract': 14224,
#          'small onion chopped': 14149,
#          'tablespoon sugar': 14049,
#          'teaspoon paprika': 14005,
#          'ketchup': 13941,
#          'c peanut butter': 13721,
#          'dash salt': 13690,
#          'cup honey': 13600,
#          'tablespoons flour': 13515,
#          'dried thyme': 13388,
#          'ground ginger': 13366,
#          'white sugar': 13329,
#          'tsp Worcestershire sauce': 13260,
#          'Tbsp vinegar': 13183,
#          'onion powder': 13130,
#          'scallions': 13064,
#          'teaspoon ground black pepper': 12964,
#          'Salt': 12927,
#          'tablespoons allpurpose flour': 12858,
#          'mushrooms': 12828,
#          'vinegar': 12801,
#          'dry white wine': 12795,
#          'tsp black pepper': 12795,
#          'cup dry white wine': 12788,
#          'tsp dry mustard': 12784,
#          'tablespoon lemon juice': 12746,
#          'teaspoon dried oregano': 12733,
#          'fresh ground pepper': 12706,
#          'c white sugar': 12673,
#          'tablespoons water': 12581,
#          'red wine vinegar': 12553,
#          'cup butter melted': 12481,
#          'teaspoon ground nutmeg': 12313,
#          'Dijon mustard': 12284,
#          'Tbsp Worcestershire sauce': 12227,
#          'c coconut': 12180,
#          'salsa': 12157,
#          'c nuts': 12127,
#          'teaspoon ground ginger': 12039,
#          'Tbsp oil': 12033,
#          'cup packed brown sugar': 11906,
#          'tsp lemon juice': 11793,
#          'c vegetable oil': 11715,
#          'dried basil': 11645,
#          'cheese': 11639,
#          'c selfrising flour': 11594,
#          'chicken': 11590,
#          'tsp oregano': 11530,
#          'lb hamburger': 11521,
#          'Tbsp salt': 11495,
#          'light brown sugar': 11457,
#          'tablespoons honey': 11441,
#          'thyme': 11406,
#          "confectioners' sugar": 11284,
#          'white pepper': 11240,
#          'shallots': 11176,
#          'ground nutmeg': 11169,
#          'tsp paprika': 11166,
#          'cup buttermilk': 11133,
#          'Tbsp margarine': 11029,
#          'teaspoon nutmeg': 10978,
#          'curry powder': 10977,
#          'yellow onion': 10958,
#          'cloves garlic': 10938,
#          'c sifted flour': 10934,
#          'tablespoons extravirgin olive oil': 10908,
#          'dash pepper': 10865,
#          'basil': 10834,
#          'whole wheat flour': 10824,
#          'shortening': 10793,
#          'black beans': 10747,
#          'Tbsp cocoa': 10728,
#          'boiling water': 10663,
#          'cup raisins': 10651,
#          'cooking spray': 10638,
#          'c butter margarine': 10608,
#          'crushed red pepper flakes': 10529,
#          'Kosher salt': 10502,
#          'white wine': 10501,
#          'fresh lime juice': 10410,
#          'flour tortillas': 10403,
#          'avocado': 10400,
#          'tablespoons soy sauce': 10383,
#          'Tbsp milk': 10328,
#          'red pepper flakes': 10155,
#          'tablespoon vegetable oil': 10090,
#          'cup orange juice': 10089,
#          'Salt pepper': 10081,
#          'cucumber': 10055,
#          'cups chicken broth': 10047,
#          'evaporated milk': 10033,
#          'tablespoons cornstarch': 9950,
#          'oz tomato sauce': 9930,
#          'tablespoons fresh lemon juice': 9930,
#          'c chicken broth': 9918,
#          'apples': 9916,
#          'tsp garlic salt': 9883,
#          'oz Cool Whip': 9740,
#          'teaspoon dried thyme': 9735,
#          'tsp chili powder': 9622,
#          'c hot water': 9622,
#          'c granulated sugar': 9606,
#          'tsp ground cinnamon': 9594,
#          'tsp cloves': 9587,
#          'teaspoon chili powder': 9555,
#          'lime': 9548,
#          'dry mustard': 9544,
#          'c pecans': 9476,
#          'tablespoons brown sugar': 9472,
#          'oz sour cream': 9464,
#          'sweetened condensed milk': 9453,
#          'teaspoons baking soda': 9436,
#          'tablespoons extra virgin olive oil': 9424,
#          'c shredded Cheddar cheese': 9337,
#          'banana': 9332,
#          'cider vinegar': 9288,
#          'worcestershire sauce': 9286,
#          'Cooking spray': 9276,
#          'c cocoa': 9215,
#          'lemon zest': 9122,
#          'cup chicken broth': 9079,
#          'shrimp': 9073,
#          'cup soy sauce': 9051,
#          'cold water': 9005,
#          'Tbsp brown sugar': 8873,
#          'teaspoon ground cloves': 8871,
#          'Tbsp olive oil': 8864,
#          'eggs separated': 8846,
#          'Tbsp vanilla': 8805,
#          'Tbsp water': 8799,
#          'lean ground beef': 8777,
#          'c plain flour': 8769,
#          'teaspoons sugar': 8763,
#          'tablespoons butter melted': 8751,
#          'c warm water': 8698,
#          'tbsp olive oil': 8682,
#          'ground cloves': 8654,
#          'c cold water': 8652,
#          'peanut butter': 8630,
#          'beef broth': 8629,
#          'boneless skinless chicken breast halves': 8618,
#          'slices bacon': 8612,
#          'cup powdered sugar': 8593,
#          'tbsp butter': 8587,
#          'sesame seeds': 8583,
#          'c lemon juice': 8555,
#          'green chilies': 8550,
#          'celery ribs': 8548,
#          'fresh thyme': 8527,
#          'white vinegar': 8525,
#          'c melted butter': 8476,
#          'cup lemon juice': 8458,
#          'whole cloves': 8447,
#          'cup ketchup': 8431,
#          'medium onion': 8430,
#          'Tbsp butter margarine': 8429,
#          'cup extravirgin olive oil': 8422,
#          'oz pkg cream cheese softened': 8383,
#          'sharp cheddar cheese': 8377,
#          'monterey jack cheese': 8349,
#          'warm water': 8313,
#          'c catsup': 8306,
#          'feta cheese': 8293,
#          'cherry tomatoes': 8197,
#          'tsp Salt': 8152,
#          'bell pepper': 8145,
#          'black olives': 8133,
#          'pepper taste': 8133,
#          'c chopped walnuts': 8126,
#          'corn tortillas': 8092,
#          'chocolate chips': 8092,
#          'clove garlic': 8088,
#          'cup chopped pecans': 8082,
#          'half-and-half': 8062,
#          'teaspoons olive oil': 8049,
#          'Salt freshly ground black pepper': 7990,
#          'tablespoons milk': 7987,
#          'tsp ginger': 7975,
#          'eggs slightly beaten': 7900,
#          'lettuce': 7881,
#          'c grated cheese': 7845,
#          'teaspoon cumin': 7810,
#          'Freshly ground black pepper': 7786,
#          'teaspoon Salt': 7776,
#          'crushed pineapple': 7759,
#          'teaspoon Worcestershire sauce': 7759,
#          'c salad oil': 7755,
#          'chopped onion': 7754,
#          'shallot': 7733,
#          'ground coriander': 7705,
#          'tablespoon honey': 7689,
#          'coconut': 7652,
#          'teaspoons vanilla': 7646,
#          'Tbsp soy sauce': 7607,
#          'c Parmesan cheese': 7605,
#          'egg yolk': 7603,
#          'teaspoon almond extract': 7556,
#          'cup white wine': 7522,
#          'corn': 7517,
#          'c Crisco': 7478,
#          'green onions chopped': 7472,
#          'maple syrup': 7452,
#          'teaspoon lemon juice': 7450,
#          'rice vinegar': 7447,
#          'cabbage': 7432,
#          'coconut milk': 7429,
#          'cup canola oil': 7422,
#          'teaspoon onion powder': 7406,
#          'whole Eggs': 7386,
#          'cup oil': 7384,
#          'seasoning salt': 7361,
#          'stick oleo': 7344,
#          'cup shortening': 7335,
#          'c bread crumbs': 7272,
#          'cup extra virgin olive oil': 7257,
#          'c grated Parmesan cheese': 7240,
#          'cups Sugar': 7226,
#          'large egg yolks': 7183,
#          'c grated Cheddar cheese': 7182,
#          'cayenne': 7170,
#          'c chopped green pepper': 7160,
#          'cups heavy cream': 7156,
#          'fresh mushrooms': 7149,
#          'c orange juice': 7124,
#          'tsp cream tartar': 7114,
#          'cups chicken stock': 7098,
#          'lb lean ground beef': 7092,
#          'c chopped onions': 7075,
#          'skim milk': 7059,
#          'chives': 7042,
#          'plain yogurt': 6969,
#          'rice': 6967,
#          'teaspoon sea salt': 6967,
#          'cinnamon sticks': 6963,
#          'cup chopped walnuts': 6963,
#          'cup confectioners sugar': 6943,
#          'teaspoon oregano': 6925,
#          'hot water': 6913,
#          'green beans': 6909,
#          'swiss cheese': 6903,
#          'tablespoons oil': 6900,
#          'c evaporated milk': 6895,
#          'tablespoon baking powder': 6890,
#          'Kosher salt freshly ground black pepper': 6887,
#          'fish sauce': 6869,
#          'tablespoon cornstarch': 6868,
#          'tablespoon salt': 6867,
#          'cinnamon stick': 6842,
#          'cup whole milk': 6842,
#          'teaspoon dried basil': 6841,
#          'egg white': 6838,
#          'fresh rosemary': 6837,
#          'small onion': 6817,
#          'eggs well beaten': 6777,
#          'sesame oil': 6763,
#          'large onion': 6747,
#          'cream celery soup': 6734,
#          'dark brown sugar': 6733,
#          'c ketchup': 6722,
#          'mushroom': 6704,
#          'dijon mustard': 6687,
#          'flat leaf parsley': 6659,
#          'chicken stock': 6657,
#          'tablespoons canola oil': 6654,
#          'garlic cloves chopped': 6648,
#          'mushroom soup': 6639,
#          'c cooked rice': 6581,
#          'teaspoon dry mustard': 6553,
#          'sweet potatoes': 6551,
#          'cooked rice': 6550,
#          'tomato soup': 6538,
#          'teaspoon fresh ground black pepper': 6537,
#          'Tbsp vegetable oil': 6500,
#          'capers': 6482,
#          'cup whipping cream': 6462,
#          'tablespoon fresh lemon juice': 6451,
#          'tsp celery seed': 6437,
#          'ham': 6424,
#          'garlic cloves crushed': 6403,
#          'teaspoon olive oil': 6391,
#          'vegetable broth': 6386,
#          'ounces cream cheese softened': 6382,
#          'molasses': 6375,
#          'orange zest': 6342,
#          'tsp allspice': 6223,
#          'cornmeal': 6205,
#          'teaspoons ground cinnamon': 6199,
#          'lb butter': 6182,
#          'green pepper chopped': 6181,
#          'apple': 6165,
#          'teaspoon crushed red pepper flakes': 6092,
#          'orange juice': 6085,
#          'lemons': 6069,
#          'Salt pepper taste': 6065,
#          'coarse salt': 6050,
#          'cloves garlic crushed': 6047,
#          'tablespoon Worcestershire sauce': 6034,
#          'strawberries': 6016,
#          'plum tomatoes': 6015,
#          'c Bisquick': 5998,
#          'cup grated parmesan cheese': 5994,
#          'cup onion chopped': 5975,
#          'broccoli': 5932,
#          'tablespoon water': 5926,
#          'beaten eggs': 5921,
#          'cloves garlic chopped': 5917,
#          'teaspoon pure vanilla extract': 5917,
#          'cup boiling water': 5904,
#          'red wine': 5901,
#          'eggs lightly beaten': 5883,
#          'turmeric': 5869,
#          'tablespoon soy sauce': 5858,
#          'c graham cracker crumbs': 5856,
#          'teaspoon red pepper flakes': 5846,
#          'sticks margarine': 5837,
#          'allspice': 5827,
#          'active dry yeast': 5817,
#          'teaspoon garlic salt': 5815,
#          'white wine vinegar': 5814,
#          'ricotta cheese': 5811,
#          'teaspoon Dijon mustard': 5810,
#          'cocoa powder': 5798,
#          'kidney beans': 5787,
#          'teaspoons cinnamon': 5773,
#          'oz cream cheese softened': 5762,
#          'cherry pie filling': 5744,
#          'pt sour cream': 5728,
#          'ounce tomato sauce': 5728,
#          'orange': 5722,
#          'c miniature marshmallows': 5706,
#          'Tabasco sauce': 5674,
#          'cup whole wheat flour': 5668,
#          'sticks butter': 5651,
#          'spinach': 5639,
#          'barbecue sauce': 5637,
#          'cup shredded cheddar cheese': 5634,
#          'tablespoons red wine vinegar': 5632,
#          'teaspoon white pepper': 5625,
#          'pure vanilla extract': 5624,
#          'garlic salt': 5574,
#          'cup heavy whipping cream': 5565,
#          'cups whole milk': 5563,
#          'tablespoon Dijon mustard': 5559,
#          'tablespoons tomato paste': 5548,
#          'fresh dill': 5530,
#          'cup grated Parmesan cheese': 5516,
#          'Tbsp chili powder': 5512,
#          'c honey': 5511,
#          'extra-virgin olive oil': 5494,
#          'teaspoon minced garlic': 5481,
#          'Tbsp melted butter': 5471,
#          'Eagle Brand milk': 5465,
#          'cups confectioners sugar': 5465,
#          'scallion': 5457,
#          'Cool Whip': 5451,
#          'teaspoons kosher salt': 5447,
#          'cups powdered sugar': 5442,
#          'cup chopped celery': 5440,
#          '': 5431,
#          'clove': 5424,
#          'large egg whites': 5418,
#          'tablespoons balsamic vinegar': 5415,
#          'cloves': 5408,
#          'c packed brown sugar': 5408,
#          'pine nuts': 5399,
#          'Salt freshly ground pepper': 5372,
#          'c confectioners sugar': 5355,
#          'teaspoon ground allspice': 5348,
#          'c soy sauce': 5344,
#          'balsamic vinegar': 5328,
#          'beer': 5318,
#          'apple cider vinegar': 5314,
#          'mustard': 5312,
#          'onion diced': 5310,
#          'potato': 5303,
#          'Filling': 5284,
#          'Eggs': 5276,
#          'rosemary': 5274,
#          'teaspoons ground cumin': 5259,
#          'c oatmeal': 5239,
#          'tsp thyme': 5237,
#          'teaspoon Vanilla Extract': 5229,
#          'plain flour': 5218,
#          'c chocolate chips': 5218,
#          'sweet onion': 5180,
#          'teaspoon ground coriander': 5175,
#          'tsp almond extract': 5153,
#          'green peppers': 5143,
#          'rolled oats': 5135,
#          'cups Water': 5126,
#          'c cooking oil': 5112,
#          'tortilla chips': 5102,
#          'cup red wine vinegar': 5095,
#          'chickpeas': 5094,
#          'c olive oil': 5087,
#          'qt water': 5051,
#          'ice cubes': 5045,
#          'caster sugar': 5036,
#          'fresh chives': 5023,
#          'tsp ground cumin': 5015,
#          'ground pepper': 5014,
#          'crushed tomatoes': 5007,
#          'cups Allpurpose Flour': 5006,
#          'c butter melted': 4993,
#          'low sodium chicken broth': 4975,
#          'ounce package cream cheese softened': 4975,
#          'teaspoons lemon juice': 4961,
#          'c diced celery': 4950,
#          'tablespoons fresh lime juice': 4935,
#          'ounces cream cheese': 4933,
#          'blueberries': 4922,
#          'cups granulated sugar': 4901,
#          'tablespoon brown sugar': 4889,
#          'cup cold water': 4879,
#          'tsp basil': 4858,
#          'tablespoons Worcestershire sauce': 4856,
#          'cup Sugar': 4843,
#          'oz crushed pineapple': 4838,
#          'cup fresh lemon juice': 4837,
#          'red pepper': 4828,
#          'Pinch salt': 4824,
#          'tablespoons Dijon mustard': 4817,
#          'icing sugar': 4816,
#          'Tbsp baking powder': 4813,
#          'Tbsp shortening': 4808,
#          'tsp ground cloves': 4807,
#          'boneless chicken breasts': 4797,
#          'c onion chopped': 4797,
#          'teaspoon cream tartar': 4794,
#          'cup chicken stock': 4793,
#          'ground allspice': 4785,
#          'cups Flour': 4779,
#          'c molasses': 4769,
#          'dry sherry': 4751,
#          'cumin seed': 4746,
#          'cups white sugar': 4746,
#          'pasta': 4738,
#          'pork chops': 4737,
#          'salt  freshly ground black pepper': 4737,
#          'teaspoons Baking Powder': 4729,
#          'vanilla ice cream': 4719,
#          'gingerroot': 4718,
#          'Tbsp chopped onion': 4718,
#          'cloves Garlic Minced': 4717,
#          'dried parsley': 4716,
#          'Tbsp mayonnaise': 4699,
#          'teaspoon thyme': 4693,
#          'tsp ground ginger': 4683,
#          'basil leaves': 4680,
#          'Tablespoons Olive Oil': 4673,
#          'cup cornstarch': 4666,
#          'Salt taste': 4642,
#          'cup peanut butter': 4627,
#          'teaspoon turmeric': 4627,
#          'spaghetti': 4619,
#          'chicken bouillon cubes': 4609,
#          'whipping cream': 4606,
#          'black peppercorns': 4606,
#          'egg slightly beaten': 4597,
#          'cup chopped fresh cilantro': 4594,
#          'tablespoons lime juice': 4591,
#          'c lowfat milk': 4571,
#          'light corn syrup': 4563,
#          'tablespoons mayonnaise': 4548,
#          'c rice': 4547,
#          'cups boiling water': 4541,
#          'purple onion': 4536,
#          'stalks celery chopped': 4515,
#          'teaspoons cornstarch': 4514,
#          'cauliflower': 4513,
#          'box yellow cake mix': 4505,
#          'dried cranberries': 4503,
#          'tsp cayenne pepper': 4501,
#          'large eggs lightly beaten': 4494,
#          'garam masala': 4488,
#          'heavy whipping cream': 4486,
#          'c pecans chopped': 4483,
#          'leeks': 4470,
#          'cup finely chopped onion': 4464,
#          'onions chopped': 4452,
#          'cup semisweet chocolate chips': 4449,
#          'tsp mustard': 4447,
#          'tablespoon canola oil': 4442,
#          'tsp curry powder': 4439,
#          'teaspoons Baking Soda': 4438,
#          'grated parmesan cheese': 4416,
#          'c celery chopped': 4396,
#          'c oleo': 4375,
#          'medium onions chopped': 4358,
#          'ground turkey': 4357,
#          'bread flour': 4353,
#          'stick margarine melted': 4347,
#          'tablespoon unsalted butter': 4343,
#          'fresh spinach': 4338,
#          'pkg yeast': 4338,
#          'tablespoon vanilla extract': 4335,
#          'eggplant': 4332,
#          'clove garlic crushed': 4318,
#          'stewed tomatoes': 4309,
#          'cup chopped fresh parsley': 4305,
#          'tablespoon minced garlic': 4299,
#          'teaspoon salt taste': 4291,
#          'avocados': 4288,
#          'cup cider vinegar': 4288,
#          'chopped tomatoes': 4284,
#          'tsp vinegar': 4284,
#          'applesauce': 4282,
#          'pinch Salt': 4282,
#          'teaspoon curry powder': 4282,
#          'medium onion diced': 4279,
#          'vodka': 4269,
#          'cup dried cranberries': 4257,
#          'brandy': 4253,
#          'cup brown sugar packed': 4247,
#          'cans cream chicken soup': 4236,
#          'cup balsamic vinegar': 4234,
#          'cream of tartar': 4233,
#          'salt  pepper': 4229,
#          'Salt And Pepper taste': 4218,
#          'cup maple syrup': 4214,
#          'peanuts': 4213,
#          'cucumbers': 4213,
#          'cup molasses': 4212,
#          'of fresh mint': 4211,
#          'red bell peppers': 4164,
#          'ground turmeric': 4162,
#          'asparagus': 4152,
#          'dried rosemary': 4144,
#          'fresh basil leaves': 4143,
#          'cup margarine': 4140,
#          'egg lightly beaten': 4137,
#          'ground pork': 4135,
#          'oz pkg chocolate chips': 4097,
#          'frozen chopped spinach': 4094,
#          'cup unsalted butter': 4093,
#          'oz tomato paste': 4087,
#          'fresh oregano': 4076,
#          'lb Velveeta cheese': 4070,
#          'garlic cloves finely chopped': 4069,
#          'hot sauce': 4058,
#          'blue cheese': 4056,
#          'pumpkin': 4047,
#          'g butter': 4046,
#          'cup parmesan cheese': 4041,
#          'tablespoons chili powder': 4035,
#          'lb ground chuck': 4034,
#          'c firmly packed brown sugar': 4027,
#          'pkg dry yeast': 4026,
#          'medium potatoes': 4025,
#          'teaspoon Baking Soda': 4025,
#          'tablespoon oil': 4018,
#          'whole kernel corn': 4014,
#          'oranges': 4011,
#          'teaspoons chili powder': 4005,
#          'tablespoon chili powder': 4005,
#          'tablespoons salt': 3999,
#          'tbsp lemon juice': 3997,
#          'Tbsp mustard': 3986,
#          'Tablespoons Butter': 3977,
#          'chicken thighs': 3974,
#          'boneless skinless chicken breast': 3974,
#          'tablespoons chopped fresh parsley': 3970,
#          'onion finely chopped': 3966,
#          'pound ground beef': 3966,
#          'c salt': 3962,
#          'cups buttermilk': 3962,
#          'tablespoons butter softened': 3961,
#          'fresh strawberries': 3914,
#          'romaine lettuce': 3913,
#          'teaspoon allspice': 3896,
#          'teaspoon Vanilla': 3894,
#          'lb sausage': 3886,
#          'c light corn syrup': 3883,
#          'cup warm water': 3881,
#          'cracked black pepper': 3877,
#          'cups Milk': 3872,
#          'whole Egg': 3871,
#          'teaspoon cayenne': 3860,
#          'red onions': 3858,
#          'teaspoon sesame oil': 3854,
#          'tbsp sugar': 3853,
#          'lbs ground beef': 3846,
#          'dry red wine': 3834,
#          'strawberry': 3829,
#          'lettuce leaves': 3823,
#          'teaspoon Baking Powder': 3823,
#          'Egg': 3821,
#          'salt ground black pepper taste': 3821,
#          'Tbsp chopped parsley': 3808,
#          'cup light brown sugar': 3800,
#          'cups whole wheat flour': 3800,
#          'Tbsp minced onion': 3789,
#          'prepared mustard': 3778,
#          'c uncooked rice': 3777,
#          'graham cracker crumbs': 3755,
#          'Tbsp honey': 3748,
#          'Tbsp cinnamon': 3748,
#          'small onion finely chopped': 3746,
#          'cups purpose flour': 3742,
#          'salmon fillets': 3735,
#          'cup firmly packed brown sugar': 3731,
#          'tsp ground nutmeg': 3720,
#          'stick butter melted': 3714,
#          'nuts': 3707,
#          'teaspoons Dijon mustard': 3704,
#          'whipped cream': 3698,
#          'cup light corn syrup': 3685,
#          'tablespoons olive oil divided': 3685,
#          'Topping': 3677,
#          'medium onion finely chopped': 3670,
#          'c butter softened': 3666,
#          'roma tomatoes': 3663,
#          'tsp cornstarch': 3651,
#          'tsp seasoned salt': 3651,
#          'cup red wine': 3650,
#          'pinto beans': 3649,
#          'c minced onion': 3646,
#          'cup plain yogurt': 3639,
#          'hoisin sauce': 3638,
#          'beef bouillon cubes': 3636,
#          'chili sauce': 3630,
#          'tablespoon flour': 3630,
#          'ounce diced tomatoes': 3619,
#          'beaten egg': 3612,
#          'cup melted butter': 3612,
#          'low sodium soy sauce': 3604,
#          'whole milk': 3600,
#          'tsp onion powder': 3598,
#          'cup breadcrumbs': 3596,
#          'hard-boiled eggs': 3592,
#          'cup halfandhalf': 3588,
#          'small onion diced': 3578,
#          'ice': 3576,
#          'celery seed': 3566,
#          'slices bread': 3565,
#          'cake flour': 3561,
#          'green onions sliced': 3559,
#          'corn starch': 3549,
#          'teaspoon cornstarch': 3539,
#          'c Wesson oil': 3525,
#          'frozen corn': 3511,
#          'tsp prepared mustard': 3510,
#          'cottage cheese': 3508,
#          'c whipping cream': 3504,
#          'teaspoons Vanilla Extract': 3494,
#          'Tbsp butter melted': 3492,
#          'tablespoon allpurpose flour': 3492,
#          'jalapeno chilies': 3484,
#          'russet potatoes': 3467,
#          'tablespoons granulated sugar': 3467,
#          'lb bacon': 3464,
#          'minced garlic cloves': 3459,
#          'tablespoon extra virgin olive oil': 3454,
#          'minced garlic': 3450,
#          'tablespoon extravirgin olive oil': 3449,
#          'elbow macaroni': 3443,
#          'teaspoon ginger': 3443,
#          'pineapple': 3435,
#          'cup cornmeal': 3431,
#          'teaspoon honey': 3431,
#          'c brown sugar packed': 3419,
#          'peas': 3415,
#          'yellow bell pepper': 3409,
#          'flaked coconut': 3409,
#          'large eggs room temperature': 3398,
#          'chopped cilantro fresh': 3397,
#          'c Rice Krispies': 3397,
#          'Tbsp parsley': 3393,
#          'cup unsweetened cocoa powder': 3386,
#          'bell peppers': 3368,
#          'juice  lemon': 3368,
#          'quarts water': 3367,
#          'spring onions': 3363,
#          'onion sliced': 3342,
#          'dates': 3340,
#          'cloves garlic finely chopped': 3339,
#          'limes': 3337,
#          'cooking oil': 3335,
#          'creamy peanut butter': 3329,
#          'teaspoons Worcestershire sauce': 3329,
#          'c celery': 3325,
#          'cup parmesan cheese grated': 3308,
#          'cup vinegar': 3307,
#          'c white vinegar': 3306,
#          'Freshly ground pepper': 3294,
#          'rum': 3289,
#          'cup purpose flour': 3287,
#          'mango': 3285,
#          'garlic clove crushed': 3281,
#          'cups bread flour': 3277,
#          'Parmesan cheese': 3275,
#          'Tablespoon Olive Oil': 3271,
#          'teaspoon ground red pepper': 3267,
#          'oz crushed pineapple drained': 3254,
#          'large shrimp': 3251,
#          'cup evaporated milk': 3250,
#          'c cider vinegar': 3249,
#          'c skim milk': 3221,
#          'pecan halves': 3219,
#          'cup butter  cup margarine': 3217,
#          'cup packed light brown sugar': 3211,
#          'cup skim milk': 3209,
#          'sherry wine': 3208,
#          'c heavy cream': 3208,
#          'breadcrumbs': 3207,
#          'lemon juiced': 3204,
#          'ounce tomato paste': 3203,
#          'Tbsp allpurpose flour': 3196,
#          'large eggs beaten': 3192,
#          'stalks celery': 3191,
#          'stick butter margarine': 3184,
#          'Large eggs': 3184,
#          'tablespoon tomato paste': 3176,
#          'white onion': 3173,
#          'cups Brown Sugar': 3169,
#          'oz carton sour cream': 3166,
#          'teaspoon basil': 3165,
#          'baking potatoes': 3163,
#          'tsp cumin': 3160,
#          'c melted margarine': 3159,
#          'c finely chopped onion': 3155,
#          'Pepper': 3151,
#          'leek': 3147,
#          'teaspoons Cinnamon': 3144,
#          'tablespoon balsamic vinegar': 3141,
#          'peppercorns': 3137,
#          'cup white vinegar': 3137,
#          'c flaked coconut': 3133,
#          'oatmeal': 3132,
#          'cup dry red wine': 3131,
#          'graham cracker crust': 3125,
#          'salt & freshly ground black pepper': 3123,
#          'tomatoes chopped': 3121,
#          'tsp dill weed': 3114,
#          'large onion diced': 3114,
#          'cup fresh lime juice': 3113,
#          'Sauce': 3105,
#          'c nuts chopped': 3102,
#          'c shredded cheese': 3098,
#          'cup Allpurpose Flour': 3097,
#          'lemon peel': 3093,
#          'c cottage cheese': 3090,
#          'sliced mushrooms': 3089,
#          'tablespoons cider vinegar': 3084,
#          'oyster sauce': 3081,
#          'peanut oil': 3076,
#          'mandarin oranges': 3069,
#          'bittersweet chocolate': 3067,
#          'dill': 3060,
#          'cup hot water': 3056,
#          'tablespoons unsalted butter melted': 3056,
#          'large egg lightly beaten': 3052,
#          'tomato juice': 3045,
#          'medium shrimp': 3044,
#          'c sweet milk': 3039,
#          'teaspoons minced garlic': 3036,
#          'lemon, zest of': 3034,
#          'yellow cake mix': 3033,
#          'light soy sauce': 3031,
#          'freshly ground pepper': 3029,
#          'c margarine melted': 3019,
#          'cup salsa': 3019,
#          'c pineapple juice': 3016,
#          'lime, juice of': 3012,
#          'prosciutto': 3007,
#          'cups sour cream': 3005,
#          'mustard seeds': 3000,
#          'ground cardamom': 2997,
#          'italian seasoning': 2990,
#          'oz chocolate chips': 2989,
#          'marshmallows': 2982,
#          'teaspoons paprika': 2981,
#          'cup chocolate chips': 2978,
#          'box powdered sugar': 2976,
#          'c whole wheat flour': 2974,
#          'beef': 2965,
#          'teaspoon ground turmeric': 2960,
#          'cream': 2957,
#          'maraschino cherries': 2956,
#          'cup lime juice': 2952,
#          'sage': 2947,
#          'cans cream mushroom soup': 2944,
#          'grams Sugar': 2937,
#          'cup cream': 2935,
#          'tuna': 2933,
#          'raspberries': 2931,
#          'broccoli florets': 2931,
#          'cup Milk': 2926,
#          'provolone cheese': 2918,
#          'Dressing': 2915,
#          'oats': 2904,
#          'c Sugar': 2903,
#          'cilantro leaves': 2902,
#          'tablespoons melted butter': 2894,
#          'teaspoon fresh ground pepper': 2891,
#          'bell pepper chopped': 2890,
#          'artichoke hearts': 2875,
#          ...})

# %% [markdown]
# ### We can see a large amount of words that are unneccesary to our goal
# - will create a list (large) through study of the dataset of words to remove
# - we also don't need words like "flour" and "salt" to offset the predictions, nobody wants to hear "You know what goes really well with chicken? Flour!"

# %%
words_to_drop = {
    '° °', '&', '1%', '2%', 'a', 'about', 'accent', 'according', 'add', 'added', 'additional', 'all',
    'all-purpose', 'allpurpose', 'also', 'amount', 'amp', 'and', 'another', 'any', 'approx',
    'approximately', 'artificial', 'as', 'at', 'available', 'bag', 'bags', 'baking', 'baking soda',
    'bar', 'basic', 'beaten', 'beaters', 'best', 'better', 'big', 'bite', 'bitesize', 'bitesized', 'bits',
    'black pepper', 'blanched', 'blend', 'block', 'boiled', 'boiling', 'bone', 'boned', 'boneless',
    'bottle', 'bottled', 'bottles', 'bottom', 'box', 'boxes', 'brewed', 'broiler-fryer', 'broken',
    'brown', 'bsp', 'bunch', 'bunches', 'butter', 'buttered', 'buy', 'c', 'cake', 'called', 'can',
    'canned', 'cans', 'carton', 'center', 'chilled', 'chip', 'choice', 'chopped', 'chunk', 'clean',
    'cleaned', 'clear', 'club', 'cm', 'coarsely', 'coarse', 'coating', 'coconut oil', 'cocktail', 'cold',
    'colored', 'coloring', 'condensed', 'confectioners', "confectioners'", 'container', 'cooked', 'cooking', 'cornflour',
    'cornstarch', 'count', 'country', 'cover', 'crisp', 'crumbled', 'crumbles', 'crunchy', 'crushed',
    'crystallized', 'ct', 'cube', 'cubed', 'cubes', 'cup', 'cups', 'cut', 'dairy', 'dash', 'dashes', 'day',
    'dayold', 'de', 'deboned', 'defrosted', 'depending', 'desired', 'desseded', 'deveined', 'devil', 'diagonal',
    'diagonally', 'diameter', 'dice', 'diced', 'diet', 'dinner', 'dip', 'discarded', 'dish', 'dissolved',
    'divided', 'dont', 'dough', 'doz', 'dozen', 'drain', 'drained', 'dream', 'dried', 'drizzle', 'drops', 'dry',
    'dusting', 'ea', 'each', 'ears', 'either', 'ends', 'enough', 'envelope', 'equal', 'equipment', 'equivalent',
    'etc', 'evoo', 'exess', 'extract', 'extra', 'extravirgin', 'f', 'farm', 'fat', 'fatfree', 'favorite', 'filling', 'fine', 'find',
    'finely', 'firm', 'firmly', 'fl', 'flat', 'float', 'flour', 'foil', 'food', 'foods', 'for', 'found', 'four', 'free',
    'fresh', 'freshly', 'frozen', 'frzn', 'fry', 'fryer', 'frying', 'full', 'fully', 'g', 'gal', 'gallon', 'gallons', 'garlic',
    'garlic cloves', 'garnish', 'gelatin', 'generous', 'get', 'gluten', 'gm', 'goodquality', 'gram', 'grams', 'granulated', 'grated', 'great',
    'greasing', 'grill', 'grilled', 'grm', 'ground', 'halved', 'halves', 'handful', 'harcooked', 'hard', 'hard-boiled', 'hardboiled',
    'head', 'healthy', 'heat', 'heated', 'heaping', 'hellmanns', 'hidden', 'homemade', 'hot', 'hulled', 'i', 'ice', 'if', 'in', 'inch',
    'inches', 'inchthick', 'including', 'ingredient', 'ingredients', 'instant', 'into', 'jar', 'jarred', 'jars', 'juiced', 'julienne',
    'julienned', 'k', 'kernels', 'key', 'kg', 'kind', 'kitchen', 'kraft', 'l', 'large', 'layer', 'lb', 'lbs', 'lean', 'least', 'leave',
    'leftover', 'lengthwise', 'lengths', 'less', 'lesssodium', 'level', 'lg', 'lightly', 'like', 'liter', 'liters', 'little', 'loosely', 'low', 'lowfat',
    'lowsodium', 'lrg', 'lukewarm', 'lump', 'made', 'make', 'makes', 'margarine', 'mashed', 'med', 'medium', 'mediumsize', 'mediumsized',
    'melted', 'mg', 'milligram', 'milligrams', 'milliliter', 'milliliters', 'minced', 'mini', 'miniature', 'minute', 'minutes', 'mix',
    'ml', 'mms', 'more', 'mrs', 'much', 'n', 'necessary', 'need', 'needed', 'new', 'no', 'none', 'nonfat', 'nonstick', 'not', 'note', 'notes',
    'nutritional', 'o', 'of', 'oil', 'on', 'one', 'ones', 'optional', 'or', 'organic', 'ounce', 'ounces', 'oven', 'overnight', 'oz',
    'oz.', 'pack', 'package', 'packages', 'packed', 'packet', 'packets', 'page', 'partially', 'part-skim', 'parts', 'paste', 'patted',
    'pcs', 'peeled', 'per', 'philadelphia', 'pie', 'piece', 'pieces', 'pinch', 'pint', 'pints', 'pitted', 'pkg', 'pkt', 'plain', 'plus',
    'possibly', 'pot', 'pound', 'pounds', 'powder', 'powdered', 'precooked', 'prefer', 'preferably', 'preference', 'prepared', 'preserves',
    'pressed', 'process', 'processed', 'processor', 'product', 'pt', 'pureed', 'purpose', 'pwdr', 'qt', 'quart', 'quartered', 'quarters',
    'quarts', 'quick-cooking', 'raw', 'ready', 'recommended', 'reduced', 'reduced-sodium', 'reducedsodium', 'refrigerated', 'regular', 'remove', 'reserved',
    'room', 'rotel', 'rough', 'roughly', 'rounded', 'rounds', 'rubbed', 'safeway', 'salt', 'salted', 'san', 'sanwich', 'sauce', 'save',
    'scalded', 'scraped', 'scrubbed', 'sea', 'seasoned', 'seasons', 'sec', 'sections', 'see', 'seeded', 'self-rising', 'seperated', 'separated',
    'serving', 'several', 'shaved', 'sheet', 'sheets', 'shelled', 'shredded', 'shucked', 'side', 'sifted', 'simple', 'size', 'sized', 'skinless',
    'skinned', 'slice', 'sliced', 'slices', 'slightly', 'slivered', 'sm', 'small', 'smashed', 'snipped', 'soaked', 'softened', 'softend', 'sodium',
    'solid', 'soup', 'sour cream', 'splash', 'spray', 'sprig', 'sprigs', 'sprinkle', 'sprinkling', 'sq', 'square', 'squares', 'squeezed', 'steamed',
    'stem', 'stemmed', 'stewing', 'stick', 'sticks', 'storebought', 'stove', 'strained', 'string', 'strip', 'strips', 'stuffed', 'sub', 'substitute',
    'substituted', 'sugar', 'sweetener', 't', 'tablespoon', 'tablespoons', 'taste', 'tb', 'tbl', 'tbls', 'tbs', 'tbsp', 'teaspoon', 'teaspoons', 'temp',
    'temperature', 'thawed', 'thick', 'thickly', 'thin', 'thinly', 'thread', 'three', 'thru', 'time', 'tiny', 'tips', 'to', 'toasted', 'together', 'tomato',
    'toppings', 'tops', 'total', 'tots', 'triple', 'tsp', 'tub', 'two', 'type', 'unbaked', 'unbeaten', 'uncle', 'uncooked', 'undiluted', 'undrained',
    'unflavored', 'unpeeled', 'unsalted', 'unsifted', 'up', 'use', 'used', 'using', 'usually', 'v', 'variety', 'virgin', 'want', 'warm', 'warmed', 'washed',
    'water', 'wedge', 'weight', 'well', 'whatever', 'whipping', 'white', 'whites', 'whole', 'wide', 'with', 'without', 'wooden', 'work', 'would', 'x',
    'yeast', 'yolks', 'you', 'your', 'zested',
}

# %%
df['clean_ingredients'] = df['ingredients'].apply(lambda x: remove_words(x, words_to_drop))
df.head()
# Out:
#       id                                        ingredients  \
# 0  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213                [water, vegetable oil, wheat, salt]
# 4  13162  [black pepper, shallots, cornflour, cayenne pe...
#
#                                    clean_ingredients
# 0  [romaine lettuce, black olives, grape tomatoes...
# 1  [pepper, tomatoes, black pepper, thyme, eggs, ...
# 2  [eggs, pepper, mayonaise, green chilies, chick...
# 3                                 [vegetable, wheat]
# 4  [black pepper, shallots, cayenne pepper, onion...

# %% [markdown]
# ### Lots of words ending in "s" will reduce visibility
#  - I don't need "eggs" in one spot and "egg" in another

# %%
df['clean_ingredients'] = df['clean_ingredients'].apply(lambda x: remove_plural_s(x, letters_to_replace="s", replace_with=""))
counting(df['clean_ingredients'], "s")
# Out:
# Counter({'cloves': 359367,
#          'tomatoes': 179838,
#          'potatoes': 96656,
#          'red pepper flakes': 48734,
#          'strawberries': 41464,
#          'chives': 36616,
#          'bananas': 34096,
#          'bay leaves': 32616,
#          'apples': 30265,
#          'cranberries': 26999,
#          'basil leaves': 24514,
#          'peas': 24470,
#          'blueberries': 24419,
#          'green chilies': 23760,
#          'tortillas': 23751,
#          'black olives': 23027,
#          'molasses': 21742,
#          'cherry tomatoes': 19026,
#          'sweet potatoes': 18970,
#          'dates': 17004,
#          'raspberries': 14787,
#          'parsley flakes': 14413,
#          'cilantro leaves': 13589,
#          'corn tortillas': 13466,
#          'mint leaves': 13396,
#          'thyme leaves': 13257,
#          'plum tomatoes': 12392,
#          'peaches': 12305,
#          'mandarin oranges': 11921,
#          'asparagus': 11540,
#          'stewed tomatoes': 10932,
#          'parsley leaves': 10415,
#          'red potatoes': 9690,
#          'cherries': 9672,
#          'egg noodles': 9266,
#          'maraschino cherries': 8459,
#          'chickpeas': 8454,
#          'noodles': 8251,
#          'ripe olives': 8245,
#          'avocados': 7863,
#          'oregano leaves': 7827,
#          'ripe bananas': 7656,
#          'russet potatoes': 7616,
#          'green olives': 7509,
#          'roma tomatoes': 6918,
#          'oranges': 6856,
#          'mixed vegetables': 6381,
#          'limes': 6357,
#          'green peas': 6309,
#          'grape tomatoes': 6256,
#          'lasagna noodles': 6225,
#          'pimentos': 6116,
#          'couscous': 5878,
#          'olives': 5822,
#          'radishes': 5691,
#          'corn flakes': 5647,
#          'lettuce leaves': 5516,
#          'kalamata olives': 5275,
#          'jalapenos': 5154,
#          'pistachios': 5140,
#          'granny smith apples': 5137,
#          'rice krispies': 5101,
#          'yukon gold potatoes': 5055,
#          'ripe tomatoes': 4907,
#          'lime wedges': 4900,
#          'onion flakes': 4900,
#          'sage leaves': 4873,
#          'blackberries': 4810,
#          'lemon wedges': 4608,
#          'snow peas': 4559,
#          'coriander leaves': 4298,
#          'oreo cookies': 4174,
#          'jalapeno chilies': 3878,
#          'hash potatoes': 3844,
#          'spinach leaves': 3825,
#          'sundried tomatoes': 3776,
#          'baby spinach leaves': 3754,
#          'tomatoes green chilies': 3714,
#          'lemongrass': 3680,
#          'green chiles': 3665,
#          'rosemary leaves': 3659,
#          'tart apples': 3589,
#          'prunes': 3182,
#          'pimientos': 3027,
#          'vegetables': 3026,
#          'watercress': 3010,
#          'coffee granules': 2965,
#          'chow mein noodles': 2961,
#          'green tomatoes': 2950,
#          'red chilies': 2932,
#          'mangoes': 2893,
#          'berries': 2710,
#          'rice noodles': 2669,
#          'curry leaves': 2668,
#          'sun-dried tomatoes': 2614,
#          'chicken bouillon granules': 2607,
#          'celery leaves': 2472,
#          'chili flakes': 2458,
#          'land lakes': 2378,
#          'artichokes': 2355,
#          'tarragon leaves': 2334,
#          'dill pickles': 2206,
#          'chilies': 2192,
#          'cornflakes': 2169,
#          'grapes': 2153,
#          'flatleaf parsley leaves': 2089,
#          'candied cherries': 2085,
#          'english peas': 2060,
#          'ripe avocados': 2039,
#          'seedless grapes': 1999,
#          'blackeyed peas': 1957,
#          'dark molasses': 1914,
#          'anchovies': 1901,
#          'wheat tortillas': 1898,
#          'beef bouillon granules': 1875,
#          'snap peas': 1812,
#          'coconut flakes': 1795,
#          'tomatillos': 1777,
#          'tomatoes wedges': 1679,
#          'onion wedges': 1673,
#          'kaffir lime leaves': 1670,
#          'black-eyed peas': 1641,
#          'degrees': 1541,
#          'red seedless grapes': 1473,
#          'envelopes': 1463,
#          'poblano chiles': 1446,
#          'potato flakes': 1417,
#          'pinches': 1396,
#          'italian tomatoes': 1390,
#          'allspice berries': 1368,
#          'idaho potatoes': 1346,
#          'sweetened cranberries': 1341,
#          'navel oranges': 1326,
#          'spaghetti noodles': 1326,
#          'sausages': 1321,
#          'flakes': 1291,
#          'doritos': 1276,
#          'pickles': 1275,
#          'sweet pickles': 1268,
#          'mixed berries': 1261,
#          'lime juice limes': 1225,
#          'juniper berries': 1211,
#          'tomatoes chilies': 1169,
#          'ripe peaches': 1161,
#          'pepper flakes': 1151,
#          'light molasses': 1139,
#          'tomatoes tomatoes': 1137,
#          'serrano chilies': 1123,
#          'sultanas': 1101,
#          'sweet peas': 1097,
#          'spices': 1094,
#          'romaine lettuce leaves': 1089,
#          'baby peas': 1072,
#          'cookies': 1057,
#          'nectarines': 1039,
#          'red grapes': 1038,
#          'granules': 1033,
#          'chili pepper flakes': 1019,
#          'ramen noodles': 1013,
#          'juice limes': 1011,
#          'italian plum tomatoes': 1010,
#          'red apples': 994,
#          'lasagne noodles': 979,
#          'green grapes': 973,
#          'golden delicious apples': 972,
#          'mild green chilies': 963,
#          'split peas': 960,
#          'baby potatoes': 935,
#          'chiles': 929,
#          'sprinkles': 927,
#          'pickling spices': 922,
#          'pomegranate molasses': 920,
#          'chinese noodles': 919,
#          'italian parsley leaves': 911,
#          'tart cherries': 888,
#          'sour cherries': 867,
#          'red onion wedges': 867,
#          'fingerling potatoes': 860,
#          'saltines': 832,
#          'oreos': 830,
#          'seedless red grapes': 826,
#          'wedges': 815,
#          'jalapeno chiles': 813,
#          'fritos': 800,
#          'hummus': 796,
#          'arugula leaves': 793,
#          'duncan hines': 789,
#          'bonito flakes': 785,
#          'red chili pepper flakes': 783,
#          'raisins seedless': 773,
#          'soba noodles': 768,
#          'chipotle chiles': 761,
#          'nosaltadded tomatoes': 759,
#          'marjoram leaves': 755,
#          'macaroni noodles': 750,
#          'medjool dates': 739,
#          'unsweetened strawberries': 720,
#          'sweet cherries': 713,
#          'red chili flakes': 713,
#          'cheerios': 711,
#          'oilpacked sundried tomatoes': 702,
#          'seedless green grapes': 692,
#          'fireroasted tomatoes': 692,
#          'ancho chiles': 675,
#          'italianstyle tomatoes': 672,
#          'green apples': 670,
#          'italian-style tomatoes': 669,
#          'cabbage leaves': 658,
#          'serrano chiles': 653,
#          'italian sausages': 648,
#          'the cupcakes': 638,
#          'cakes': 633,
#          'green chillies': 630,
#          'sun tomatoes': 626,
#          'beefsteak tomatoes': 621,
#          'tomatoes green chiles': 614,
#          'onions wedges': 613,
#          'unsweetened raspberries': 597,
#          'degrees degrees': 597,
#          'cloves cloves': 581,
#          'substitutes': 580,
#          'udon noodles': 574,
#          'limes wedges': 573,
#          'dark sweet cherries': 560,
#          'heirloom tomatoes': 557,
#          'green chilis': 554,
#          'petite tomatoes': 553,
#          'crepes': 552,
#          'cupcakes': 547,
#          'anaheim chilies': 540,
#          'baby red potatoes': 540,
#          'chocolate wafer cookies': 539,
#          'french fries': 539,
#          'bing cherries': 538,
#          'courgettes': 534,
#          'gala apples': 532,
#          'calvados': 526,
#          'fenugreek leaves': 525,
#          'roasted pistachios': 522,
#          'stalks celery leaves': 522,
#          'pimento olives': 521,
#          'candy sprinkles': 519,
#          'french baguettes': 518,
#          'red chile flakes': 516,
#          'unsulphured molasses': 514,
#          'red delicious apples': 512,
#          'sweetened strawberries': 512,
#          'blackstrap molasses': 510,
#          'italian stewed tomatoes': 508,
#          'the cookies': 503,
#          'ripe plum tomatoes': 502,
#          'bran flakes': 501,
#          'papayas': 501,
#          'potatoes wedges': 498,
#          'chocolate cookies': 494,
#          'chocolate sprinkles': 493,
#          'red chiles': 493,
#          'marzano tomatoes': 492,
#          'lemon grass': 486,
#          'celery flakes': 485,
#          'green seedless grapes': 480,
#          'pickled jalapenos': 477,
#          'ripe mangoes': 471,
#          'torn basil leaves': 469,
#          'yellow split peas': 467,
#          'gingersnap cookies': 463,
#          'grape leaves': 461,
#          'garnishes': 461,
#          'hass avocadoes': 458,
#          'pimientostuffed olives': 458,
#          'redpepper flakes': 456,
#          'italian spices': 455,
#          'red cinnamon candies': 453,
#          'stalk lemongrass': 452,
#          'andouille sausages': 448,
#          'boston lettuce leaves': 447,
#          'mangos': 446,
#          'tomatoes juices': 441,
#          'chick-peas': 440,
#          'unsweetened coconut flakes': 436,
#          'potatoes potatoes': 433,
#          'chillies': 432,
#          'kale leaves': 431,
#          'ancho chilies': 431,
#          'sweetened coconut flakes': 430,
#          'israeli couscous': 430,
#          'red raspberries': 427,
#          'red cherries': 427,
#          'dashi stock granules': 426,
#          'peppermint candies': 425,
#          'pepitas': 424,
#          'fire roasted tomatoes': 423,
#          'marinated artichokes': 420,
#          'nicoise olives': 420,
#          'glace cherries': 419,
#          'leaves': 416,
#          'sweet basil leaves': 416,
#          'gloves': 411,
#          'candy canes': 409,
#          'canchopped green chilies': 407,
#          'spanish olives': 406,
#          'creme cassis': 406,
#          'assorted vegetables': 405,
#          'juice oranges': 404,
#          'blood oranges': 399,
#          'zucchinis': 395,
#          'kiwis': 392,
#          'cherry grape tomatoes': 392,
#          'cloves press': 388,
#          'parsley parsley flakes': 385,
#          'grnd cloves': 384,
#          'tangerines': 382,
#          'simply potatoes traditional potatoes': 378,
#          'lemons wedges': 375,
#          'raisins dates': 369,
#          'blueberries blueberries': 368,
#          'stalks lemongrass': 364,
#          'sardines': 362,
#          'baked potatoes': 362,
#          'roma plum tomatoes': 359,
#          'yellow tomatoes': 356,
#          'pork sausages': 355,
#          'aubergines': 354,
#          'redskinned potatoes': 351,
#          'red radishes': 347,
#          'guajillo chiles': 346,
#          'pimentostuffed green olives': 346,
#          'wheat berries': 345,
#          'grape cherry tomatoes': 345,
#          'noboil lasagna noodles': 343,
#          'chicken stock granules': 343,
#          'lesueur peas': 341,
#          'greek olives': 340,
#          'overripe bananas': 338,
#          'lime leaves': 336,
#          'pancakes': 335,
#          'tomatoes mild green chilies': 333,
#          'thai basil leaves': 333,
#          'waxy potatoes': 331,
#          'no-salt-added tomatoes': 331,
#          'peas peas': 331,
#          'cream cheese chives': 330,
#          'dill leaves': 330,
#          'veggies': 329,
#          'fire-roasted tomatoes': 329,
#          'vineripened tomatoes': 322,
#          'irish potatoes': 321,
#          'brownies': 320,
#          'chinese egg noodles': 319,
#          'chick peas': 318,
#          'ripe strawberries': 317,
#          'vanilla wafer cookies': 316,
#          'cellophane noodles': 314,
#          'pitas': 313,
#          'chinese chives': 311,
#          'mcintosh apples': 311,
#          'minus': 308,
#          'chilli flakes': 308,
#          'red bliss potatoes': 306,
#          'mixed pickling spices': 302,
#          'wheat couscous': 301,
#          'candied red cherries': 300,
#          'cabbage wedges': 300,
#          'chocolate sandwich cookies': 297,
#          'orange juice oranges': 297,
#          'petite peas': 291,
#          'yellow potatoes': 291,
#          'ketjap manis': 290,
#          'soft tortillas': 290,
#          'strawberries strawberries': 290,
#          'amaretti cookies': 289,
#          'judges': 289,
#          'rutabagas': 283,
#          'red candied cherries': 283,
#          'clementines': 281,
#          'red onions wedges': 281,
#          'waffles': 279,
#          'peaches peaches': 279,
#          'shortbread cookies': 278,
#          'cranberries cranberries': 277,
#          'parsley chives': 272,
#          'chile flakes': 272,
#          'tamales': 268,
#          'baby artichokes': 268,
#          'garden peas': 266,
#          'italianstyle stewed tomatoes': 266,
#          'baby arugula leaves': 265,
#          'red maraschino cherries': 261,
#          'green split peas': 258,
#          'italian plum roma tomatoes': 257,
#          'shiso leaves': 255,
#          'thai chiles': 255,
#          'leviticus': 254,
#          'cored apples': 254,
#          'braggs liquid aminos': 253,
#          'turkey carcass': 247,
#          'roasted tomatoes': 246,
#          'chorizo sausages': 246,
#          'shakes': 246,
#          'burrito-size tortillas': 244,
#          'cream asparagus': 244,
#          'bibb lettuce leaves': 244,
#          'orange wedges': 243,
#          'watercress leaves': 240,
#          'tagliatelle pasta noodles': 238,
#          'pared apples': 238,
#          'singles': 238,
#          'pasilla chiles': 237,
#          'iceberg lettuce leaves': 237,
#          'celery ribs leaves': 237,
#          'red chillies': 235,
#          'lychees': 234,
#          'fuji apples': 234,
#          'vegetable bouillon granules': 232,
#          'teas': 231,
#          'tomatos': 230,
#          'ripe black olives': 228,
#          'unsulfured molasses': 228,
#          'garbanzo beans chickpeas': 228,
#          'burritosize tortillas': 228,
#          'hersheys kisses': 227,
#          'oilcured black olives': 227,
#          'milk degrees': 226,
#          'chayotes': 225,
#          'glass': 225,
#          'shoestring potatoes': 223,
#          'octopus': 222,
#          'unsweetened blueberries': 220,
#          'rotini noodles': 219,
#          'cream cones': 219,
#          'stir vegetables': 217,
#          'red tomatoes': 217,
#          'soft corn tortillas': 215,
#          'southern style hash potatoes': 215,
#          'floury potatoes': 215,
#          'chinese vegetables': 215,
#          'plump cloves': 214,
#          'mexican-style tomatoes': 213,
#          'candies': 213,
#          'kosher dill pickles': 213,
#          'bread pickles': 212,
#          'tomatoes jalapenos': 212,
#          'roasted cloves': 212,
#          'ro-tel tomatoes': 212,
#          'cantaloupes': 210,
#          'reeses': 210,
#          'green asparagus': 209,
#          'cukes': 209,
#          'bean noodles': 208,
#          'black cherries': 207,
#          'oregano flakes': 207,
#          'bananas bananas': 207,
#          'pimento green olives': 206,
#          'vegall mixed vegetables': 205,
#          'vermicelli noodles': 204,
#          'cajun spices': 203,
#          'red ripe tomatoes': 201,
#          'celery stalks leaves': 201,
#          'serves': 201,
#          'romaine leaves': 200,
#          'stalk celery leaves': 200,
#          'leaves shiso leaves': 200,
#          'mint flakes': 199,
#          'quinces': 199,
#          'heads cloves': 199,
#          'boysenberries': 198,
#          'italian-style stewed tomatoes': 197,
#          'chocolate kisses': 197,
#          'cream sandwiches': 196,
#          'twinkies': 195,
#          'vine ripened tomatoes': 193,
#          'fennel leaves': 193,
#          'seedless oranges': 193,
#          'leaf parsley leaves': 193,
#          'apples apples': 192,
#          'wheat lasagna noodles': 191,
#          'sweetened raspberries': 191,
#          'pumpkin seeds pepitas': 191,
#          'bass': 190,
#          'mixed spices': 190,
#          'au jus': 189,
#          'goji berries': 188,
#          'stalks asparagus': 188,
#          'the brownies': 188,
#          'caramel candies': 187,
#          'torn mint leaves': 186,
#          'strawberries raspberries': 185,
#          'peaches wedges': 185,
#          'thyme thyme leaves': 185,
#          'green cherries': 183,
#          'arbol chiles': 182,
#          'chard leaves': 182,
#          'cherry tomatoes grape tomatoes': 182,
#          'mexicanstyle stewed tomatoes': 181,
#          'mild green chiles': 180,
#          'beef bones': 179,
#          'daikon radishes': 178,
#          'clove press': 178,
#          'wild blueberries': 177,
#          'yellow cherry tomatoes': 177,
#          'chicken breasts pounded thickness': 177,
#          'banana leaves': 176,
#          'wiener sausages': 176,
#          'clove cloves': 175,
#          'calamata olives': 174,
#          'hershey chocolate kisses': 174,
#          'pineapples': 174,
#          'green onions chives': 173,
#          'mixed veggies': 172,
#          'ripe hass avocados': 172,
#          'stock granules': 172,
#          'raspberries raspberries': 171,
#          'broad egg noodles': 170,
#          'carrots bias': 170,
#          'habaneros': 169,
#          'black eyed peas': 169,
#          'pinches red pepper flakes': 169,
#          'rocket leaves': 168,
#          'california vegetables': 166,
#          'salad olives': 166,
#          'wholewheat tortillas': 166,
#          'red green candied cherries': 165,
#          'ortega chilies': 165,
#          'pared potatoes': 164,
#          'yellow duncan hines': 164,
#          'pasta noodles': 163,
#          'honey molasses': 163,
#          'chervil leaves': 163,
#          'gooseberries': 162,
#          'hamburger patties': 162,
#          'stirfry vegetables': 162,
#          'ripe bananas bananas': 162,
#          'cansliced black olives': 161,
#          'scapes': 160,
#          'fettuccine noodles': 160,
#          'chicken drummettes': 159,
#          'bacos': 159,
#          'raisins cranberries': 157,
#          'purple potatoes': 156,
#          'jerusalem artichokes': 155,
#          'scalloped potatoes': 155,
#          'italian style tomatoes': 155,
#          'pimientostuffed green olives': 155,
#          'green candied cherries': 155,
#          'cilantro stems leaves': 155,
#          'the pancakes': 154,
#          'tostadas': 153,
#          'pimentostuffed olives': 153,
#          'yams sweet potatoes': 153,
#          'apples cored wedges': 153,
#          'flatleafed parsley leaves': 153,
#          'red potatoes wedges': 152,
#          'spears asparagus': 152,
#          '8-inch tortillas': 151,
#          'onion onion flakes': 151,
#          'obrien potatoes': 151,
#          'zest oranges': 151,
#          'au gratin potatoes': 150,
#          'amos': 150,
#          'sorghum molasses': 149,
#          'hass avocados': 149,
#          'milk chocolate kisses': 148,
#          'chives chives': 148,
#          'fines herbes': 147,
#          'times': 147,
#          'swiss chard leaves': 146,
#          'concord grapes': 145,
#          'grape tomatoes cherry tomatoes': 145,
#          'scallions bias': 145,
#          'swiss': 144,
#          'oreida hash potatoes': 144,
#          'redhot candies': 144,
#          'rosemary needles': 143,
#          'unsweetened peaches': 143,
#          'salad leaves': 142,
#          'sweet apples': 142,
#          'vegall vegetables': 142,
#          'mexican-style stewed tomatoes': 141,
#          'forgiveness': 141,
#          'mexicanstyle tomatoes': 141,
#          'rice cakes': 140,
#          'chablis': 140,
#          'tart green apples': 140,
#          'foie gras': 139,
#          'huckleberries': 139,
#          'sweet potatoes wedges': 139,
#          'green maraschino cherries': 138,
#          'limas': 138,
#          'nacho cheese doritos': 138,
#          'poblano chilies': 137,
#          'sandwiches': 137,
#          'guajillo chilies': 137,
#          'torn spinach leaves': 136,
#          'italian style stewed tomatoes': 135,
#          'broad noodles': 135,
#          'zest limes': 135,
#          'whl cloves': 135,
#          'basil basil leaves': 134,
#          'colby monterey jack cheeses': 134,
#          'leaf lettuce leaves': 134,
#          'tin tomatoes': 133,
#          'trimmed watercress': 133,
#          'dipping sauces': 132,
#          'pigeon peas': 132,
#          'raspberries strawberries': 132,
#          'fettucini noodles': 132,
#          'red green grapes': 132,
#          'cherries cranberries': 132,
#          'the scones': 132,
#          'bouillon granules': 131,
#          'tart red cherries': 131,
#          'rolling cookies': 131,
#          'lo mein noodles': 130,
#          'potatos': 130,
#          'matzos': 129,
#          'cranberries cherries': 128,
#          'hunts tomatoes': 128,
#          'chicken breast pounded thickness': 128,
#          'tomatoes chiles': 127,
#          'mildflavored light molasses': 127,
#          'kluski noodles': 126,
#          'pomegranates': 126,
#          'pineapple wedges': 126,
#          'tacos': 126,
#          'rome apples': 125,
#          'hash patties': 125,
#          'plum tomatoes wedges': 125,
#          'apple wedges': 124,
#          'multicolored sprinkles': 123,
#          'green leaf lettuce leaves': 123,
#          'ortega green chilies': 121,
#          'apples wedges': 120,
#          'vine ripe tomatoes': 120,
#          'oilcured olives': 120,
#          'radicchio leaves': 119,
#          'shell noodles': 119,
#          'nosaltadded stewed tomatoes': 119,
#          'coconut aminos': 118,
#          '10-inch tortillas': 118,
#          'dark cherries': 118,
#          'green black olives': 118,
#          'chipotle chilies': 118,
#          'natural pistachios': 117,
#          'toes': 117,
#          'ripe tomatoes wedges': 117,
#          'chicken drumettes': 117,
#          'elbow noodles': 117,
#          'leaves bay leaves': 117,
#          'very ripe bananas': 117,
#          'hellmann real mayonnais': 117,
#          'ripe tomatoes tomatoes': 116,
#          'tightly baby spinach leaves': 116,
#          'napa cabbage leaves': 115,
#          'allspice cloves': 115,
#          'mostaccioli noodles': 114,
#          'black green olives': 114,
#          'consomme stock granules': 114,
#          'split green peas': 113,
#          'sour cream chives': 113,
#          'espresso granules': 112,
#          'lemon thyme leaves': 112,
#          'sweet italian sausages': 112,
#          'baguettes': 112,
#          'cinnamon candies': 111,
#          'spiral noodles': 110,
#          'chickenflavored ramen noodles': 110,
#          'unsweetened cocoa dutchprocess': 110,
#          'fluid tomatoes': 110,
#          'peperoncino flakes': 110,
#          'glass noodles': 109,
#          'lemon balm leaves': 109,
#          'dehydrated onion flakes': 109,
#          'corn tortillas tortillas': 109,
#          'stalks lemon grass': 109,
#          'yellow onion wedges': 109,
#          'black tea leaves': 108,
#          'mexican tomatoes': 108,
#          'smokies': 108,
#          'manicotti noodles': 108,
#          'no-boil lasagna noodles': 107,
#          'soft taco-size tortillas': 107,
#          'lecithin granules': 107,
#          'red candies': 107,
#          'ripe roma tomatoes': 107,
#          'hokkien noodles': 106,
#          'banana bananas': 106,
#          'tomatoes cherry tomatoes': 106,
#          'espresso coffee granules': 106,
#          'rice vermicelli noodles': 106,
#          'california bay leaves': 105,
#          'scones': 105,
#          'bushel tomatoes': 105,
#          'chocolate candies': 105,
#          'bulb cloves': 105,
#          'belgian endives': 105,
#          'basil leaves leaves': 105,
#          'baby yukon gold potatoes': 105,
#          'chicken bones': 104,
#          'avocado wedges': 104,
#          'burrito tortillas': 104,
#          'meringues': 103,
#          'ripe nectarines': 103,
#          'kalamata brinecured black olives': 103,
#          'truffles': 102,
#          'tea leaves': 102,
#          'mexico chiles': 102,
#          'genesis': 102,
#          'petite green peas': 102,
#          'zest juice limes': 102,
#          'delicious apples': 101,
#          'peck green tomatoes': 101,
#          'granny smith apples cored wedges': 101,
#          'grapes seedless': 101,
#          'ladyfinger cookies': 101,
#          'epazote leaves': 100,
#          'potato wedges': 99,
#          'beef sausages': 99,
#          'beef patties': 99,
#          'hershey kisses': 99,
#          'creamettes': 99,
#          'mexican stewed tomatoes': 99,
#          'cheddar monterey jack cheeses': 99,
#          'cloves put press': 98,
#          'creamfilled chocolate sandwich cookies': 98,
#          'jonathan apples': 97,
#          'spinach tortillas': 97,
#          'juice tomatoes': 97,
#          'tomatoes stewed tomatoes': 97,
#          'nopales': 96,
#          'smokies sausages': 96,
#          'frosted flakes': 96,
#          'roll cookies': 96,
#          'basket strawberries': 96,
#          'strawberries berries': 96,
#          'mixed olives': 96,
#          'turkish bay leaves': 95,
#          "o'brien potatoes": 95,
#          'candied green cherries': 95,
#          'rainbow sprinkles': 95,
#          'black truffles': 94,
#          'black grapes': 94,
#          'spinach noodles': 94,
#          'macadamias': 94,
#          'anaheim chiles': 94,
#          'crab cakes': 94,
#          'scallions chives': 94,
#          'sweet potatoes sweet potatoes': 94,
#          'peaches nectarines': 94,
#          'kalamata olives brinecured black olives': 94,
#          'compressed cakes': 93,
#          'green onions bias': 93,
#          'plum tomatoes juices': 93,
#          'nocook lasagna noodles': 93,
#          'soft tacosize tortillas': 93,
#          'md potatoes': 93,
#          'chop suey vegetables': 92,
#          'ripe banana bananas': 92,
#          'patties': 92,
#          'glasses': 92,
#          'mixed vegetables carrots corn green beans peas': 92,
#          'vine tomatoes': 91,
#          'sweet onion wedges': 91,
#          'enchiladas': 91,
#          'breakfast sausages': 90,
#          'oven-ready lasagna noodles': 90,
#          'oil-cured black olives': 90,
#          'braeburn apples': 90,
#          'endives': 90,
#          'other pastas': 90,
#          'servings potatoes': 90,
#          'nachos': 90,
#          'milk singles': 90,
#          'baby dill pickles': 89,
#          'rice bubbles': 89,
#          'lemon verbena leaves': 89,
#          'broccoli flowerettes': 89,
#          'tomatoes hand juices': 89,
#          'candiced tomatoes green chilies': 89,
#          'serve sausages': 88,
#          'sausage patties': 88,
#          'green olives pimentos': 88,
#          'peppermint candy canes': 88,
#          'stalk lemon grass': 88,
#          'canschopped green chilies': 88,
#          'round red potatoes': 87,
#          'fettucine noodles': 87,
#          'sweet potatoes potatoes': 87,
#          'guinness': 87,
#          'picholine olives': 86,
#          'tostitos': 86,
#          'baskets strawberries': 86,
#          'green bananas': 85,
#          '6-inch tortillas': 85,
#          'somen noodles': 85,
#          'tortillas corn tortillas': 85,
#          'plum tomatoes tomatoes': 85,
#          'tinned tomatoes': 85,
#          'meat bones': 84,
#          'shirataki noodles': 84,
#          'pandan leaves': 84,
#          'hostess twinkies': 84,
#          'chicken flavored bouillon granules': 84,
#          'ripe cherry tomatoes': 84,
#          'wasabi peas': 83,
#          'red skin potatoes': 83,
#          'cinnamon cloves': 83,
#          'lesueur english peas': 83,
#          'red potatoes potatoes': 83,
#          'tightly basil leaves': 83,
#          'chocolate sandwich style cookies': 82,
#          'green mangoes': 82,
#          'ribs celery leaves': 82,
#          'turnips wedges': 82,
#          'castelvetrano olives': 81,
#          'fromage frais': 81,
#          'baby tomatoes': 81,
#          'pork neck bones': 81,
#          'chanterelles': 81,
#          'eggs wedges': 81,
#          'lime juice lime wedges': 81,
#          'roasted potatoes': 80,
#          'mulberries': 80,
#          'red green cherries': 80,
#          'assorted berries': 80,
#          'pared tart apples': 80,
#          'red leaf lettuce leaves': 80,
#          'ripe mangos': 80,
#          'pita bread wedges': 80,
#          'kale stems removed leaves': 80,
#          'orange zest oranges': 80,
#          'green tea leaves': 79,
#          'nacho cheese flavor doritos': 79,
#          'curry madras': 79,
#          'caper berries': 78,
#          'pasta shapes': 78,
#          'low-sodium tomatoes': 78,
#          'baby limas': 78,
#          'corkscrew noodles': 78,
#          'potatoes red potatoes': 78,
#          'rind oranges': 78,
#          'russet potatoes wedges': 78,
#          'red chilis': 78,
#          'gaeta olives': 77,
#          'sorrel leaves': 77,
#          'nuts cherries': 77,
#          'blueberries raspberries': 77,
#          'smoked sausages': 77,
#          'vineripe tomatoes': 77,
#          'bones': 76,
#          'unsweetened mixed berries': 76,
#          'low-sodium chicken bouillon granules': 76,
#          'vermicelli rice noodles': 76,
#          'peck tomatoes': 76,
#          'hardcooked eggs wedges': 76,
#          'craisins cranberries': 75,
#          'grandmas molasses': 75,
#          'californiablend vegetables': 75,
#          'lime zest limes': 75,
#          'buckwheat noodles': 74,
#          "hellmann' real mayonnais": 74,
#          '6-inch corn tortillas': 74,
#          'pumpkin spices': 74,
#          'rice crispies': 74,
#          'thai chilies': 74,
#          'thai bird chiles': 74,
#          'gingersnap cookies cookies': 74,
#          'elderberries': 73,
#          'cinnamon red candies': 73,
#          'red cherry tomatoes': 73,
#          'pickled vegetables': 72,
#          'roasted green chilies': 72,
#          'ripened bananas': 72,
#          'baked sweet potatoes': 72,
#          'onion stuck cloves': 72,
#          'globe artichokes': 72,
#          'jalepenos': 72,
#          'birds eye chiles': 71,
#          'andes mints candies': 71,
#          'basil leaves basil leaves': 71,
#          'freezedried chives': 71,
#          'mild molasses': 71,
#          'green onion chives': 71,
#          'wholewheat pitas': 71,
#          'kecap manis': 70,
#          'fajita tortillas': 70,
#          'quinoa flakes': 70,
#          'assorted candies': 70,
#          'wheat pitas': 70,
#          'barberries': 69,
#          'guavas': 69,
#          'black raspberries': 69,
#          'raspberry jam seedless': 69,
#          'cartons strawberries': 69,
#          'rigatoni noodles': 69,
#          'onions onion flakes': 69,
#          'orange oranges': 69,
#          'chicken-flavored ramen noodles': 68,
#          'linguine noodles': 68,
#          'milk colby monterey jack cheeses': 68,
#          'the cakes': 68,
#          'almond flakes': 68,
#          'wheat egg noodles': 67,
#          'top ramen noodles': 67,
#          'unsweetened cherries': 67,
#          'baby octopus': 67,
#          'sour apples': 67,
#          'habanero chiles': 67,
#          'pimiento olives': 67,
#          'clove put press': 67,
#          'natures': 67,
#          'basket cherry tomatoes': 67,
#          'raspberries blueberries': 67,
#          'mixed salad leaves': 67,
#          'belgian endive leaves': 67,
#          'gold potatoes': 66,
#          'sunchokes': 66,
#          'green serrano chilies': 66,
#          'wheaties': 66,
#          'coriander cilantro leaves': 66,
#          'idaho russet potatoes': 66,
#          'nectarines wedges': 66,
#          'iceberg lettuce wedges': 66,
#          'celery rib leaves': 66,
#          'bibb boston lettuce leaves': 66,
#          'millilitres': 66,
#          'chicken carcass': 65,
#          'apples golden delicious': 65,
#          'cherry tomatoes tomatoes': 65,
#          'strawberries blueberries': 65,
#          'corn tortillas wedges': 65,
#          'plums wedges': 65,
#          'ripe hass avocadoes': 65,
#          'wholewheat couscous': 65,
#          'red chilli flakes': 65,
#          'honey nut cheerios': 64,
#          'baby green peas': 64,
#          'cannelloni tubes': 64,
#          'lemon leaves': 64,
#          'watermelon wedges': 64,
#          'angel cakes': 64,
#          'creole seasoning tony chacheres': 64,
#          'long red chilies': 64,
#          'garbanzos': 63,
#          'ripe red tomatoes': 63,
#          'onion chives': 63,
#          'celery stalk leaves': 63,
#          'asparagus asparagus': 63,
#          'cherries cherries': 63,
#          'thickness': 63,
#          'brer rabbit molasses': 63,
#          'nutmeg cloves': 63,
#          'spinach excess': 63,
#          'yellow corn tortillas': 63,
#          'assorted sprinkles': 63,
#          'torn romaine lettuce leaves': 63,
#          'manzanilla olives': 62,
#          'wheat noodles': 62,
#          'taco flavored doritos': 62,
#          'cling peaches': 62,
#          'seedless red green grapes': 62,
#          'boil lasagna noodles': 62,
#          'red yellow cherry tomatoes': 62,
#          'chilis': 62,
#          'orientalflavor ramen noodles': 62,
#          'heirloom cherry tomatoes': 62,
#          'redskin potatoes': 61,
#          'yes': 61,
#          'early peas': 61,
#          'russet yukon gold potatoes': 61,
#          'chicken breast skin bones': 61,
#          'avacados': 61,
#          'ovenready lasagna noodles': 61,
#          'mint leaves leaves': 61,
#          'low-fat tortillas': 60,
#          'red pimentos': 60,
#          'cored tomatoes': 60,
#          'cured black olives': 60,
#          'oat flakes': 60,
#          'curly leaf lettuce leaves': 60,
#          'desiree potatoes': 60,
#          'accompaniment lemon wedges': 60,
#          'canpetite tomatoes': 60,
#          'fresno chiles': 59,
#          'shortcakes': 59,
#          'spaetzle noodles': 59,
#          'rye flakes': 59,
#          'wheat flakes': 59,
#          'ortega green chiles': 59,
#          'sweet green peas': 59,
#          'kindness': 59,
#          'cheese cheddar swiss': 59,
#          'chicken ramen noodles': 59,
#          'ripe beefsteak tomatoes': 59,
#          'glazed cherries': 59,
#          'rinsed chickpeas': 59,
#          'milk degrees degrees': 59,
#          'punnet cherry tomatoes': 59,
#          'peppermint patties': 58,
#          'vegetable flakes': 58,
#          'salad potatoes': 58,
#          ...})

# %% [markdown]
# ### We still have other plurals
#  - lets convert "ies" to "y"
#  - lets convert "oes" to "o"

# %%
df['clean_ingredients'] = df['clean_ingredients'].apply(lambda x: remove_plural_s(x, letters_to_replace="ies", replace_with="y"))
df.head()
# Out:
#       id                                        ingredients  \
# 0  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213                [water, vegetable oil, wheat, salt]
# 4  13162  [black pepper, shallots, cornflour, cayenne pe...
#
#                                    clean_ingredients
# 0  [romaine lettuce, black olives, grape tomatoes...
# 1  [pepper, tomatoes, black pepper, thyme, egg, g...
# 2  [egg, pepper, mayonaise, green chily, chicken ...
# 3                                 [vegetable, wheat]
# 4  [black pepper, shallot, cayenne pepper, onion,...

# %%
counting(df['clean_ingredients'], "ies")
# Out:
# Counter()

# %%
df['clean_ingredients'] = df['clean_ingredients'].apply(lambda x: remove_plural_s(x, letters_to_replace="oes", replace_with="o"))
df.head()
# Out:
#       id                                        ingredients  \
# 0  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213                [water, vegetable oil, wheat, salt]
# 4  13162  [black pepper, shallots, cornflour, cayenne pe...
#
#                                    clean_ingredients
# 0  [romaine lettuce, black olives, grape tomato, ...
# 1  [pepper, tomato, black pepper, thyme, egg, gre...
# 2  [egg, pepper, mayonaise, green chily, chicken ...
# 3                                 [vegetable, wheat]
# 4  [black pepper, shallot, cayenne pepper, onion,...

# %%
counting(df['clean_ingredients'], "oes")
# Out:
# Counter()

# %%
counters = counting(data_list = df['clean_ingredients'], to_count="")
counters
# Out:
# Counter({'egg': 847536,
#          'onion': 696568,
#          'pepper': 505680,
#          'olive': 433019,
#          'milk': 421965,
#          'vanilla': 376812,
#          'cloves': 359367,
#          'black pepper': 288154,
#          'cinnamon': 261298,
#          'lemon juice': 229158,
#          'soda': 217104,
#          'tomato': 179838,
#          'parsley': 163236,
#          'sour cream': 161162,
#          'carrot': 157705,
#          'cream cheese': 155799,
#          'parmesan cheese': 145850,
#          'clove': 138487,
#          'ginger': 132896,
#          'vegetable': 125912,
#          'green onion': 120729,
#          'chicken breast': 117080,
#          'celery': 116783,
#          'beef': 116102,
#          'cheddar cheese': 114880,
#          'pecan': 111680,
#          'potato': 111569,
#          'soy': 110857,
#          'nutmeg': 110276,
#          'mayonnaise': 110059,
#          'mushroom': 104583,
#          'chicken broth': 103901,
#          'oregano': 103107,
#          'honey': 101815,
#          'cumin': 101315,
#          'kosher': 96732,
#          'thyme': 95491,
#          'worcestershire': 93427,
#          'chili': 92532,
#          'vinegar': 90506,
#          'basil': 88672,
#          'cilantro': 88450,
#          'green pepper': 87638,
#          'heavy cream': 84078,
#          'rice': 82858,
#          'mustard': 82051,
#          'bacon': 81007,
#          'paprika': 80987,
#          'walnut': 74249,
#          'almond': 73106,
#          'chicken': 71539,
#          'red onion': 69365,
#          'nut': 67251,
#          'peanut': 67183,
#          'lime juice': 66762,
#          'cayenne pepper': 63802,
#          'wine': 63283,
#          'pineapple': 62278,
#          'lemon': 61457,
#          'buttermilk': 61040,
#          'shortening': 60877,
#          'raisin': 57426,
#          'mozzarella cheese': 55935,
#          'dijon mustard': 52242,
#          'shallot': 52087,
#          'coconut': 51990,
#          'strawberry': 51433,
#          'cocoa': 49807,
#          'canola': 49555,
#          'zucchini': 49195,
#          'red pepper flakes': 48734,
#          'red bell pepper': 48541,
#          'orange juice': 47972,
#          'shrimp': 47824,
#          'red pepper': 45692,
#          'cheese': 45604,
#          'cool whip': 44850,
#          'corn': 43496,
#          'cream mushroom': 42818,
#          'rosemary': 42722,
#          'ketchup': 42606,
#          'cream': 42037,
#          'spinach': 41401,
#          'light': 40414,
#          'chocolate chip': 39852,
#          'cream chicken': 38665,
#          'scallion': 38056,
#          'bay leaf': 37006,
#          'green bell pepper': 36989,
#          'chives': 36616,
#          'cucumber': 36553,
#          'bread': 34892,
#          'broccoli': 34406,
#          'red wine vinegar': 34296,
#          'evaporated milk': 34278,
#          'bananas': 34096,
#          'allspice': 34093,
#          'coriander': 33330,
#          'yellow onion': 33080,
#          'bread crumb': 33053,
#          'bay leaves': 32616,
#          'curry': 32322,
#          'yogurt': 32199,
#          'wheat': 31849,
#          'oleo': 31588,
#          'chicken stock': 30936,
#          'cranberry': 30678,
#          'marshmallow': 30442,
#          'apples': 30265,
#          'bell pepper': 30104,
#          'ham': 29812,
#          'turmeric': 29286,
#          'lemon zest': 29188,
#          'sharp cheddar cheese': 28850,
#          'sesame': 28687,
#          'sesame seed': 28320,
#          'cabbage': 27753,
#          'balsamic vinegar': 27443,
#          'cider vinegar': 27170,
#          'blueberry': 26435,
#          'mint': 26298,
#          'dill': 25612,
#          'sweet potato': 25023,
#          'basil leaves': 24514,
#          'spaghetti': 24503,
#          'peas': 24470,
#          'red wine': 24162,
#          'salsa': 24129,
#          'green chily': 23760,
#          'tortillas': 23751,
#          'sage': 23369,
#          'black olives': 23027,
#          'tabasco': 22579,
#          'beef broth': 22561,
#          'green bean': 22368,
#          'pineapple juice': 22296,
#          'swiss cheese': 22188,
#          'cherry': 21924,
#          'pumpkin': 21913,
#          'molasses': 21742,
#          'monterey jack cheese': 21720,
#          'breadcrumb': 21720,
#          'lime': 21419,
#          'feta cheese': 21330,
#          'sweetened milk': 21125,
#          'lettuce': 20979,
#          'pork': 20936,
#          'maple syrup': 20910,
#          'avocado': 20685,
#          'wine vinegar': 20419,
#          'celery rib': 20146,
#          'turkey': 19914,
#          'dark': 19757,
#          'cottage cheese': 19638,
#          'vanilla pudding': 19522,
#          'semisweet chocolate chip': 19470,
#          'chocolate': 19414,
#          'black bean': 19185,
#          'cherry tomato': 19026,
#          'active': 18919,
#          'cream tartar': 18760,
#          'skim milk': 18607,
#          'selfrising': 18516,
#          'raspberry': 18436,
#          'celery seed': 18254,
#          'cornmeal': 18057,
#          'pure vanilla': 17953,
#          'banana': 17943,
#          'rice vinegar': 17942,
#          'jalapeno pepper': 17832,
#          'cayenne': 17778,
#          'apple': 17660,
#          'stalks celery': 17412,
#          'orange zest': 17355,
#          'ricotta cheese': 17326,
#          'chestnut': 17296,
#          'salad': 17195,
#          'dates': 17004,
#          'light corn syrup': 16977,
#          'yellow': 16848,
#          'hamburger': 16844,
#          'seasoning': 16831,
#          'coconut milk': 16633,
#          'sherry': 16550,
#          'italian seasoning': 16375,
#          'orange': 16331,
#          'caper': 16276,
#          'catsup': 16202,
#          'apple cider vinegar': 15865,
#          'fish': 15648,
#          'graham cracker crumb': 15586,
#          'eggplant': 15385,
#          'pine nut': 15325,
#          'velveeta cheese': 15269,
#          'horseradish': 14804,
#          'sweet onion': 14778,
#          'kidney bean': 14717,
#          'rolled oat': 14641,
#          'parsley flakes': 14413,
#          'cumin seed': 14390,
#          'unsweetened cocoa': 14361,
#          'apricot': 14314,
#          'tarragon': 14070,
#          'taco seasoning': 13942,
#          'dill weed': 13930,
#          'vegetable broth': 13869,
#          'kernel corn': 13845,
#          'crisco': 13782,
#          'egg yolk': 13745,
#          'juice': 13618,
#          'leek': 13590,
#          'cilantro leaves': 13589,
#          'unbleached': 13541,
#          'chicken thigh': 13487,
#          'broccoli floret': 13481,
#          'corn tortillas': 13466,
#          'mint leaves': 13396,
#          'thyme leaves': 13257,
#          'oatmeal': 13249,
#          'oat': 13127,
#          'bisquick': 13089,
#          'pasta': 12983,
#          'cauliflower': 12793,
#          'vanilla cream': 12727,
#          'chicken bouillon': 12607,
#          'barbecue': 12531,
#          'plum tomato': 12392,
#          'applesauce': 12375,
#          'coffee': 12311,
#          'peaches': 12305,
#          'crust': 12215,
#          'icing': 12175,
#          'mandarin oranges': 11921,
#          'lemon rind': 11907,
#          'cardamom': 11816,
#          'flaked coconut': 11724,
#          'mustard seed': 11645,
#          'asparagus': 11540,
#          'caster': 11497,
#          'cream celery': 11471,
#          'black peppercorn': 11416,
#          'pork chop': 11401,
#          'maraschino cherry': 11332,
#          'tuna': 11280,
#          'marjoram': 11247,
#          'sausage': 11220,
#          'lemon peel': 11216,
#          'gingerroot': 11173,
#          'leaf parsley': 11054,
#          'stewed tomato': 10932,
#          'semisweet chocolate': 10886,
#          'mango': 10869,
#          'red potato': 10852,
#          'beer': 10739,
#          'poppy seed': 10729,
#          'brandy': 10710,
#          'blue cheese': 10648,
#          'corn syrup': 10550,
#          'shell': 10518,
#          'whipped topping': 10494,
#          'american cheese': 10484,
#          'rum': 10440,
#          'parsley leaves': 10415,
#          'juice lemon': 10405,
#          'elbow macaroni': 10219,
#          'whipped cream': 10055,
#          'kosher black pepper': 10043,
#          'creamy peanut': 10022,
#          'graham cracker crust': 9826,
#          'cracked black pepper': 9702,
#          'flatleaf parsley': 9614,
#          'artichoke heart': 9570,
#          'vodka': 9559,
#          'golden raisin': 9549,
#          'graham cracker': 9497,
#          'tortilla chip': 9496,
#          'bean': 9486,
#          'fennel seed': 9420,
#          'garam masala': 9363,
#          'long grain rice': 9348,
#          'tofu': 9342,
#          'parmesan': 9332,
#          'beef bouillon': 9274,
#          'egg noodles': 9266,
#          'oyster': 9250,
#          'soft': 9093,
#          'halfandhalf': 9065,
#          'fruit': 9029,
#          'russet potato': 8997,
#          'salmon fillet': 8990,
#          'pumpkin spice': 8958,
#          'vegetable stock': 8923,
#          'eagle brand milk': 8860,
#          'pinto bean': 8776,
#          'button mushroom': 8721,
#          'splenda': 8706,
#          'cashew': 8702,
#          'unsweetened chocolate': 8518,
#          'chickpeas': 8454,
#          'pineapple chunk': 8431,
#          'spring onion': 8335,
#          'caraway seed': 8292,
#          'stalk celery': 8278,
#          'noodles': 8251,
#          'ripe olives': 8245,
#          'ginger ale': 8238,
#          'pear': 8130,
#          'half-and-half': 8064,
#          'italian parsley': 7986,
#          'macaroni': 7930,
#          'poultry seasoning': 7876,
#          'avocados': 7863,
#          'black beans rinsed': 7845,
#          'puree': 7835,
#          'oregano leaves': 7827,
#          'jalapeno': 7802,
#          'biscuit': 7791,
#          'hoisin': 7762,
#          'baby spinach': 7724,
#          'greek yogurt': 7691,
#          'yellow bell pepper': 7691,
#          'vegetable shortening': 7681,
#          'ripe bananas': 7656,
#          'yellow cornmeal': 7639,
#          'pimento': 7597,
#          'green olives': 7509,
#          'crescent roll': 7417,
#          'apple juice': 7414,
#          'quick oat': 7406,
#          'crabmeat': 7389,
#          'romaine lettuce': 7370,
#          'pizza': 7362,
#          'puff pastry': 7278,
#          'strawberry jello': 7251,
#          'rhubarb': 7247,
#          'hazelnut': 7218,
#          'bean sprout': 7218,
#          'chocolate pudding': 7158,
#          'sunflower seed': 7140,
#          'apple cider': 7121,
#          'half half': 7075,
#          'pumpkin puree': 7045,
#          'peppercorn': 7021,
#          'prosciutto': 7016,
#          'bittersweet chocolate': 7005,
#          'liquid smoke': 6945,
#          'roma tomato': 6918,
#          'lime zest': 6895,
#          'dark chocolate': 6878,
#          'oranges': 6856,
#          'goat cheese': 6795,
#          'pepperoni': 6757,
#          'topping': 6714,
#          'refried bean': 6690,
#          'mirin': 6661,
#          'chuck': 6640,
#          'cranberry juice': 6603,
#          'coriander seed': 6593,
#          'orange rind': 6592,
#          'smoked paprika': 6587,
#          'red': 6559,
#          'beef stock': 6546,
#          'celery stalk': 6542,
#          'roasted peanut': 6534,
#          'butternut squash': 6506,
#          'wheat germ': 6499,
#          'bourbon': 6487,
#          'yellow mustard': 6463,
#          'sake': 6455,
#          'lentil': 6427,
#          'sauerkraut': 6415,
#          'provolone cheese': 6411,
#          'orange peel': 6409,
#          'unsweetened applesauce': 6383,
#          'creamstyle corn': 6382,
#          'mixed vegetables': 6381,
#          'sharp cheese': 6374,
#          'limes': 6357,
#          'vanilla wafer': 6321,
#          'green peas': 6309,
#          'light soy': 6302,
#          'pork bean': 6302,
#          'purple onion': 6286,
#          'dark rum': 6263,
#          'beet': 6263,
#          'grape tomato': 6256,
#          'lasagna noodles': 6225,
#          'red kidney bean': 6200,
#          'scallop': 6175,
#          'miracle whip': 6158,
#          'pork tenderloin': 6152,
#          'romano cheese': 6145,
#          'pimentos': 6116,
#          'roasted red pepper': 6096,
#          'sweet red pepper': 6087,
#          'yellow squash': 6000,
#          'low-fat milk': 5974,
#          'yukon gold potato': 5911,
#          'lamb': 5879,
#          'couscous': 5878,
#          'ritz cracker': 5851,
#          'italian sausage': 5848,
#          'olives': 5822,
#          'syrup': 5809,
#          'linguine': 5781,
#          'blackberry': 5751,
#          'saffron': 5727,
#          'table': 5714,
#          'penne pasta': 5713,
#          'radishes': 5691,
#          'flax seed': 5685,
#          'lemon pepper': 5649,
#          'corn flakes': 5647,
#          'sherry wine': 5638,
#          'ranch dressing': 5607,
#          'currant': 5580,
#          'gruyere cheese': 5543,
#          'lettuce leaves': 5516,
#          'parsnip': 5495,
#          'meat': 5495,
#          'extra-virgin olive': 5494,
#          'quinoa': 5490,
#          'pesto': 5454,
#          'rice wine vinegar': 5450,
#          'basmati rice': 5418,
#          'plum': 5416,
#          'salmon': 5399,
#          'pretzel': 5380,
#          'vanilla bean': 5375,
#          'chicken wing': 5372,
#          'orange marmalade': 5334,
#          'creamed corn': 5329,
#          'corn starch': 5319,
#          'tomatoes juice': 5305,
#          'kalamata olives': 5275,
#          'green cabbage': 5223,
#          'shiitake mushroom': 5169,
#          'jalapenos': 5154,
#          'pistachios': 5140,
#          'granny smith apples': 5137,
#          'okra': 5128,
#          'the': 5125,
#          'mozzarella': 5121,
#          'rice krispy': 5102,
#          'cauliflower floret': 5099,
#          'red chili pepper': 5081,
#          'pure maple syrup': 5078,
#          'light cream': 5076,
#          'caramel': 5066,
#          'arugula': 5003,
#          'creme fraiche': 4988,
#          'red cabbage': 4980,
#          'hash brown': 4970,
#          'tahini': 4956,
#          'baby carrot': 4950,
#          'lemonade': 4912,
#          'chili bean': 4908,
#          'ripe tomato': 4907,
#          'chili pepper': 4903,
#          'lime wedges': 4900,
#          'onion flakes': 4900,
#          'garbanzo bean': 4876,
#          'sage leaves': 4873,
#          'cracker crumb': 4866,
#          'steak': 4832,
#          'arborio rice': 4822,
#          'red chili': 4817,
#          'orange juice concentrate': 4816,
#          'dressing': 4814,
#          'crouton': 4787,
#          'panko breadcrumb': 4766,
#          'vanilla yogurt': 4764,
#          'lemon jello': 4688,
#          'sweet paprika': 4686,
#          'lemon wedges': 4608,
#          'squash': 4583,
#          'pancetta': 4563,
#          'snow peas': 4559,
#          'pimiento': 4541,
#          'butterscotch chip': 4537,
#          'iceberg lettuce': 4536,
#          'italian dressing': 4504,
#          'kosher pepper': 4478,
#          'cajun seasoning': 4460,
#          'clam': 4457,
#          'round steak': 4434,
#          'peach': 4430,
#          'herb': 4401,
#          'anchovy fillet': 4351,
#          'turnip': 4343,
#          'light sour cream': 4343,
#          'ginger root': 4341,
#          'french bread': 4341,
#          'lima bean': 4329,
#          'tapioca': 4314,
#          'coriander leaves': 4298,
#          'wesson': 4296,
#          'hardcooked egg': 4283,
#          'green': 4280,
#          'light mayonnaise': 4278,
#          'fig': 4275,
#          'tea': 4244,
#          'kale': 4216,
#          'english cucumber': 4174,
#          'oreo cooky': 4174,
#          'longgrain rice': 4157,
#          'old fashioned oat': 4112,
#          'mace': 4102,
#          'pork sausage': 4063,
#          'vanilla flavoring': 4049,
#          'wild rice': 4043,
#          'anchovy': 4029,
#          'fennel bulb': 3990,
#          'chocolate syrup': 3990,
#          'espresso': 3969,
#          'cooled': 3963,
#          'mascarpone cheese': 3947,
#          'star anise': 3945,
#          'egg egg': 3943,
#          'baguette': 3941,
#          'vanilla essence': 3928,
#          'cheez whiz': 3922,
#          'sweet milk': 3912,
#          'soymilk': 3905,
#          'splenda granular': 3883,
#          'jalapeno chily': 3878,
#          'distilled vinegar': 3873,
#          'hash potato': 3863,
#          'mayo': 3856,
#          'basil leaf': 3850,
#          'cannellini bean': 3840,
#          'smoked sausage': 3826,
#          'spinach leaves': 3825,
#          'spanish onion': 3804,
#          'orange jello': 3803,
#          'corn meal': 3799,
#          'sundried tomato': 3776,
#          'baby spinach leaves': 3754,
#          'ghee': 3753,
#          'green chili pepper': 3743,
#          'crab meat': 3737,
#          'karo syrup': 3722,
#          'tomatoes green chily': 3714,
#          'cool whip whipped topping': 3714,
#          'broth': 3707,
#          'pineapple tidbit': 3698,
#          'lemongrass': 3680,
#          'lard': 3675,
#          'smoked salmon': 3675,
#          'turkey breast': 3672,
#          'marshmallow creme': 3669,
#          'salad dressing': 3666,
#          'green chiles': 3665,
#          'rosemary leaves': 3659,
#          'marshmallow cream': 3659,
#          'italian salad dressing': 3653,
#          'superfine': 3646,
#          'sweet': 3645,
#          'northern bean': 3632,
#          'sriracha': 3619,
#          'cremini mushroom': 3607,
#          'sweetened flaked coconut': 3604,
#          'pan': 3592,
#          'tart apples': 3589,
#          'brussels sprout': 3565,
#          'milk chocolate chip': 3557,
#          'hamburger bun': 3549,
#          'tequila': 3548,
#          'angel': 3531,
#          'old bay seasoning': 3489,
#          'sherry vinegar': 3471,
#          'pecans walnut': 3469,
#          'fettuccine': 3428,
#          'marinara': 3427,
#          'partskim mozzarella cheese': 3394,
#          'potato chip': 3381,
#          'taco': 3376,
#          'apples cored': 3374,
#          'enchilada': 3360,
#          'kahlua': 3345,
#          'mild cheddar cheese': 3345,
#          'cheddar': 3345,
#          'flank steak': 3341,
#          'parmigianoreggiano cheese': 3318,
#          'corned beef': 3312,
#          'dark corn syrup': 3302,
#          'wheat pastry': 3301,
#          'feta': 3294,
#          'sunflower': 3288,
#          'frosting': 3267,
#          'walnuts pecan': 3233,
#          'bacon fried': 3229,
#          'zest lemon': 3227,
#          'soft bread crumb': 3226,
#          'sweetened coconut': 3201,
#          'orzo pasta': 3193,
#          'angel hair pasta': 3192,
#          'cracked pepper': 3188,
#          'lipton onion': 3184,
#          'prunes': 3182,
#          'asparagus spear': 3177,
#          'self raising': 3166,
#          'unsweetened coconut': 3162,
#          'mexican cheese': 3158,
#          'asiago cheese': 3153,
#          'barley': 3148,
#          'light cream cheese': 3146,
#          'german chocolate': 3140,
#          'vermouth': 3130,
#          'lime jello': 3121,
#          'vidalia onion': 3117,
#          'glaze': 3115,
#          'wonton wrapper': 3103,
#          'miso': 3102,
#          'olive drizzling': 3097,
#          'dark soy': 3096,
#          'teriyaki': 3066,
#          'quickcooking oat': 3060,
#          'kalamata olive': 3059,
#          'cracker': 3052,
#          'green beans trimmed': 3040,
#          'lemon, zest': 3034,
#          'pimientos': 3027,
#          'vegetables': 3026,
#          'long-grain rice': 3024,
#          'lime, juice': 3016,
#          'pistachio pudding': 3015,
#          'watercress': 3010,
#          'dark sesame': 3000,
#          'beef stew meat': 2999,
#          'stuffing': 2987,
#          'onion ring': 2975,
#          'coffee granules': 2965,
#          'picante': 2961,
#          'chow mein noodles': 2961,
#          'wheat bread': 2955,
#          'green tomato': 2950,
#          'red chily': 2933,
#          'macadamia nut': 2932,
#          'phyllo': 2917,
#          'hamburger meat': 2903,
#          'monterey jack pepper cheese': 2895,
#          'unsweetened coconut milk': 2892,
#          'grand marnier': 2892,
#          'cardamom pod': 2857,
#          'granny smith apple': 2850,
#          'spicy mustard': 2845,
#          'yellow pepper': 2833,
#          'chickpeas rinsed': 2831,
#          'peppermint': 2820,
#          'baked shell': 2820,
#          'bacon dripping': 2818,
#          'berry': 2812,
#          'chunky salsa': 2811,
#          'pearl barley': 2808,
#          'cognac': 2798,
#          'pork loin': 2797,
#          'amaretto': 2784,
#          'curd cottage cheese': 2780,
#          'kidney beans rinsed': 2758,
#          'navy bean': 2747,
#          'portabella mushroom': 2744,
#          'halfandhalf cream': 2734,
#          'ribs celery': 2703,
#          'grain mustard': 2700,
#          'fish fillet': 2686,
#          'pork shoulder': 2670,
#          'rice noodles': 2669,
#          'curry leaves': 2668,
#          'fennel': 2667,
#          'chunky peanut': 2664,
#          'xanthan gum': 2663,
#          'sun-dried': 2654,
#          'saffron thread': 2648,
#          'napa cabbage': 2646,
#          'fontina cheese': 2644,
#          'saltine cracker': 2638,
#          'whip': 2622,
#          'cream whipped': 2619,
#          'stock': 2618,
#          'sun-dried tomato': 2614,
#          'sweet pickle relish': 2612,
#          'chicken bouillon granules': 2607,
#          'semi-sweet chocolate chip': 2606,
#          'half-and-half cream': 2602,
#          'bamboo shoot': 2601,
#          'clam juice': 2601,
#          'self rising': 2596,
#          'watermelon': 2590,
#          'mussel': 2579,
#          'roasting chicken': 2572,
#          'creole seasoning': 2570,
#          'green chili': 2544,
#          'sour milk': 2541,
#          'pecorino romano cheese': 2539,
#          'parmigiano-reggiano cheese': 2526,
#          'low-fat yogurt': 2519,
#          'ripe banana': 2518,
#          'chorizo sausage': 2512,
#          'pumpkin seed': 2497,
#          'wasabi': 2484,
#          'agave nectar': 2476,
#          'dog': 2474,
#          'celery leaves': 2472,
#          'cilantro leaf': 2467,
#          'juice lime': 2459,
#          'chili flakes': 2458,
#          'lemon pudding': 2445,
#          'pet milk': 2439,
#          'gravy': 2420,
#          'velveeta': 2392,
#          'polenta': 2387,
#          'deli ham': 2382,
#          'light coconut milk': 2378,
#          'land lakes': 2378,
#          'marinade': 2374,
#          'pastry': 2374,
#          'lemon juice lemon': 2374,
#          'smooth peanut': 2368,
#          'heavy cream whipped': 2367,
#          'strong coffee': 2366,
#          'rice wine': 2358,
#          'marsala wine': 2358,
#          'artichokes': 2355,
#          'english muffin': 2354,
#          'cantaloupe': 2349,
#          'ripe avocado': 2346,
#          'asparagus trimmed': 2346,
#          'gorgonzola': 2344,
#          'candied cherry': 2344,
#          'italian breadcrumb': 2343,
#          'red lentil': 2338,
#          'tarragon leaves': 2334,
#          'roll': 2323,
#          'potato starch': 2322,
#          'berry cranberry': 2308,
#          'light rum': 2307,
#          'chile': 2301,
#          'alfredo': 2300,
#          'lemonade concentrate': 2284,
#          'milk chocolate': 2283,
#          'seedless raisin': 2282,
#          'semisweet chocolate morsel': 2261,
#          'turbinado': 2247,
#          'grapeseed': 2245,
#          'semolina': 2240,
#          'chipotle chiles adobo': 2236,
#          'guacamole': 2228,
#          'smoked ham': 2227,
#          'pita bread': 2226,
#          'sherry wine vinegar': 2225,
#          'beef brisket': 2211,
#          'zesty italian dressing': 2209,
#          'ricotta': 2208,
#          'dill pickles': 2206,
#          'apricot jam': 2206,
#          'tortilla': 2198,
#          'chily': 2193,
#          'baby arugula': 2192,
#          'acorn squash': 2189,
#          'tamari': 2178,
#          'bakers semisweet chocolate': 2178,
#          'penne': 2173,
#          'chicken leg': 2170,
#          'golden syrup': 2169,
#          'cornflakes': 2169,
#          'marinated artichoke heart': 2169,
#          'sirloin': 2167,
#          'dill pickle': 2166,
#          'chicken drumstick': 2165,
#          'coconut cream': 2160,
#          'eggs egg': 2160,
#          'grapes': 2153,
#          'gin': 2150,
#          'salami': 2148,
#          'bulk pork sausage': 2145,
#          'beef chuck': 2141,
#          'golden': 2139,
#          'kielbasa': 2128,
#          'chipotle chile adobo': 2126,
#          'light olive': 2121,
#          'jicama': 2119,
#          'sweet corn': 2107,
#          'mint leaf': 2106,
#          'loaf french bread': 2106,
#          'unsweetened pineapple juice': 2103,
#          'tumeric': 2095,
#          'cashew nut': 2095,
#          'mushroom stem': 2093,
#          'cannellini beans rinsed': 2093,
#          'pork loin chop': 2090,
#          'olive vegetable': 2089,
#          'flatleaf parsley leaves': 2089,
#          'red chile': 2088,
#          'orange bell pepper': 2084,
#          'chuck roast': 2082,
#          'mayonnaise salad dressing': 2080,
#          'cherry jello': 2075,
#          'sirloin steak': 2068,
#          'anise seed': 2066,
#          'corn chip': 2061,
#          'bok choy': 2060,
#          'english peas': 2060,
#          'veal': 2056,
#          'lemon, juice': 2056,
#          'rotini pasta': 2054,
#          'ancho chile': 2053,
#          'red curry': 2043,
#          'cornbread': 2039,
#          'tater': 2039,
#          'ripe avocados': 2039,
#          'mayonaise': 2036,
#          'red capsicum': 2036,
#          'italian bread crumb': 2030,
#          'porcini mushroom': 2025,
#          'hominy': 2019,
#          'bouillon': 2019,
#          'bow tie pasta': 2019,
#          'pearl onion': 2018,
#          'kiwi fruit': 2016,
#          'arrowroot': 2009,
#          'seedless grapes': 1999,
#          'bicarbonate soda': 1986,
#          'port wine': 1986,
#          'palm': 1975,
#          'soya': 1970,
#          'yoghurt': 1969,
#          'pastry shell': 1963,
#          'blackeyed peas': 1957,
#          'lettuce leaf': 1956,
#          'grapefruit juice': 1942,
#          'loaf bread': 1939,
#          'crisco shortening': 1935,
#          'scant': 1935,
#          'mexican oregano': 1934,
#          'flavoring': 1933,
#          'french onion': 1931,
#          'silken tofu': 1930,
#          'scallions green': 1926,
#          'double cream': 1924,
#          'grit': 1915,
#          'dark molasses': 1914,
#          'wheat tortillas': 1898,
#          'sweet pepper': 1890,
#          'pasta shell': 1889,
#          'roma': 1889,
#          'mango chutney': 1884,
#          'savory': 1878,
#          'beef bouillon granules': 1875,
#          'beef consomme': 1858,
#          'almond milk': 1857,
#          'frenchstyle green bean': 1853,
#          'tilapia fillet': 1849,
#          'raspberry jello': 1849,
#          'beef roast': 1845,
#          'herb stuffing': 1845,
#          'panko bread crumb': 1837,
#          'jasmine rice': 1836,
#          'season': 1834,
#          'chicken stock broth': 1834,
#          'mixed salad green': 1831,
#          'sweet basil': 1825,
#          'chicken turkey': 1825,
#          'quick oatmeal': 1822,
#          'poblano pepper': 1820,
#          'rose': 1816,
#          'snap peas': 1812,
#          'reducedfat sour cream': 1808,
#          'meatball': 1806,
#          'jumbo shrimp': 1799,
#          'coconut flakes': 1795,
#          'apple cored': 1795,
#          'round': 1779,
#          'tomatillos': 1777,
#          'chicken liver': 1775,
#          'leg lamb': 1772,
#          'sweet chili': 1771,
#          'pudding': 1759,
#          'beef browned': 1753,
#          'grenadine': 1748,
#          'kiwi': 1741,
#          'pomegranate seed': 1741,
#          'pickling': 1741,
#          'radish': 1740,
#          'chia seed': 1738,
#          'shell pasta': 1736,
#          'mascarpone': 1734,
#          'black sesame seed': 1729,
#          'pomegranate juice': 1725,
#          'popped popcorn': 1723,
#          'edamame': 1713,
#          'baked bean': 1706,
#          'tarragon vinegar': 1705,
#          'mixed spice': 1702,
#          'flat-leaf parsley': 1699,
#          'french vanilla pudding': 1699,
#          'stew meat': 1698,
#          'chinese five spice': 1693,
#          'pizza crust': 1692,
#          'cream coconut': 1692,
#          'grnd beef': 1690,
#          'sundried': 1687,
#          'sourdough bread': 1687,
#          'almond flavoring': 1686,
#          'peanut chip': 1680,
#          'rye': 1679,
#          'sharp cheddar': 1679,
#          'tomatoes wedges': 1679,
#          'adobo': 1675,
#          'stevia': 1674,
#          'bacon grease': 1674,
#          'katakuriko': 1674,
#          'onion wedges': 1673,
#          '° °': 1672,
#          'andouille sausage': 1670,
#          'kaffir lime leaves': 1670,
#          'champagne vinegar': 1666,
#          'deep': 1662,
#          'champagne': 1661,
#          'coleslaw': 1658,
#          'jack cheese': 1657,
#          'tamari soy': 1655,
#          'basil pesto': 1649,
#          'prawn': 1647,
#          'butterscotch pudding': 1645,
#          'tuna steak': 1644,
#          'yellow corn meal': 1643,
#          'caramel cream topping': 1643,
#          'black-eyed peas': 1641,
#          'lime rind': 1636,
#          'cream potato': 1635,
#          'papaya': 1632,
#          'real': 1631,
#          'devil': 1628,
#          'oat bran': 1626,
#          'habanero pepper': 1624,
#          'tamarind': 1622,
#          'colby cheese': 1621,
#          'catfish fillet': 1618,
#          'red bean': 1616,
#          'vanilla bean split': 1615,
#          'scallions spring green onion': 1611,
#          'phyllo pastry': 1610,
#          'dark chocolate chip': 1608,
#          'herbes provence': 1603,
#          'raspberry jam': 1599,
#          'apricot nectar': 1595,
#          'beef turkey': 1592,
#          'jello': 1588,
#          'serrano pepper': 1586,
#          'black mustard seed': 1584,
#          'smoked bacon': 1584,
#          'dill seed': 1582,
#          'french fried onion': 1581,
#          'swiss chard': 1579,
#          'onion onion': 1579,
#          'allspice berry': 1577,
#          'italian bread': 1576,
#          'eagle brand sweetened milk': 1563,
#          'olive brushing': 1562,
#          'angel flake coconut': 1561,
#          'pork loin roast': 1560,
#          'idaho potato': 1558,
#          'karo': 1555,
#          'lemon flavoring': 1555,
#          'canadian bacon': 1554,
#          'olive flavored': 1552,
#          'chipotle pepper': 1552,
#          'rigatoni pasta': 1547,
#          'msg': 1546,
#          'dijonstyle mustard': 1545,
#          'breakstones knudsen sour cream': 1545,
#          'chipotle': 1542,
#          'creme cacao': 1541,
#          'degrees': 1541,
#          'capers rinsed': 1538,
#          'cool': 1537,
#          'golden mushroom': 1536,
#          'tuna flaked': 1535,
#          'pineapple chunks juice': 1534,
#          'flax seed meal': 1533,
#          'parmigianoreggiano': 1533,
#          'vegall': 1532,
#          'lawry': 1530,
#          'yam': 1524,
#          'basil basil': 1522,
#          'grapefruit': 1521,
#          'broccoli floweret': 1518,
#          'candied pineapple': 1515,
#          'potatoes chunk': 1515,
#          'selfraising': 1515,
#          'whiskey': 1514,
#          'corn kernel': 1512,
#          'pistachio nut': 1506,
#          'beef tenderloin': 1505,
#          'spice': 1505,
#          'ranch style bean': 1502,
#          'vegetable olive': 1501,
#          'skewer': 1499,
#          'beef chuck roast': 1498,
#          ...})

# %%
words_to_replace = {
    'halfandhalf': 'half-and-half cream',
    'half half': 'half-and-half cream',
    'half-and-half': 'half-and-half cream',
    'lowfat sour cream': 'light sour cream',
    'marshmallow creme': 'marshmallow cream',
    'egg egg': 'egg',

}

# %%
df.shape
# Out:
# (3064844, 3)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (3064844, 3)

# %%
non_list_rows = df[df['clean_ingredients'].apply(lambda x: not isinstance(x, list))]
non_list_rows
# Out:
# Empty DataFrame
# Columns: [id, ingredients, clean_ingredients]
# Index: []

# %%
counters = counting(data_list = df['clean_ingredients'], to_count="")
counters
# Out:
# Counter({'egg': 847536,
#          'onion': 696568,
#          'pepper': 505680,
#          'olive': 433019,
#          'milk': 421965,
#          'vanilla': 376812,
#          'cloves': 359367,
#          'black pepper': 288154,
#          'cinnamon': 261298,
#          'lemon juice': 229158,
#          'soda': 217104,
#          'tomato': 179838,
#          'parsley': 163236,
#          'sour cream': 161162,
#          'carrot': 157705,
#          'cream cheese': 155799,
#          'parmesan cheese': 145850,
#          'clove': 138487,
#          'ginger': 132896,
#          'vegetable': 125912,
#          'green onion': 120729,
#          'chicken breast': 117080,
#          'celery': 116783,
#          'beef': 116102,
#          'cheddar cheese': 114880,
#          'pecan': 111680,
#          'potato': 111569,
#          'soy': 110857,
#          'nutmeg': 110276,
#          'mayonnaise': 110059,
#          'mushroom': 104583,
#          'chicken broth': 103901,
#          'oregano': 103107,
#          'honey': 101815,
#          'cumin': 101315,
#          'kosher': 96732,
#          'thyme': 95491,
#          'worcestershire': 93427,
#          'chili': 92532,
#          'vinegar': 90506,
#          'basil': 88672,
#          'cilantro': 88450,
#          'green pepper': 87638,
#          'heavy cream': 84078,
#          'rice': 82858,
#          'mustard': 82051,
#          'bacon': 81007,
#          'paprika': 80987,
#          'walnut': 74249,
#          'almond': 73106,
#          'chicken': 71539,
#          'red onion': 69365,
#          'nut': 67251,
#          'peanut': 67183,
#          'lime juice': 66762,
#          'cayenne pepper': 63802,
#          'wine': 63283,
#          'pineapple': 62278,
#          'lemon': 61457,
#          'buttermilk': 61040,
#          'shortening': 60877,
#          'raisin': 57426,
#          'mozzarella cheese': 55935,
#          'dijon mustard': 52242,
#          'shallot': 52087,
#          'coconut': 51990,
#          'strawberry': 51433,
#          'cocoa': 49807,
#          'canola': 49555,
#          'zucchini': 49195,
#          'red pepper flakes': 48734,
#          'red bell pepper': 48541,
#          'orange juice': 47972,
#          'shrimp': 47824,
#          'red pepper': 45692,
#          'cheese': 45604,
#          'cool whip': 44850,
#          'corn': 43496,
#          'cream mushroom': 42818,
#          'rosemary': 42722,
#          'ketchup': 42606,
#          'cream': 42037,
#          'spinach': 41401,
#          'light': 40414,
#          'chocolate chip': 39852,
#          'cream chicken': 38665,
#          'scallion': 38056,
#          'bay leaf': 37006,
#          'green bell pepper': 36989,
#          'chives': 36616,
#          'cucumber': 36553,
#          'bread': 34892,
#          'broccoli': 34406,
#          'red wine vinegar': 34296,
#          'evaporated milk': 34278,
#          'bananas': 34096,
#          'allspice': 34093,
#          'coriander': 33330,
#          'yellow onion': 33080,
#          'bread crumb': 33053,
#          'bay leaves': 32616,
#          'curry': 32322,
#          'yogurt': 32199,
#          'wheat': 31849,
#          'oleo': 31588,
#          'chicken stock': 30936,
#          'cranberry': 30678,
#          'marshmallow': 30442,
#          'apples': 30265,
#          'bell pepper': 30104,
#          'ham': 29812,
#          'turmeric': 29286,
#          'lemon zest': 29188,
#          'sharp cheddar cheese': 28850,
#          'sesame': 28687,
#          'sesame seed': 28320,
#          'cabbage': 27753,
#          'balsamic vinegar': 27443,
#          'cider vinegar': 27170,
#          'blueberry': 26435,
#          'mint': 26298,
#          'dill': 25612,
#          'sweet potato': 25023,
#          'basil leaves': 24514,
#          'spaghetti': 24503,
#          'peas': 24470,
#          'red wine': 24162,
#          'salsa': 24129,
#          'green chily': 23760,
#          'tortillas': 23751,
#          'sage': 23369,
#          'black olives': 23027,
#          'tabasco': 22579,
#          'beef broth': 22561,
#          'green bean': 22368,
#          'pineapple juice': 22296,
#          'swiss cheese': 22188,
#          'cherry': 21924,
#          'pumpkin': 21913,
#          'molasses': 21742,
#          'monterey jack cheese': 21720,
#          'breadcrumb': 21720,
#          'lime': 21419,
#          'feta cheese': 21330,
#          'sweetened milk': 21125,
#          'lettuce': 20979,
#          'pork': 20936,
#          'maple syrup': 20910,
#          'avocado': 20685,
#          'wine vinegar': 20419,
#          'celery rib': 20146,
#          'turkey': 19914,
#          'dark': 19757,
#          'cottage cheese': 19638,
#          'vanilla pudding': 19522,
#          'semisweet chocolate chip': 19470,
#          'chocolate': 19414,
#          'black bean': 19185,
#          'cherry tomato': 19026,
#          'active': 18919,
#          'cream tartar': 18760,
#          'skim milk': 18607,
#          'selfrising': 18516,
#          'raspberry': 18436,
#          'celery seed': 18254,
#          'cornmeal': 18057,
#          'pure vanilla': 17953,
#          'banana': 17943,
#          'rice vinegar': 17942,
#          'jalapeno pepper': 17832,
#          'cayenne': 17778,
#          'apple': 17660,
#          'stalks celery': 17412,
#          'orange zest': 17355,
#          'ricotta cheese': 17326,
#          'chestnut': 17296,
#          'salad': 17195,
#          'dates': 17004,
#          'light corn syrup': 16977,
#          'yellow': 16848,
#          'hamburger': 16844,
#          'seasoning': 16831,
#          'coconut milk': 16633,
#          'sherry': 16550,
#          'italian seasoning': 16375,
#          'orange': 16331,
#          'caper': 16276,
#          'catsup': 16202,
#          'apple cider vinegar': 15865,
#          'fish': 15648,
#          'graham cracker crumb': 15586,
#          'eggplant': 15385,
#          'pine nut': 15325,
#          'velveeta cheese': 15269,
#          'horseradish': 14804,
#          'sweet onion': 14778,
#          'kidney bean': 14717,
#          'rolled oat': 14641,
#          'parsley flakes': 14413,
#          'cumin seed': 14390,
#          'unsweetened cocoa': 14361,
#          'apricot': 14314,
#          'tarragon': 14070,
#          'taco seasoning': 13942,
#          'dill weed': 13930,
#          'vegetable broth': 13869,
#          'kernel corn': 13845,
#          'crisco': 13782,
#          'egg yolk': 13745,
#          'juice': 13618,
#          'leek': 13590,
#          'cilantro leaves': 13589,
#          'unbleached': 13541,
#          'chicken thigh': 13487,
#          'broccoli floret': 13481,
#          'corn tortillas': 13466,
#          'mint leaves': 13396,
#          'thyme leaves': 13257,
#          'oatmeal': 13249,
#          'oat': 13127,
#          'bisquick': 13089,
#          'pasta': 12983,
#          'cauliflower': 12793,
#          'vanilla cream': 12727,
#          'chicken bouillon': 12607,
#          'barbecue': 12531,
#          'plum tomato': 12392,
#          'applesauce': 12375,
#          'coffee': 12311,
#          'peaches': 12305,
#          'crust': 12215,
#          'icing': 12175,
#          'mandarin oranges': 11921,
#          'lemon rind': 11907,
#          'cardamom': 11816,
#          'flaked coconut': 11724,
#          'mustard seed': 11645,
#          'asparagus': 11540,
#          'caster': 11497,
#          'cream celery': 11471,
#          'black peppercorn': 11416,
#          'pork chop': 11401,
#          'maraschino cherry': 11332,
#          'tuna': 11280,
#          'marjoram': 11247,
#          'sausage': 11220,
#          'lemon peel': 11216,
#          'gingerroot': 11173,
#          'leaf parsley': 11054,
#          'stewed tomato': 10932,
#          'semisweet chocolate': 10886,
#          'mango': 10869,
#          'red potato': 10852,
#          'beer': 10739,
#          'poppy seed': 10729,
#          'brandy': 10710,
#          'blue cheese': 10648,
#          'corn syrup': 10550,
#          'shell': 10518,
#          'whipped topping': 10494,
#          'american cheese': 10484,
#          'rum': 10440,
#          'parsley leaves': 10415,
#          'juice lemon': 10405,
#          'elbow macaroni': 10219,
#          'whipped cream': 10055,
#          'kosher black pepper': 10043,
#          'creamy peanut': 10022,
#          'graham cracker crust': 9826,
#          'cracked black pepper': 9702,
#          'flatleaf parsley': 9614,
#          'artichoke heart': 9570,
#          'vodka': 9559,
#          'golden raisin': 9549,
#          'graham cracker': 9497,
#          'tortilla chip': 9496,
#          'bean': 9486,
#          'fennel seed': 9420,
#          'garam masala': 9363,
#          'long grain rice': 9348,
#          'tofu': 9342,
#          'parmesan': 9332,
#          'beef bouillon': 9274,
#          'egg noodles': 9266,
#          'oyster': 9250,
#          'soft': 9093,
#          'halfandhalf': 9065,
#          'fruit': 9029,
#          'russet potato': 8997,
#          'salmon fillet': 8990,
#          'pumpkin spice': 8958,
#          'vegetable stock': 8923,
#          'eagle brand milk': 8860,
#          'pinto bean': 8776,
#          'button mushroom': 8721,
#          'splenda': 8706,
#          'cashew': 8702,
#          'unsweetened chocolate': 8518,
#          'chickpeas': 8454,
#          'pineapple chunk': 8431,
#          'spring onion': 8335,
#          'caraway seed': 8292,
#          'stalk celery': 8278,
#          'noodles': 8251,
#          'ripe olives': 8245,
#          'ginger ale': 8238,
#          'pear': 8130,
#          'half-and-half': 8064,
#          'italian parsley': 7986,
#          'macaroni': 7930,
#          'poultry seasoning': 7876,
#          'avocados': 7863,
#          'black beans rinsed': 7845,
#          'puree': 7835,
#          'oregano leaves': 7827,
#          'jalapeno': 7802,
#          'biscuit': 7791,
#          'hoisin': 7762,
#          'baby spinach': 7724,
#          'greek yogurt': 7691,
#          'yellow bell pepper': 7691,
#          'vegetable shortening': 7681,
#          'ripe bananas': 7656,
#          'yellow cornmeal': 7639,
#          'pimento': 7597,
#          'green olives': 7509,
#          'crescent roll': 7417,
#          'apple juice': 7414,
#          'quick oat': 7406,
#          'crabmeat': 7389,
#          'romaine lettuce': 7370,
#          'pizza': 7362,
#          'puff pastry': 7278,
#          'strawberry jello': 7251,
#          'rhubarb': 7247,
#          'hazelnut': 7218,
#          'bean sprout': 7218,
#          'chocolate pudding': 7158,
#          'sunflower seed': 7140,
#          'apple cider': 7121,
#          'half half': 7075,
#          'pumpkin puree': 7045,
#          'peppercorn': 7021,
#          'prosciutto': 7016,
#          'bittersweet chocolate': 7005,
#          'liquid smoke': 6945,
#          'roma tomato': 6918,
#          'lime zest': 6895,
#          'dark chocolate': 6878,
#          'oranges': 6856,
#          'goat cheese': 6795,
#          'pepperoni': 6757,
#          'topping': 6714,
#          'refried bean': 6690,
#          'mirin': 6661,
#          'chuck': 6640,
#          'cranberry juice': 6603,
#          'coriander seed': 6593,
#          'orange rind': 6592,
#          'smoked paprika': 6587,
#          'red': 6559,
#          'beef stock': 6546,
#          'celery stalk': 6542,
#          'roasted peanut': 6534,
#          'butternut squash': 6506,
#          'wheat germ': 6499,
#          'bourbon': 6487,
#          'yellow mustard': 6463,
#          'sake': 6455,
#          'lentil': 6427,
#          'sauerkraut': 6415,
#          'provolone cheese': 6411,
#          'orange peel': 6409,
#          'unsweetened applesauce': 6383,
#          'creamstyle corn': 6382,
#          'mixed vegetables': 6381,
#          'sharp cheese': 6374,
#          'limes': 6357,
#          'vanilla wafer': 6321,
#          'green peas': 6309,
#          'light soy': 6302,
#          'pork bean': 6302,
#          'purple onion': 6286,
#          'dark rum': 6263,
#          'beet': 6263,
#          'grape tomato': 6256,
#          'lasagna noodles': 6225,
#          'red kidney bean': 6200,
#          'scallop': 6175,
#          'miracle whip': 6158,
#          'pork tenderloin': 6152,
#          'romano cheese': 6145,
#          'pimentos': 6116,
#          'roasted red pepper': 6096,
#          'sweet red pepper': 6087,
#          'yellow squash': 6000,
#          'low-fat milk': 5974,
#          'yukon gold potato': 5911,
#          'lamb': 5879,
#          'couscous': 5878,
#          'ritz cracker': 5851,
#          'italian sausage': 5848,
#          'olives': 5822,
#          'syrup': 5809,
#          'linguine': 5781,
#          'blackberry': 5751,
#          'saffron': 5727,
#          'table': 5714,
#          'penne pasta': 5713,
#          'radishes': 5691,
#          'flax seed': 5685,
#          'lemon pepper': 5649,
#          'corn flakes': 5647,
#          'sherry wine': 5638,
#          'ranch dressing': 5607,
#          'currant': 5580,
#          'gruyere cheese': 5543,
#          'lettuce leaves': 5516,
#          'parsnip': 5495,
#          'meat': 5495,
#          'extra-virgin olive': 5494,
#          'quinoa': 5490,
#          'pesto': 5454,
#          'rice wine vinegar': 5450,
#          'basmati rice': 5418,
#          'plum': 5416,
#          'salmon': 5399,
#          'pretzel': 5380,
#          'vanilla bean': 5375,
#          'chicken wing': 5372,
#          'orange marmalade': 5334,
#          'creamed corn': 5329,
#          'corn starch': 5319,
#          'tomatoes juice': 5305,
#          'kalamata olives': 5275,
#          'green cabbage': 5223,
#          'shiitake mushroom': 5169,
#          'jalapenos': 5154,
#          'pistachios': 5140,
#          'granny smith apples': 5137,
#          'okra': 5128,
#          'the': 5125,
#          'mozzarella': 5121,
#          'rice krispy': 5102,
#          'cauliflower floret': 5099,
#          'red chili pepper': 5081,
#          'pure maple syrup': 5078,
#          'light cream': 5076,
#          'caramel': 5066,
#          'arugula': 5003,
#          'creme fraiche': 4988,
#          'red cabbage': 4980,
#          'hash brown': 4970,
#          'tahini': 4956,
#          'baby carrot': 4950,
#          'lemonade': 4912,
#          'chili bean': 4908,
#          'ripe tomato': 4907,
#          'chili pepper': 4903,
#          'lime wedges': 4900,
#          'onion flakes': 4900,
#          'garbanzo bean': 4876,
#          'sage leaves': 4873,
#          'cracker crumb': 4866,
#          'steak': 4832,
#          'arborio rice': 4822,
#          'red chili': 4817,
#          'orange juice concentrate': 4816,
#          'dressing': 4814,
#          'crouton': 4787,
#          'panko breadcrumb': 4766,
#          'vanilla yogurt': 4764,
#          'lemon jello': 4688,
#          'sweet paprika': 4686,
#          'lemon wedges': 4608,
#          'squash': 4583,
#          'pancetta': 4563,
#          'snow peas': 4559,
#          'pimiento': 4541,
#          'butterscotch chip': 4537,
#          'iceberg lettuce': 4536,
#          'italian dressing': 4504,
#          'kosher pepper': 4478,
#          'cajun seasoning': 4460,
#          'clam': 4457,
#          'round steak': 4434,
#          'peach': 4430,
#          'herb': 4401,
#          'anchovy fillet': 4351,
#          'turnip': 4343,
#          'light sour cream': 4343,
#          'ginger root': 4341,
#          'french bread': 4341,
#          'lima bean': 4329,
#          'tapioca': 4314,
#          'coriander leaves': 4298,
#          'wesson': 4296,
#          'hardcooked egg': 4283,
#          'green': 4280,
#          'light mayonnaise': 4278,
#          'fig': 4275,
#          'tea': 4244,
#          'kale': 4216,
#          'english cucumber': 4174,
#          'oreo cooky': 4174,
#          'longgrain rice': 4157,
#          'old fashioned oat': 4112,
#          'mace': 4102,
#          'pork sausage': 4063,
#          'vanilla flavoring': 4049,
#          'wild rice': 4043,
#          'anchovy': 4029,
#          'fennel bulb': 3990,
#          'chocolate syrup': 3990,
#          'espresso': 3969,
#          'cooled': 3963,
#          'mascarpone cheese': 3947,
#          'star anise': 3945,
#          'egg egg': 3943,
#          'baguette': 3941,
#          'vanilla essence': 3928,
#          'cheez whiz': 3922,
#          'sweet milk': 3912,
#          'soymilk': 3905,
#          'splenda granular': 3883,
#          'jalapeno chily': 3878,
#          'distilled vinegar': 3873,
#          'hash potato': 3863,
#          'mayo': 3856,
#          'basil leaf': 3850,
#          'cannellini bean': 3840,
#          'smoked sausage': 3826,
#          'spinach leaves': 3825,
#          'spanish onion': 3804,
#          'orange jello': 3803,
#          'corn meal': 3799,
#          'sundried tomato': 3776,
#          'baby spinach leaves': 3754,
#          'ghee': 3753,
#          'green chili pepper': 3743,
#          'crab meat': 3737,
#          'karo syrup': 3722,
#          'tomatoes green chily': 3714,
#          'cool whip whipped topping': 3714,
#          'broth': 3707,
#          'pineapple tidbit': 3698,
#          'lemongrass': 3680,
#          'lard': 3675,
#          'smoked salmon': 3675,
#          'turkey breast': 3672,
#          'marshmallow creme': 3669,
#          'salad dressing': 3666,
#          'green chiles': 3665,
#          'rosemary leaves': 3659,
#          'marshmallow cream': 3659,
#          'italian salad dressing': 3653,
#          'superfine': 3646,
#          'sweet': 3645,
#          'northern bean': 3632,
#          'sriracha': 3619,
#          'cremini mushroom': 3607,
#          'sweetened flaked coconut': 3604,
#          'pan': 3592,
#          'tart apples': 3589,
#          'brussels sprout': 3565,
#          'milk chocolate chip': 3557,
#          'hamburger bun': 3549,
#          'tequila': 3548,
#          'angel': 3531,
#          'old bay seasoning': 3489,
#          'sherry vinegar': 3471,
#          'pecans walnut': 3469,
#          'fettuccine': 3428,
#          'marinara': 3427,
#          'partskim mozzarella cheese': 3394,
#          'potato chip': 3381,
#          'taco': 3376,
#          'apples cored': 3374,
#          'enchilada': 3360,
#          'kahlua': 3345,
#          'mild cheddar cheese': 3345,
#          'cheddar': 3345,
#          'flank steak': 3341,
#          'parmigianoreggiano cheese': 3318,
#          'corned beef': 3312,
#          'dark corn syrup': 3302,
#          'wheat pastry': 3301,
#          'feta': 3294,
#          'sunflower': 3288,
#          'frosting': 3267,
#          'walnuts pecan': 3233,
#          'bacon fried': 3229,
#          'zest lemon': 3227,
#          'soft bread crumb': 3226,
#          'sweetened coconut': 3201,
#          'orzo pasta': 3193,
#          'angel hair pasta': 3192,
#          'cracked pepper': 3188,
#          'lipton onion': 3184,
#          'prunes': 3182,
#          'asparagus spear': 3177,
#          'self raising': 3166,
#          'unsweetened coconut': 3162,
#          'mexican cheese': 3158,
#          'asiago cheese': 3153,
#          'barley': 3148,
#          'light cream cheese': 3146,
#          'german chocolate': 3140,
#          'vermouth': 3130,
#          'lime jello': 3121,
#          'vidalia onion': 3117,
#          'glaze': 3115,
#          'wonton wrapper': 3103,
#          'miso': 3102,
#          'olive drizzling': 3097,
#          'dark soy': 3096,
#          'teriyaki': 3066,
#          'quickcooking oat': 3060,
#          'kalamata olive': 3059,
#          'cracker': 3052,
#          'green beans trimmed': 3040,
#          'lemon, zest': 3034,
#          'pimientos': 3027,
#          'vegetables': 3026,
#          'long-grain rice': 3024,
#          'lime, juice': 3016,
#          'pistachio pudding': 3015,
#          'watercress': 3010,
#          'dark sesame': 3000,
#          'beef stew meat': 2999,
#          'stuffing': 2987,
#          'onion ring': 2975,
#          'coffee granules': 2965,
#          'picante': 2961,
#          'chow mein noodles': 2961,
#          'wheat bread': 2955,
#          'green tomato': 2950,
#          'red chily': 2933,
#          'macadamia nut': 2932,
#          'phyllo': 2917,
#          'hamburger meat': 2903,
#          'monterey jack pepper cheese': 2895,
#          'unsweetened coconut milk': 2892,
#          'grand marnier': 2892,
#          'cardamom pod': 2857,
#          'granny smith apple': 2850,
#          'spicy mustard': 2845,
#          'yellow pepper': 2833,
#          'chickpeas rinsed': 2831,
#          'peppermint': 2820,
#          'baked shell': 2820,
#          'bacon dripping': 2818,
#          'berry': 2812,
#          'chunky salsa': 2811,
#          'pearl barley': 2808,
#          'cognac': 2798,
#          'pork loin': 2797,
#          'amaretto': 2784,
#          'curd cottage cheese': 2780,
#          'kidney beans rinsed': 2758,
#          'navy bean': 2747,
#          'portabella mushroom': 2744,
#          'halfandhalf cream': 2734,
#          'ribs celery': 2703,
#          'grain mustard': 2700,
#          'fish fillet': 2686,
#          'pork shoulder': 2670,
#          'rice noodles': 2669,
#          'curry leaves': 2668,
#          'fennel': 2667,
#          'chunky peanut': 2664,
#          'xanthan gum': 2663,
#          'sun-dried': 2654,
#          'saffron thread': 2648,
#          'napa cabbage': 2646,
#          'fontina cheese': 2644,
#          'saltine cracker': 2638,
#          'whip': 2622,
#          'cream whipped': 2619,
#          'stock': 2618,
#          'sun-dried tomato': 2614,
#          'sweet pickle relish': 2612,
#          'chicken bouillon granules': 2607,
#          'semi-sweet chocolate chip': 2606,
#          'half-and-half cream': 2602,
#          'bamboo shoot': 2601,
#          'clam juice': 2601,
#          'self rising': 2596,
#          'watermelon': 2590,
#          'mussel': 2579,
#          'roasting chicken': 2572,
#          'creole seasoning': 2570,
#          'green chili': 2544,
#          'sour milk': 2541,
#          'pecorino romano cheese': 2539,
#          'parmigiano-reggiano cheese': 2526,
#          'low-fat yogurt': 2519,
#          'ripe banana': 2518,
#          'chorizo sausage': 2512,
#          'pumpkin seed': 2497,
#          'wasabi': 2484,
#          'agave nectar': 2476,
#          'dog': 2474,
#          'celery leaves': 2472,
#          'cilantro leaf': 2467,
#          'juice lime': 2459,
#          'chili flakes': 2458,
#          'lemon pudding': 2445,
#          'pet milk': 2439,
#          'gravy': 2420,
#          'velveeta': 2392,
#          'polenta': 2387,
#          'deli ham': 2382,
#          'light coconut milk': 2378,
#          'land lakes': 2378,
#          'marinade': 2374,
#          'pastry': 2374,
#          'lemon juice lemon': 2374,
#          'smooth peanut': 2368,
#          'heavy cream whipped': 2367,
#          'strong coffee': 2366,
#          'rice wine': 2358,
#          'marsala wine': 2358,
#          'artichokes': 2355,
#          'english muffin': 2354,
#          'cantaloupe': 2349,
#          'ripe avocado': 2346,
#          'asparagus trimmed': 2346,
#          'gorgonzola': 2344,
#          'candied cherry': 2344,
#          'italian breadcrumb': 2343,
#          'red lentil': 2338,
#          'tarragon leaves': 2334,
#          'roll': 2323,
#          'potato starch': 2322,
#          'berry cranberry': 2308,
#          'light rum': 2307,
#          'chile': 2301,
#          'alfredo': 2300,
#          'lemonade concentrate': 2284,
#          'milk chocolate': 2283,
#          'seedless raisin': 2282,
#          'semisweet chocolate morsel': 2261,
#          'turbinado': 2247,
#          'grapeseed': 2245,
#          'semolina': 2240,
#          'chipotle chiles adobo': 2236,
#          'guacamole': 2228,
#          'smoked ham': 2227,
#          'pita bread': 2226,
#          'sherry wine vinegar': 2225,
#          'beef brisket': 2211,
#          'zesty italian dressing': 2209,
#          'ricotta': 2208,
#          'dill pickles': 2206,
#          'apricot jam': 2206,
#          'tortilla': 2198,
#          'chily': 2193,
#          'baby arugula': 2192,
#          'acorn squash': 2189,
#          'tamari': 2178,
#          'bakers semisweet chocolate': 2178,
#          'penne': 2173,
#          'chicken leg': 2170,
#          'golden syrup': 2169,
#          'cornflakes': 2169,
#          'marinated artichoke heart': 2169,
#          'sirloin': 2167,
#          'dill pickle': 2166,
#          'chicken drumstick': 2165,
#          'coconut cream': 2160,
#          'eggs egg': 2160,
#          'grapes': 2153,
#          'gin': 2150,
#          'salami': 2148,
#          'bulk pork sausage': 2145,
#          'beef chuck': 2141,
#          'golden': 2139,
#          'kielbasa': 2128,
#          'chipotle chile adobo': 2126,
#          'light olive': 2121,
#          'jicama': 2119,
#          'sweet corn': 2107,
#          'mint leaf': 2106,
#          'loaf french bread': 2106,
#          'unsweetened pineapple juice': 2103,
#          'tumeric': 2095,
#          'cashew nut': 2095,
#          'mushroom stem': 2093,
#          'cannellini beans rinsed': 2093,
#          'pork loin chop': 2090,
#          'olive vegetable': 2089,
#          'flatleaf parsley leaves': 2089,
#          'red chile': 2088,
#          'orange bell pepper': 2084,
#          'chuck roast': 2082,
#          'mayonnaise salad dressing': 2080,
#          'cherry jello': 2075,
#          'sirloin steak': 2068,
#          'anise seed': 2066,
#          'corn chip': 2061,
#          'bok choy': 2060,
#          'english peas': 2060,
#          'veal': 2056,
#          'lemon, juice': 2056,
#          'rotini pasta': 2054,
#          'ancho chile': 2053,
#          'red curry': 2043,
#          'cornbread': 2039,
#          'tater': 2039,
#          'ripe avocados': 2039,
#          'mayonaise': 2036,
#          'red capsicum': 2036,
#          'italian bread crumb': 2030,
#          'porcini mushroom': 2025,
#          'hominy': 2019,
#          'bouillon': 2019,
#          'bow tie pasta': 2019,
#          'pearl onion': 2018,
#          'kiwi fruit': 2016,
#          'arrowroot': 2009,
#          'seedless grapes': 1999,
#          'bicarbonate soda': 1986,
#          'port wine': 1986,
#          'palm': 1975,
#          'soya': 1970,
#          'yoghurt': 1969,
#          'pastry shell': 1963,
#          'blackeyed peas': 1957,
#          'lettuce leaf': 1956,
#          'grapefruit juice': 1942,
#          'loaf bread': 1939,
#          'crisco shortening': 1935,
#          'scant': 1935,
#          'mexican oregano': 1934,
#          'flavoring': 1933,
#          'french onion': 1931,
#          'silken tofu': 1930,
#          'scallions green': 1926,
#          'double cream': 1924,
#          'grit': 1915,
#          'dark molasses': 1914,
#          'wheat tortillas': 1898,
#          'sweet pepper': 1890,
#          'pasta shell': 1889,
#          'roma': 1889,
#          'mango chutney': 1884,
#          'savory': 1878,
#          'beef bouillon granules': 1875,
#          'beef consomme': 1858,
#          'almond milk': 1857,
#          'frenchstyle green bean': 1853,
#          'tilapia fillet': 1849,
#          'raspberry jello': 1849,
#          'beef roast': 1845,
#          'herb stuffing': 1845,
#          'panko bread crumb': 1837,
#          'jasmine rice': 1836,
#          'season': 1834,
#          'chicken stock broth': 1834,
#          'mixed salad green': 1831,
#          'sweet basil': 1825,
#          'chicken turkey': 1825,
#          'quick oatmeal': 1822,
#          'poblano pepper': 1820,
#          'rose': 1816,
#          'snap peas': 1812,
#          'reducedfat sour cream': 1808,
#          'meatball': 1806,
#          'jumbo shrimp': 1799,
#          'coconut flakes': 1795,
#          'apple cored': 1795,
#          'round': 1779,
#          'tomatillos': 1777,
#          'chicken liver': 1775,
#          'leg lamb': 1772,
#          'sweet chili': 1771,
#          'pudding': 1759,
#          'beef browned': 1753,
#          'grenadine': 1748,
#          'kiwi': 1741,
#          'pomegranate seed': 1741,
#          'pickling': 1741,
#          'radish': 1740,
#          'chia seed': 1738,
#          'shell pasta': 1736,
#          'mascarpone': 1734,
#          'black sesame seed': 1729,
#          'pomegranate juice': 1725,
#          'popped popcorn': 1723,
#          'edamame': 1713,
#          'baked bean': 1706,
#          'tarragon vinegar': 1705,
#          'mixed spice': 1702,
#          'flat-leaf parsley': 1699,
#          'french vanilla pudding': 1699,
#          'stew meat': 1698,
#          'chinese five spice': 1693,
#          'pizza crust': 1692,
#          'cream coconut': 1692,
#          'grnd beef': 1690,
#          'sundried': 1687,
#          'sourdough bread': 1687,
#          'almond flavoring': 1686,
#          'peanut chip': 1680,
#          'rye': 1679,
#          'sharp cheddar': 1679,
#          'tomatoes wedges': 1679,
#          'adobo': 1675,
#          'stevia': 1674,
#          'bacon grease': 1674,
#          'katakuriko': 1674,
#          'onion wedges': 1673,
#          '° °': 1672,
#          'andouille sausage': 1670,
#          'kaffir lime leaves': 1670,
#          'champagne vinegar': 1666,
#          'deep': 1662,
#          'champagne': 1661,
#          'coleslaw': 1658,
#          'jack cheese': 1657,
#          'tamari soy': 1655,
#          'basil pesto': 1649,
#          'prawn': 1647,
#          'butterscotch pudding': 1645,
#          'tuna steak': 1644,
#          'yellow corn meal': 1643,
#          'caramel cream topping': 1643,
#          'black-eyed peas': 1641,
#          'lime rind': 1636,
#          'cream potato': 1635,
#          'papaya': 1632,
#          'real': 1631,
#          'devil': 1628,
#          'oat bran': 1626,
#          'habanero pepper': 1624,
#          'tamarind': 1622,
#          'colby cheese': 1621,
#          'catfish fillet': 1618,
#          'red bean': 1616,
#          'vanilla bean split': 1615,
#          'scallions spring green onion': 1611,
#          'phyllo pastry': 1610,
#          'dark chocolate chip': 1608,
#          'herbes provence': 1603,
#          'raspberry jam': 1599,
#          'apricot nectar': 1595,
#          'beef turkey': 1592,
#          'jello': 1588,
#          'serrano pepper': 1586,
#          'black mustard seed': 1584,
#          'smoked bacon': 1584,
#          'dill seed': 1582,
#          'french fried onion': 1581,
#          'swiss chard': 1579,
#          'onion onion': 1579,
#          'allspice berry': 1577,
#          'italian bread': 1576,
#          'eagle brand sweetened milk': 1563,
#          'olive brushing': 1562,
#          'angel flake coconut': 1561,
#          'pork loin roast': 1560,
#          'idaho potato': 1558,
#          'karo': 1555,
#          'lemon flavoring': 1555,
#          'canadian bacon': 1554,
#          'olive flavored': 1552,
#          'chipotle pepper': 1552,
#          'rigatoni pasta': 1547,
#          'msg': 1546,
#          'dijonstyle mustard': 1545,
#          'breakstones knudsen sour cream': 1545,
#          'chipotle': 1542,
#          'creme cacao': 1541,
#          'degrees': 1541,
#          'capers rinsed': 1538,
#          'cool': 1537,
#          'golden mushroom': 1536,
#          'tuna flaked': 1535,
#          'pineapple chunks juice': 1534,
#          'flax seed meal': 1533,
#          'parmigianoreggiano': 1533,
#          'vegall': 1532,
#          'lawry': 1530,
#          'yam': 1524,
#          'basil basil': 1522,
#          'grapefruit': 1521,
#          'broccoli floweret': 1518,
#          'candied pineapple': 1515,
#          'potatoes chunk': 1515,
#          'selfraising': 1515,
#          'whiskey': 1514,
#          'corn kernel': 1512,
#          'pistachio nut': 1506,
#          'beef tenderloin': 1505,
#          'spice': 1505,
#          'ranch style bean': 1502,
#          'vegetable olive': 1501,
#          'skewer': 1499,
#          'beef chuck roast': 1498,
#          ...})

# %%
num_to_drop = 1500
filtered_counter = {item for item, count in counters.items() if count <= num_to_drop}
filtered_counter
# Out:
# {'penne rigatoni pasta al dente',
#  'syrian rice',
#  'spices dill',
#  'easy melt cheese',
#  'start half the it sweet',
#  'bonito flakes preflaked katsuobushi',
#  'flesh fish snapper dorado grouper',
#  'icing sugarwater',
#  'eastern black walnut',
#  'chicken stock suggest crock chicken stock',
#  'ripe pears bartlett anjou half',
#  'duncan hines devils pan',
#  'cornish hens chicken skin',
#  'cherry red raspberry',
#  'periperi rub',
#  'assorted vegetable dipper',
#  'texture bread',
#  'corn liquid removed corn',
#  'bacon grease canola ham dripping',
#  'tangerine clementines belly',
#  'bell peppers eighth',
#  'bread crumbs eggs dipping',
#  'cream style cream cheese strawberry',
#  'japaneseeggplant',
#  'penzeys fennel seed',
#  'asian guacamole',
#  'pasta frolla short crust pastry',
#  'chicken broth listed stuffing liquid',
#  'comice bartlett pears cored eighth',
#  'berries husband prefers blueberry',
#  'chicken eg drumstick thighs chicken fillet',
#  'shrimp heads red',
#  'cloves pernil',
#  'dates apricots fruit',
#  'good saffron milk heavy cream',
#  'shiro miso',
#  'blue oyster mushrooms trimmed untrimmed',
#  'mesquite fajita',
#  'top milk cream half half',
#  'guava bbq',
#  'chicken drumlettes',
#  'spicy green serrano chili peppers red peppers chili',
#  'reeses peanut',
#  'pekin long island duck',
#  'circus animal cooky',
#  'bibb lettuce rinsed spun',
#  'black forest ham xinch',
#  'bacon microwaveready bacon',
#  'juice meat',
#  'commercial ranchstyle dressing',
#  'chickpeas rinsed skins removed skip this step it helps the hummus creamy',
#  'scoop whey',
#  'cherries standard black cherry',
#  'game hens refrigerator',
#  'shrimp tails easy eating',
#  'ham honey ham delicious',
#  'corncut cob',
#  'unsweetened blueberries juice',
#  'vegetables broccoli florets peas andor green bean',
#  'kale prepackaged kale mine trader joes california',
#  'anchovy fillets coarsley',
#  'soft shortening eg crisco',
#  'pasta tri color rotini',
#  'pasta except spaghetti linguine',
#  'blackening season',
#  'broccoli cauliflower carrots mixed',
#  'redandwhite striped peppermint candies candy canes',
#  'spaghetti store',
#  'beef round tenderloin',
#  'vegetable flavored bouillon granules',
#  'reams noodles recipe pasta',
#  'black olives seed',
#  'leaves romaine bibb lettuce',
#  'the thyme beef gravy',
#  'cumin seed pan roasted',
#  'red chili pepper thai bird chile',
#  'onion recommend wallawalla vidalia sweet onion',
#  'shortcrust pastry pastry case',
#  'hibiscus flowers hibiscus flower skewered pick',
#  'recipe perfect crust',
#  'cream cheese patty shell',
#  'rice prior rice needs completely cool',
#  'ribeye beef korean stores sell right',
#  'mild chilis ristra variety',
#  'chicken legthigh combination',
#  'cream half half mock',
#  'red apple gala fuji',
#  'red plums nectarines',
#  'snow peas trimmed removed',
#  'cutup ham chicken',
#  'mayonnaise helmans preferred',
#  'heavy cream table cream table cream thinner',
#  'oatmeal quick cook style',
#  'hummus sabra prefered',
#  'red potatoes left half',
#  'bonein skinon chicken breasts split half thighs leg',
#  'penne elbow macaroni twist pasta',
#  'green vidalia onion',
#  'grain puff',
#  'savoryspicy item enjoy',
#  'nashi pears cored thinely',
#  'cocoa omit vanilla',
#  'heirloom beans mixed variety',
#  'challah bread crust removed',
#  'baked mac cheese',
#  'sweet onion spanish vidalia',
#  'fish bones tail backbone',
#  'pineapple apple',
#  'onions red essential fairly',
#  'marmalade orange cherry apricot',
#  'chicken legandthigh bonein chicken breast mixture',
#  'worcestershire guesstimate',
#  'green coriander hara dhaniya',
#  'ciabatta loaves half',
#  'stalks rosemary only leaves',
#  'croutons eggplant',
#  'shrimp cool',
#  'coconut rum bacardi',
#  'ghee coconut pan',
#  'pan brushing',
#  'spicy italian chicken sausage spicy sausage youre the casings crumble cook it',
#  'honey lapiculteur miel fleurs france',
#  'oregano bud',
#  'kielbasa sausage smoked sausage',
#  'chicken poaching liquid recipe follows chicken stock',
#  'but still',
#  'aduki adzuki beans lowsalt adzuki beans rinsed',
#  'filets striped bass',
#  'red currant jelly lion',
#  'set kosher',
#  'scattered caraway seed',
#  'macaroni cheese mac cheese deluxe cheese mac cheese',
#  'sprays wishboner salad spritzersr ranch dressing',
#  'valley salad dressing original',
#  'icepop molds icepop',
#  'bushes baked beans flavor',
#  'orchard apple cored',
#  'cracker flavor',
#  'bittersweet semisweet chocolate chunks chocolate chip',
#  'roasted beet wedges',
#  'green purple lettuce',
#  'ancho chiles dryroasted',
#  'eggs worth egg yolk eggwash',
#  'shiitake mushrooms many sliver',
#  'mildflavoured vegetable deepfrying',
#  'coriander serve cilantro',
#  'brandied cranberry recipe follow',
#  'final risotto al forno',
#  'pine nuts pistachio nut',
#  'rainbow swiss chard leaves stripped ribs torn ribs stem',
#  'cherries maraschino red',
#  'bourbon sherry madeira chicken broth',
#  'beet stem',
#  'mincedground beef',
#  'olive the roasted',
#  'bamboo skewers long toothpick',
#  'beef flank skirt steak',
#  'jalapeno seeds removed spicy',
#  'tart apples peel core',
#  'potatoe buds brand potato',
#  'portabella mushrooms stems normally throw away',
#  'chicken base granulespowder',
#  'scallions baton',
#  'grapefruit zest removed vegetable peeler',
#  'walnuts honey honey',
#  'potatoes scrubbedpierce places fork',
#  'chilie bell peppers padi chily',
#  '°f pan line pan parchment waxed paper parchment double boiler melt unsweetened chocolate stir chocolate mixture vanilla eggs stirring blended cocoa beat incorporated mixture smooth scrape batter pan bake toothpick inserted middle comes moist crumbs clinging min now let chocolate baked brownie cool',
#  'silken tofu blended',
#  'chicken pc drumsticks pc bonein thighs breast leg',
#  'chicken bouillon beef',
#  'nabisco cracker crumb',
#  'cloves left paper towel air day',
#  'mango banana juice',
#  'inchdiameter logs mild goat cheese herbed',
#  'fancy pasta',
#  'skewers inchcm long toothpick',
#  'alino complete',
#  'manly boyfood flavorful option',
#  'tomatoes heirlooms otherwise plum',
#  'olive browning',
#  'gound meat',
#  'flax seed meal butterfree flax meal',
#  'bucatini pasta casserole elbow cavatappi',
#  'turkey breast butcher',
#  'melt dipping',
#  'nutmeg the aged cheddar fritter',
#  'old baguette ciabatta loaf',
#  'jumbo shrimp butterflied almost way',
#  'cinnamon baked flatbread crisp',
#  'tomatoes removed',
#  'butifarra sausages',
#  'green pepper onion black olive mixture',
#  'twelve tuscan peasant bread',
#  'fructose natural first measure',
#  'heinz special',
#  'half knox unflavoured',
#  'almond nut meat',
#  'peppers piquillo',
#  'juice oranges wedges',
#  'baked chocolate cupcakes paper liners removed',
#  'liquid coffee creamer flavor',
#  'assorted vegetable chunks zucchini red green peppers onions celery cherry tomato',
#  'portabella mushrooms removed',
#  'salad light cream',
#  'chicken stock good stock',
#  'grease the bowl',
#  'heads manoa lettuce',
#  'tortillas triangles',
#  'raisins sultana nut',
#  'tin kidney bean',
#  'cured smoked speck ham',
#  'meatball pan dripping meatball recipe posted separately',
#  'rose flavoring',
#  'cabbage almost tender',
#  'lamb brain',
#  'lobster meat quantity',
#  'burritos taco seasoning',
#  'marsala wine grape juice chicken broth',
#  'oscar mayer chicken',
#  'poppy seed milk',
#  'soft creamy double chocolate frosting recipe follow',
#  'onion flakes may',
#  'plastic oyster cracker',
#  'rolling forming tortelli',
#  'premier morsel',
#  'calf',
#  'thyme oregano tarragon basil',
#  'heath skoar candy bar',
#  'ripe plums stoned wedges',
#  'preferred meat pork',
#  'vanilla pudding cook serve do pudding',
#  'hollands gin strongly juniperscented',
#  'short ribs trimmed tied butcher',
#  'flake cereal',
#  'milk coconut milk work',
#  'mushroom caviar',
#  'duck plums star anis red wine soy ginger walnut',
#  'alfredo could',
#  'lime koolaid ring',
#  'the crepes',
#  'tomatoes liquid tomatoes season',
#  'handfuls scallion',
#  'frosting tan',
#  'glaze optionalbeaten egg milk',
#  'betty crocker fudge frosting',
#  'assorted vegetables bell peppers broccoli carrots cauliflower cherry tomatoes cucumbers scallion',
#  'eclairs chocolate',
#  'omasum bible tripe',
#  'semisweet chocolate chips top',
#  'sage sausage loose',
#  'pastry wheat chapati',
#  'olive blended vegetable',
#  'basil leaves pinches oregano',
#  'romano cheese combo parmesan cheese combo',
#  'vanilla maple syrup included original recipe',
#  'readytouse crust recipe',
#  'slab bacon smoked ham hock',
#  'cheese swiss cheddar fontina',
#  'tomatoes real ripe',
#  'pickle spice allspice',
#  'chow mein noodles salad',
#  'russet potato bigger',
#  'eggs largeslightly',
#  'greek yogurt unsweetened',
#  'hamburger bun sturdy',
#  'savorycrushed',
#  'neededabout shakes cinnamon',
#  'cremini mushroom tough trimmed',
#  'sundried tomatoes rehydrated soaking',
#  'diamond crystal kosher half volume table kosher table',
#  'flavored chips chocolate chips mintchocolate chips peanut chips choose',
#  'green onion file',
#  'sweet milk okay',
#  'walnuts hold outer covering',
#  'spinach leaves trimmed',
#  'vanilla streusel',
#  'bell pepper membrane removed green red',
#  'green chilies original',
#  'pesto basil leaves',
#  'reducedfat dogs coin',
#  'bulgur wheat semicooked',
#  'gorgonzola cheese la fourme dambert blue cheese',
#  'red pepper puree roasted',
#  'feta cheese gorganzola',
#  'trappeys jalapeno blackeyed peas',
#  'ginger knuckle',
#  'strawberries under ripe rinsed',
#  'jimmy dean sausage flavor',
#  'beef pork veal beef pork ok',
#  'lasagne noodle',
#  'chacheres creole seasoning',
#  'frosting creamy geltype',
#  'croutons tempeh',
#  'good quality pasta bow ties wagon wheel',
#  'measured correctly',
#  'sandwich bread brioche',
#  'bolillo rolls mexican oval sandwich rolls french bread roll',
#  'faro barley rinsed',
#  'double piecrust ina gartens perfect crust',
#  'lebanese cucumbers trimmed',
#  'manila clams cockles smaller',
#  'mushroom wild mushrooms combination cultivated mushrooms portobellas cremini oyster shi',
#  'rice-a-roni',
#  'plive',
#  'crackers bagel chip',
#  'bisquick r',
#  'flexible wire whisk',
#  'juicy ripe peaches wedges',
#  'light herb spreadable cheese',
#  'mm candy corn',
#  'brushing quail',
#  'grace fish tea comparable fish bouillon',
#  'bamboo decorative skewer',
#  'green birdseye chiles green thai chiles green serrano chiles mortar pestle',
#  'french baguettes trimmed crosswise',
#  'shreaded sharp cheddar cheese',
#  'snickerdoodle protein cinnamon flavor',
#  'burbot cod mackerel',
#  'lemon grass stalks removed',
#  'chili mild try chipotle ancho',
#  'linguica sausage chorizo',
#  'oranges seeds half',
#  'kosher spaghetti',
#  'russet potatoes peeledboiledand',
#  'long grain rice ive basmati jasmine rice',
#  'assorted mushrooms cremini shiitake portobello',
#  'lemonjuice',
#  'the swirl topping',
#  'green onion around',
#  'saltpeter original recipes',
#  'bulk spinach stems removed',
#  'poblano chile seeds ribs removed chile',
#  'shallow scallion',
#  'lentils beluga',
#  'vodka vanilla stoli sure vanilla vodka',
#  'jalapenos disk',
#  'black drum fillet',
#  'bok choy cabbage trimmed',
#  'thai red chili peppers seed',
#  'jelly beans candy',
#  'quality semisweet chocolate chip',
#  'whitefleshed fish bones trimming',
#  'beef bouillon granules preferred',
#  'env blackberry soft drink',
#  'herbs combo chives parsley tarragon',
#  'apple quince jelly apricot jam orange marmalade',
#  'butterscotch jello pudding',
#  'breakfast steaks sirloin tip steak',
#  'cotija cheese known queso anejado feta',
#  'smallish thyme leaves',
#  'halfpint canning lids rings sterilized',
#  'ripe apricots segment',
#  'soft mild goat cheese log',
#  'puffed wheat cereal grain rice',
#  'green top',
#  'port sweet portuguese wine',
#  'leeks technique cleaning leeks p',
#  'heirloom smallmed',
#  'following jerk',
#  'blood orange juice italian blood orange soda',
#  'bbq pork castleberry',
#  'vanilla yogurt yogurt work',
#  'sunflower seeds many',
#  'range eggs whisked',
#  'celery leaves trimmed tough outer fibers removed vegetable peeler',
#  'smegma juice',
#  'cherry strawberry koolaid',
#  'englishstyle bitter orange marmalade',
#  'guava quince membrillo',
#  'glutenfree oats certified',
#  'crisco substitutes',
#  'onion italian seasoning seasoning',
#  'chicken patties crumbed',
#  'extrafirm waterpacked tofu rinsed',
#  'rice wholegrain flakes',
#  'wine wine okay',
#  'depends turkey',
#  'paiche black cod',
#  'pork ham hocks hog jowl',
#  'beef top sirloin grilling steak crosswise',
#  'lemon juice cider vinegar',
#  'tablesppon thyme',
#  'handfuls okra freezer stems removed',
#  'scoop caramel vanilla cream',
#  'spaghetti recipe premade',
#  'crust yellow cornmeal confect lemon rind',
#  'ginger root peel scrub',
#  'tomatoes red onion cucumber lettuce leaves dill pickle pickled peppers topping',
#  'spicy mixed smoked sausage',
#  'bread grain crumbed',
#  'satsuma mandarins tangerines',
#  'mild chili beans chili',
#  'vegeta bouillon granules',
#  'green belle pepper',
#  'parmesan cheese soy',
#  'fillets alaskan king salmon skin',
#  'noodles directed',
#  'peanutes',
#  'gluten-free pretzel',
#  'peppermint flavor simply brand',
#  'chorizo sausage spanish sausage sausage',
#  'peaches candrained peaches',
#  'pork chops tenderized',
#  'dashworcestershire',
#  'macaroni elbow bow ties spiral',
#  'apple schnapps pucker sour apple',
#  'athensr fillo shell',
#  'chicken cutlet filet',
#  'thai purple basil leaves chiffonade',
#  'amaretto fill coke',
#  'finequality bittersweet chocolate shavings vegetable peeler unsweetened cocoa',
#  'nixtamal hominy',
#  'chocolate creme liqueur apple brandy creme cacao orange liqueur amaretto',
#  'chevre cheese herbs spread',
#  'tilapia fillets sole fillet',
#  'six chicken stock',
#  'sugarfree chocolateflavored snack sweetn',
#  'brickle heath brickle',
#  'knorr vegetable swiss',
#  'paprika sweet hotto',
#  'edible glitter green pink purple crystal green pink purple',
#  'bananas vaguely',
#  'pure chile red pepper flakes pepper flakes hotter',
#  'vegit seasoning',
#  'onion mounded',
#  'pepperoni jam',
#  'cream milk maybe',
#  'escarole romaine',
#  'simply organicr nutmeg',
#  'wine marinating',
#  'edible easter grass',
#  'phyllo pastry calls cant remember sizes',
#  'tomatoes juliennes',
#  'plastic screw cap',
#  'sour cream guacamole salsa verde',
#  'fennel bulb stems fronds removed tough root end bulb',
#  'coriander stems removed',
#  'winter squash butternut hubbard',
#  'cherries sweet light syrup',
#  'mixed vegetables brussels sprouts cauliflower carrot',
#  'shrimp prawns lobster',
#  'cheese yellow cheddar',
#  'oilfree popped popcorn smartpop',
#  'chicken gizzards boil tender reserve stock',
#  'fluid thai chinese sweet chili',
#  'egg noodles al dente',
#  'leeks part rings thoroughly',
#  'tartsweet apples jonathan gala cameo',
#  'ripe avocado pear',
#  'budging ham lunch meat',
#  'raos',
#  'medley macaroni',
#  'leaves greenleaf romaine lettuce',
#  'bread inchthickcrust ontorn chunks french italian',
#  'panela syrup',
#  'bread grain texture',
#  'mandarin orange vanilla lemon yogurt',
#  'part black pepper',
#  'shrimp tuna crab whitefish may instead addtion shrimp',
#  'italian loaf parsley',
#  'miso blended miso miso',
#  'sage powdergm',
#  'peaches peeledhalved',
#  'onion till tender',
#  'betty crocker spread coconut pecan frosting',
#  'unsweetend raspberry juice',
#  'recipe martha cornbread',
#  'skinon salmon fillets rinsed manageable avoid tailsection',
#  'lemon linme juice',
#  'basil ribboned',
#  'garnishes basil',
#  'crusty hamburger buns roll',
#  'tomatoes seeds left',
#  'option decoration chocolate colon',
#  'unsweetened coconut middle eastern stores',
#  'parmesan cheese carrot peeler',
#  'carbonated mineral lime flavored preferred',
#  'okra ladyfinger bhindi',
#  'servings garden salad lettuce spinach leaves tomatoes onions bell pepper olives',
#  'phillips claw crabmeat',
#  'mosto recipe maple syrup balsamic vinegar',
#  'sweet potatoes should be',
#  'wellchilled champagne sparkling cider',
#  'vanilla could',
#  'green candy wafer',
#  'envelopes buttermilk salad dressing',
#  'coriander leaves lemon wedges',
#  'citrus wedges mint andor cucumber ribbon',
#  'cheese ragu brand',
#  'asianstyle cilantro pesto',
#  'oldfashioned frosting',
#  'decorator sugars andor candy',
#  'various sprinkles look pretty',
#  'cheese tex mex good',
#  'mushrooms portabello trimmed',
#  'honey mustard dijon',
#  'razz cherry glaze serve recipe follow',
#  'thyme torn',
#  'beets pickled quail egg',
#  'soft pretzels pretzel roll',
#  'wine yellow tail',
#  'soysunflower lecithin',
#  'green onions matchstick',
#  'thai bird chiles serrano chily',
#  'nutmeg cinnamon works too',
#  'cherry tomatoes red yellow possible third',
#  'liquid apricots pineapple',
#  'wheat tortillas ten',
#  'apples cored apples gives flavor',
#  'libby pumpkin brands consistency',
#  'rhubarb stalk rhubarb',
#  'nugget pasta',
#  'ore ida tater meat amply',
#  'candied cherries candied pineapple citron raisin',
#  'top stuffing portion',
#  'spreadable goat cheese',
#  'quantity especially salami chourizo already lot',
#  'cured spanish chorizo fried',
#  'olive tuscan',
#  'smallleaf cilantro',
#  'spiced zucchini chutney',
#  'grey works perfect',
#  'french vanilla flavored coffee creamer liquid',
#  'chayote half matchstick',
#  'peanut cream recipe follow',
#  'plum tomatoes vertically',
#  'cream cheese neufatchel',
#  'sweet potato wild rice pilaf',
#  'ricottacottage cheese',
#  'lemon cucumber peel',
#  'tomatoes tender sun',
#  'chinese chow mein vegetables',
#  'chilling',
#  'flavored breakcrumb',
#  'loaf challah chunk',
#  'recipe creamy macaroni cheese',
#  'lbstew meat',
#  'filet beef trimmed prime',
#  'molasses syrup light',
#  'smoked salmon pulled chunk',
#  'basil leaves ripped',
#  'walnuts nut preferred pumpkin seeds sprinkled muffin',
#  'meat fish making fish ball',
#  'pasta fusilli spaghetti',
#  'skinon wild salmon',
#  'chilies spice tolerance',
#  'marinated mozarella braided coursely',
#  'skim milk says milk milk says milk',
#  'loaf focaccia bread',
#  'chipotle chililime',
#  'rolled oats irish style preferred',
#  'littleneck clams purged',
#  'bagged preshredded coleslaw green cabbage',
#  'lonza italian cured pork loin montasio cheese local gourmet shop',
#  'provolone cheese italian cheese',
#  'valley ranch dressing tbsp',
#  'italian parsley choppedtorn',
#  'thyme french',
#  'tamari soy ok',
#  'polenta pancakes',
#  'masa brand',
#  'bananas extremely ripe',
#  'raspberrychipotle',
#  'ramen noodles sun noodle brand isle',
#  'green chiles mild',
#  'red bean curd fermented nam yui cantonese',
#  'galliano liqueur vanilla based',
#  'swiss cheese gruyre emmental',
#  'soda crackers aka saltine cracker',
#  'spinach torn apart stems removed',
#  'tomatillo salsa roasted recipe follow',
#  'onion spring onion reserve green',
#  'extramoist sundried',
#  'semisweet chocolate reserve',
#  'betty crocker super moist chocolate goes theme something moist layer',
#  'pinto pink beans rinsed',
#  'assorted vegetables cutup peas red bell pepper zucchini andor asparagus',
#  'sweet rice aka glutenous rice',
#  'red chiles thai cayenne chile arbol',
#  'stewed tomatoes potato masher leaving larger',
#  'real maple mapleflavored syrup',
#  'prosciutto daniele baton',
#  'veal rib',
#  'italian sweet chicken turkey pork sausage bulk',
#  'boursin brand herb spreadable cheese',
#  'pineapple coconut rice',
#  'green giant teriyaki stir meal starter',
#  'chana dal split desi beans indian grocery',
#  'mayonnaise yogurt possibility although havent tried salad dressing yogurt possibility although havent tried',
#  'readymade curry roux spicy',
#  'saltfree seasoning original',
#  'red chiles mine indian grocery arbol chiles',
#  'peanut kiss',
#  'finechopped lemon zest',
#  'ale rogue hazelnut ale',
#  'swissstyle coffee drink tested international coffees suisse mocha',
#  'red wine such merlot',
#  'fruit what trifle',
#  'pear horseradish mustard final assembly',
#  'crabapples cored',
#  'eggs patties already rectangles cts baked egg patties easy',
#  'wednesday may',
#  'greens torn spinach kale collard green',
#  'strawberry cream pineapple sherbet',
#  'sharp cheddar cheese reserve',
#  'loose assorted herbs tough stems removed chivesbasiloreganotarragon',
#  'assam tamarind',
#  'salsa ranch dressing portsmans brand',
#  'lemon wedges omitted',
#  'apples cutup rhubarb',
#  'dressing looser',
#  'leaf bay laurel',
#  'chocolateflavored sundae syrup',
#  'stalk celery celery',
#  'liquid cream olive liquid',
#  'fried blue corn tortilla',
#  'horseradish root root good quality root cuts blemishes',
#  'soda bicarbonate eno',
#  'bourbon spiced dark rum',
#  'starter sourdough starter recipe',
#  'shrimp andor thinsliced pork',
#  'chocolate fudge frosting',
#  'betty crocker super moist chocolate fudge',
#  'fish black porgy fish',
#  'maine long island potato',
#  'pretzels rolling',
#  'meat meatballs sam',
#  'skewers pierce breasts submerge hinder passion fire',
#  'rock shrimp shrimp pices',
#  'handfuls samphire',
#  'parmesan cheese p r cheese parmesanromano cheese p r cheese',
#  'vegan mozzarella',
#  'lowsalt soft goat cheese',
#  'dungeoness crab',
#  'penzeys sweet curry cumin coriander',
#  'bourbon rum gin',
#  'lactino kale',
#  'bananas over ripened',
#  'roasted bird',
#  'store bought pizza crust crust',
#  'red velvet mixwill half',
#  'plums quarted skins left methley plum',
#  'boysenberry sherbet lemon opt',
#  'flavoring lemon orange strawberry',
#  'mussels wellcleaned debearded discard open close tap shell feel extremely heavy',
#  'italian tomatoes marzano juice',
#  'oysters bluepoints portuguese',
#  'sweet potato puree baked',
#  'buttermilk cilantro dressing',
#  'smoked ham hocks smoked turkey wing',
#  'picnic pork shoulder chunk',
#  'gms paneer',
#  'limes juice fish',
#  'neutral canola safflower peanut',
#  'is anise seed',
#  'watercress cherry tomatoes opt',
#  'montrachet mild goat cheese',
#  'baby broccoli tip',
#  'vanilla beans madagascar bourbon split',
#  'mushroom caps inched stems removed saved',
#  'smoked chicken chunk',
#  'kirkland sweet mesquite',
#  'peanut chocolate candies read intro',
#  'oregano may herb spice moroccan spice',
#  'cherry decorate',
#  'scallops clams crabmeat flavor',
#  'cutup shrimp',
#  'texas toast style bread',
#  'epicure selections onion',
#  'chicken stockbroth bullion',
#  'stalks celery heart stalk',
#  'granny smith green pippin apples unsprayed',
#  'raisins ensures wonderfully chewy cookie',
#  'many youd oysters marinated olive',
#  'graham cracker crust baked cooled',
#  'andouille sausage medallion',
#  'light multigrain english muffins split',
#  'ribeye sirloin steak',
#  'lite italian salad dressing',
#  'raisins golden',
#  'sugarfree peanut',
#  'top pepperidge dressing',
#  'pasta pennnoni',
#  'coco chiffon',
#  'jalapeno spicy include seed',
#  'black red quinoa',
#  'rice chex wheat chex cheerios pretzel',
#  'truffle headnotes',
#  'fluted round cookie cutter assorted shaped cookie cutters aspic cutter',
#  'ham kites',
#  'broccoli rabe crosswise still clinging',
#  'fennel bulb similarly onion',
#  'betty crocker milk chocolate frosting frost',
#  'barolo chinato',
#  'ripe heirloom garden tomato',
#  'roundbone chuck roast',
#  'snap peas crosswise half',
#  'green cabbage quarted',
#  'chinese cabbage mustard cabbage watercress',
#  'mandarin oranges fruit juices',
#  'glutenfree pancake',
#  'pork sausagemeat',
#  'apple cider oatmeal',
#  'sumac yogurt',
#  'chickens bones skin meat neck',
#  'turkey carcass bones skin',
#  'chihuahua cheese mexican melting cheese',
#  'italian seasoning basil parsley sage rosemary mixed oregano basil parsley sage rosemary',
#  'chicken thighsdrumsticks bonein',
#  'grapefruit pink grapefruit',
#  'herbs spices condiment',
#  'pomegranate salsa recipe follow',
#  'portuguese chourio spanish chorizo cured spicy pork sausage',
#  'whtor brn',
#  'spaghetti barrilla classico',
#  'broccoli florets abt rinsed liquid removed',
#  'sweetened chestnut puree sweetened chestnut puree vanilla',
#  'sharp cheddar vegetable peeler',
#  'lundberg wild rice could grain rice',
#  'apples rome red delicious',
#  'brined turkey juniper brine',
#  'del monter southwest corn poblano red pepper',
#  'unbleached ww pastry success',
#  "kittencal's creamy ranch dressing/dip",
#  'egg egg yolk egg wash',
#  'onion deep',
#  'baileys cream',
#  'zucchini pared zucchini',
#  'italianseasoned bread crumbs progressor',
#  'chicken drumsticks king sooper',
#  'garbanzo beans chickpeas lentil',
#  'mint leaves chocolate',
#  'capsules green cardamon',
#  'sesame tahini peanut',
#  'cidah vinegah',
#  'reposado tequila sure percent agave tequila',
#  'various herbs eg thyme rosemary oregano',
#  'mayonnaise reg work',
#  'salmon cook',
#  'spinachrugalaromaine',
#  'rib beef roast first',
#  'acetate sort model making',
#  'wood chipsalder cherry apple hour hickory mesquite strong salmon',
#  'greek yogurt yogurt cheesecloth lined strainer refrigerator',
#  'fajita seasoning marinade',
#  'garhish',
#  'shrimp us farmed',
#  'herring wine',
#  'lobster tails cracked',
#  'cheese ravioli meat filled',
#  'packagedry turkey gravy',
#  'beef brisket excess',
#  'cinnamon allspice',
#  'kiddin',
#  'ream cream asparagus',
#  'turnip greens grs spinach',
#  'loose chives',
#  'monterey jack cheese mixture monterey jack cheddar cheese',
#  'spicy fig recipe follow',
#  'apricot coarselycut',
#  'cherry jelly',
#  'raisins dark chocolate chip',
#  'chilly',
#  'chives parsley tarragon',
#  'works cloves',
#  'highstarch potatoes russets idahos potato',
#  'pan bubbly caramel',
#  'honey ginger teriyaki marinade',
#  'fruit syrup passion',
#  'gingerbread house templates recipe follow',
#  'roast pork matchstick',
#  'castor tarts sweeter tbspoon',
#  'red pepper flakes double spicier chili',
#  'tomatoes jalapenos green chiles',
#  'halfandhalf milk consistency',
#  'scallion stalk',
#  'pasta garden spirals macaroni',
#  'butternut squash infused vodka',
#  'apple pear buter',
#  'penne pasta ziti elbow macaroni short pasta',
#  'apricot jam orange marmalade work',
#  'tv green peas',
#  'focaccia rolls horizontally',
#  'veal chicken meat scaloppini style',
#  'spanish imported paprika',
#  'bn fennel leaves',
#  'courgettes tender',
#  'chicken meat chunked fried chicken',
#  'celery leavestop',
#  'sausage patty broiled',
#  'mixed assorted fruit strawberries kiwi raspberries blueberry',
#  'leek crosswise light green',
#  'crusty bread point',
#  'mayonnaise please miracle whip unless',
#  'spoon thai chilly',
#  'pink peas',
#  'hero sandwich rolls split',
#  'mozzarella the deli',
#  'matchsticks daikon',
#  'black eyed peas black eyed peas',
#  'turkey meat jennyo',
#  'red wine go inexpensive stuff',
#  'campbells beef barley',
#  'mirto',
#  'green beans trimmed snapped long',
#  'premium quality milk chocolate',
#  'pumpkin reserve glaze',
#  'sweet potato medallion',
#  'cacaocacoa',
#  'rolled flaky pastry',
#  'salami deli chunk',
#  'ripe overripe banana',
#  'rib tied prime beef rib roast end trimmed',
#  'half sweetness fruit',
#  'grate orange rind',
#  'velveeta cheese jalapeno pepper',
#  'frenchcut beans crisply',
#  'sunflower sieed',
#  'pot',
#  'lettuce leaves salad green',
#  'caster sponge',
#  'spaghetti skinny noodle quantity grab quarter bundle person',
#  'state souerdough bread breadcrumb',
#  'dark rum mixture rum mixture spiced rum mixture coconut rum mixture',
#  'italian plums quetsches',
#  'fusilli long spiral spaghetti',
#  'beef steak tomatos',
#  'tied bonein beef chuck roast',
#  'cloves peach',
#  'lemon juice lemon reserve rind',
#  'wheat barley nugget cereal grapenutsr',
#  'andouille turkey sausage',
#  'fluid lime cordial',
#  'styrofoam cone feet high',
#  'ritz crackers sleeve from',
#  'oat nut milk',
#  'cheddar cheese sour cream bacon chives',
#  'handfuls red romaine lettuce',
#  'eggs milk batter roll ball',
#  'russet potato dime',
#  'northern beans liquid',
#  'deep shell bake',
#  'wesson round steak',
#  'mixed leaves parsley tarragon chervil fennel frond',
#  'cumin seeed',
#  'loaf vanilla buttercake',
#  'combo chinese chilli siracha',
#  'cheddar cheese part smoked cheddar',
#  'beets removed wedges beet',
#  'beef style',
#  'red orange sweet pepper',
#  'french haricots vert trimmed crosswise',
#  'party mixes',
#  'percent mozzarella cheese',
#  'links hungarian sausage cheese',
#  'chihuahua cheese asadero monterey jack',
#  'carrots broccoli tomatoes pepper',
#  'homestyle alfredo',
#  'beef broth beef bouillon may be',
#  'scallion light green green',
#  'ripe avocado california florida',
#  'cherry tomatoes half left',
#  'leeks light green portions rinsed ring',
#  'neutral grain alcohol spirit',
#  'onion pwd',
#  'spinach pasta',
#  'lemon rind part pith part pith',
#  'nutscrasin',
#  'sweet chestnut syrup',
#  'almonds honeyroasted almond',
#  'puffcorn curl',
#  'meyer lemon curd',
#  'pudding jello lemon',
#  'spanish onion young green scallions stem',
#  'vanilla cream barely',
#  'chipotle chiles seeds stems removed',
#  'glass stainless steel bowl spout',
#  'heads slit half',
#  'citrus herb seasoning',
#  'chicken deli rotisserie leftover',
#  'english egg dougha bread milk egg',
#  'buffalo rump roast',
#  'sweet wine marsala wine',
#  'rice yogurt love ricera brands blueberry',
#  'fillet mackerel saba',
#  'barillar elbow',
#  'tomatoes jalapenoflavored',
#  'jelly bean eggs candy',
#  'steak long',
#  'quality lard',
#  'scant handling',
#  'ripe mangoes peeles',
#  'linguini spaghetti noodles',
#  'sage leafs deep fried',
#  'roaster chicken chunk',
#  'duncan hines marble chocolate',
#  'nabiscos cheese nips cracker',
#  'nutmeg good piches',
#  'heads root end off but bulb intact',
#  'del monte pasta tomato',
#  'fried mushroom batter coat',
#  'mayonnaise light works too',
#  'radishes until tender',
#  'red pepper flakes zang',
#  'pineapple half',
#  'basmati rice min',
#  'pillsbury moist supreme premium',
#  'morels rinsed sand',
#  'mustard bourbon dijon',
#  'baby squid hoods around',
#  'gebhardt chili powderthis particular champ onessafeway line cant reddest hand',
#  'yogurt aspartame',
#  'goat cheese love merediths australia',
#  'poire william liqueur',
#  'graham cracker wafer crumb',
#  'dorothy lynch dressing',
#  'imitation egg',
#  'crust deepdish',
#  'chicken stock meat filled tortellini',
#  'crabmeat imitation crab liquid removed',
#  'cracklings run grinder',
#  'mandarin orange segments believe thats tin',
#  'carrots radish',
#  'apricot fruit spread smuckers simply fruit',
#  'thyme oregano yield leaves',
#  'sardines marinated portuguese bones removed',
#  'beans types beans beans beans blackeyed beans al',
#  'salad spread miracle whip',
#  'enoki mushrooms stems removed',
#  'salmon fillets wild preferred',
#  'creamy caramel syrup',
#  'cranberries direction',
#  'carys vermont pure maple syrup',
#  'tricolored pasta twist',
#  'top cornbread flavored stuffing',
#  'horsey',
#  'turkey rinsed inside neck heart gizzard shortcut turkey stock',
#  'amaretto lemon juice',
#  'dijon mustard half',
#  'chocolate kiss candies unwrapped',
#  'watermelon black seeds removed',
#  'mentsuyu included natto',
#  'filets salmon fillets skin',
#  'wood ear mushrooms chinese black mushroom',
#  'red pepper soft taco shell',
#  'seasonal citrus topping',
#  'crisco wesson',
#  'urfa biber',
#  'canadianstyle bacon recipe follow',
#  'masa maseca',
#  'applesmoked bacon fried',
#  'cinnamonsugar dipping',
#  'bodied red wine cab syrah',
#  'the pina colada slush',
#  'vegetables crispy bread crumbs recipe follow',
#  'chervil parsley',
#  'everyone carrot',
#  'leeks outer leaves trimmed back',
#  'scallions green reserve green final',
#  'chicken turkey beef tuna',
#  'apple cider vinegar unfiltered bragg',
#  'orange juice lemon',
#  'smaller red radishes',
#  'gourmet salad green',
#  'pasta bowtie',
#  'trollcaught mahi mahi fillets skin',
#  'green mike ike candy',
#  'seasonal vegetables zucchini yellow squash onions carrots eggplant target',
#  'low-carb tortilla',
#  'stewed tomatoes reduce stewed tomatoes spaghetti',
#  'ms spicy',
#  'kaffir lime leaves milk',
#  'jello orange lemon lime strawberry',
#  'lettuce apart',
#  'vegetable juice consistency',
#  'place bread bake untill throuhgout',
#  'eggs muffin',
#  'biscuits coffee',
#  'fregola pasta orzo',
#  'pimientos sliver',
#  'noodles pref',
#  'paper towelnewspaper',
#  'duncan hinesr signature pink velvet',
#  'sage essential oil',
#  'mexican cheese sargento walmarts shelfbrand value',
#  'sweet short crust pastry',
#  'left mexican rice',
#  'worcestershire it vegan miso bbq',
#  'clove glarlic',
#  'basil gdl target basil',
#  'whiskey canadian whisky',
#  'pumpkin optionalif the pumpkin egg',
#  'peppermint peanut',
#  'carrot onion stalk celery fennel bulb leeks red pepper green beans peas zucchini',
#  'ever cubboard',
#  'basket blackberry',
#  'tropical traditions coconut',
#  'cutup breast',
#  'packagefrozen snow pea pod',
#  ...}

# %%
def remove_items(data_list, items_to_drop):
    modified_list = []
    for item in data_list:
        if item not in items_to_drop:
            modified_list.append(item)
    return modified_list

# %%
df['clean_ingredients'] = df['clean_ingredients'].apply(lambda x: remove_items(x, filtered_counter))
df.head()
# Out:
#       id                                        ingredients  \
# 0  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213                [water, vegetable oil, wheat, salt]
# 4  13162  [black pepper, shallots, cornflour, cayenne pe...
#
#                                    clean_ingredients
# 0  [romaine lettuce, black olives, grape tomato, ...
# 1  [pepper, tomato, black pepper, thyme, egg, gre...
# 2  [egg, pepper, mayonaise, green chily, chicken ...
# 3                                 [vegetable, wheat]
# 4  [black pepper, shallot, cayenne pepper, onion,...

# %%
counting(data_list = df['clean_ingredients'], to_count="")
# Out:
# Counter({'egg': 847536,
#          'onion': 696568,
#          'pepper': 505680,
#          'olive': 433019,
#          'milk': 421965,
#          'vanilla': 376812,
#          'cloves': 359367,
#          'black pepper': 288154,
#          'cinnamon': 261298,
#          'lemon juice': 229158,
#          'soda': 217104,
#          'tomato': 179838,
#          'parsley': 163236,
#          'sour cream': 161162,
#          'carrot': 157705,
#          'cream cheese': 155799,
#          'parmesan cheese': 145850,
#          'clove': 138487,
#          'ginger': 132896,
#          'vegetable': 125912,
#          'green onion': 120729,
#          'chicken breast': 117080,
#          'celery': 116783,
#          'beef': 116102,
#          'cheddar cheese': 114880,
#          'pecan': 111680,
#          'potato': 111569,
#          'soy': 110857,
#          'nutmeg': 110276,
#          'mayonnaise': 110059,
#          'mushroom': 104583,
#          'chicken broth': 103901,
#          'oregano': 103107,
#          'honey': 101815,
#          'cumin': 101315,
#          'kosher': 96732,
#          'thyme': 95491,
#          'worcestershire': 93427,
#          'chili': 92532,
#          'vinegar': 90506,
#          'basil': 88672,
#          'cilantro': 88450,
#          'green pepper': 87638,
#          'heavy cream': 84078,
#          'rice': 82858,
#          'mustard': 82051,
#          'bacon': 81007,
#          'paprika': 80987,
#          'walnut': 74249,
#          'almond': 73106,
#          'chicken': 71539,
#          'red onion': 69365,
#          'nut': 67251,
#          'peanut': 67183,
#          'lime juice': 66762,
#          'cayenne pepper': 63802,
#          'wine': 63283,
#          'pineapple': 62278,
#          'lemon': 61457,
#          'buttermilk': 61040,
#          'shortening': 60877,
#          'raisin': 57426,
#          'mozzarella cheese': 55935,
#          'dijon mustard': 52242,
#          'shallot': 52087,
#          'coconut': 51990,
#          'strawberry': 51433,
#          'cocoa': 49807,
#          'canola': 49555,
#          'zucchini': 49195,
#          'red pepper flakes': 48734,
#          'red bell pepper': 48541,
#          'orange juice': 47972,
#          'shrimp': 47824,
#          'red pepper': 45692,
#          'cheese': 45604,
#          'cool whip': 44850,
#          'corn': 43496,
#          'cream mushroom': 42818,
#          'rosemary': 42722,
#          'ketchup': 42606,
#          'cream': 42037,
#          'spinach': 41401,
#          'light': 40414,
#          'chocolate chip': 39852,
#          'cream chicken': 38665,
#          'scallion': 38056,
#          'bay leaf': 37006,
#          'green bell pepper': 36989,
#          'chives': 36616,
#          'cucumber': 36553,
#          'bread': 34892,
#          'broccoli': 34406,
#          'red wine vinegar': 34296,
#          'evaporated milk': 34278,
#          'bananas': 34096,
#          'allspice': 34093,
#          'coriander': 33330,
#          'yellow onion': 33080,
#          'bread crumb': 33053,
#          'bay leaves': 32616,
#          'curry': 32322,
#          'yogurt': 32199,
#          'wheat': 31849,
#          'oleo': 31588,
#          'chicken stock': 30936,
#          'cranberry': 30678,
#          'marshmallow': 30442,
#          'apples': 30265,
#          'bell pepper': 30104,
#          'ham': 29812,
#          'turmeric': 29286,
#          'lemon zest': 29188,
#          'sharp cheddar cheese': 28850,
#          'sesame': 28687,
#          'sesame seed': 28320,
#          'cabbage': 27753,
#          'balsamic vinegar': 27443,
#          'cider vinegar': 27170,
#          'blueberry': 26435,
#          'mint': 26298,
#          'dill': 25612,
#          'sweet potato': 25023,
#          'basil leaves': 24514,
#          'spaghetti': 24503,
#          'peas': 24470,
#          'red wine': 24162,
#          'salsa': 24129,
#          'green chily': 23760,
#          'tortillas': 23751,
#          'sage': 23369,
#          'black olives': 23027,
#          'tabasco': 22579,
#          'beef broth': 22561,
#          'green bean': 22368,
#          'pineapple juice': 22296,
#          'swiss cheese': 22188,
#          'cherry': 21924,
#          'pumpkin': 21913,
#          'molasses': 21742,
#          'monterey jack cheese': 21720,
#          'breadcrumb': 21720,
#          'lime': 21419,
#          'feta cheese': 21330,
#          'sweetened milk': 21125,
#          'lettuce': 20979,
#          'pork': 20936,
#          'maple syrup': 20910,
#          'avocado': 20685,
#          'wine vinegar': 20419,
#          'celery rib': 20146,
#          'turkey': 19914,
#          'dark': 19757,
#          'cottage cheese': 19638,
#          'vanilla pudding': 19522,
#          'semisweet chocolate chip': 19470,
#          'chocolate': 19414,
#          'black bean': 19185,
#          'cherry tomato': 19026,
#          'active': 18919,
#          'cream tartar': 18760,
#          'skim milk': 18607,
#          'selfrising': 18516,
#          'raspberry': 18436,
#          'celery seed': 18254,
#          'cornmeal': 18057,
#          'pure vanilla': 17953,
#          'banana': 17943,
#          'rice vinegar': 17942,
#          'jalapeno pepper': 17832,
#          'cayenne': 17778,
#          'apple': 17660,
#          'stalks celery': 17412,
#          'orange zest': 17355,
#          'ricotta cheese': 17326,
#          'chestnut': 17296,
#          'salad': 17195,
#          'dates': 17004,
#          'light corn syrup': 16977,
#          'yellow': 16848,
#          'hamburger': 16844,
#          'seasoning': 16831,
#          'coconut milk': 16633,
#          'sherry': 16550,
#          'italian seasoning': 16375,
#          'orange': 16331,
#          'caper': 16276,
#          'catsup': 16202,
#          'apple cider vinegar': 15865,
#          'fish': 15648,
#          'graham cracker crumb': 15586,
#          'eggplant': 15385,
#          'pine nut': 15325,
#          'velveeta cheese': 15269,
#          'horseradish': 14804,
#          'sweet onion': 14778,
#          'kidney bean': 14717,
#          'rolled oat': 14641,
#          'parsley flakes': 14413,
#          'cumin seed': 14390,
#          'unsweetened cocoa': 14361,
#          'apricot': 14314,
#          'tarragon': 14070,
#          'taco seasoning': 13942,
#          'dill weed': 13930,
#          'vegetable broth': 13869,
#          'kernel corn': 13845,
#          'crisco': 13782,
#          'egg yolk': 13745,
#          'juice': 13618,
#          'leek': 13590,
#          'cilantro leaves': 13589,
#          'unbleached': 13541,
#          'chicken thigh': 13487,
#          'broccoli floret': 13481,
#          'corn tortillas': 13466,
#          'mint leaves': 13396,
#          'thyme leaves': 13257,
#          'oatmeal': 13249,
#          'oat': 13127,
#          'bisquick': 13089,
#          'pasta': 12983,
#          'cauliflower': 12793,
#          'vanilla cream': 12727,
#          'chicken bouillon': 12607,
#          'barbecue': 12531,
#          'plum tomato': 12392,
#          'applesauce': 12375,
#          'coffee': 12311,
#          'peaches': 12305,
#          'crust': 12215,
#          'icing': 12175,
#          'mandarin oranges': 11921,
#          'lemon rind': 11907,
#          'cardamom': 11816,
#          'flaked coconut': 11724,
#          'mustard seed': 11645,
#          'asparagus': 11540,
#          'caster': 11497,
#          'cream celery': 11471,
#          'black peppercorn': 11416,
#          'pork chop': 11401,
#          'maraschino cherry': 11332,
#          'tuna': 11280,
#          'marjoram': 11247,
#          'sausage': 11220,
#          'lemon peel': 11216,
#          'gingerroot': 11173,
#          'leaf parsley': 11054,
#          'stewed tomato': 10932,
#          'semisweet chocolate': 10886,
#          'mango': 10869,
#          'red potato': 10852,
#          'beer': 10739,
#          'poppy seed': 10729,
#          'brandy': 10710,
#          'blue cheese': 10648,
#          'corn syrup': 10550,
#          'shell': 10518,
#          'whipped topping': 10494,
#          'american cheese': 10484,
#          'rum': 10440,
#          'parsley leaves': 10415,
#          'juice lemon': 10405,
#          'elbow macaroni': 10219,
#          'whipped cream': 10055,
#          'kosher black pepper': 10043,
#          'creamy peanut': 10022,
#          'graham cracker crust': 9826,
#          'cracked black pepper': 9702,
#          'flatleaf parsley': 9614,
#          'artichoke heart': 9570,
#          'vodka': 9559,
#          'golden raisin': 9549,
#          'graham cracker': 9497,
#          'tortilla chip': 9496,
#          'bean': 9486,
#          'fennel seed': 9420,
#          'garam masala': 9363,
#          'long grain rice': 9348,
#          'tofu': 9342,
#          'parmesan': 9332,
#          'beef bouillon': 9274,
#          'egg noodles': 9266,
#          'oyster': 9250,
#          'soft': 9093,
#          'halfandhalf': 9065,
#          'fruit': 9029,
#          'russet potato': 8997,
#          'salmon fillet': 8990,
#          'pumpkin spice': 8958,
#          'vegetable stock': 8923,
#          'eagle brand milk': 8860,
#          'pinto bean': 8776,
#          'button mushroom': 8721,
#          'splenda': 8706,
#          'cashew': 8702,
#          'unsweetened chocolate': 8518,
#          'chickpeas': 8454,
#          'pineapple chunk': 8431,
#          'spring onion': 8335,
#          'caraway seed': 8292,
#          'stalk celery': 8278,
#          'noodles': 8251,
#          'ripe olives': 8245,
#          'ginger ale': 8238,
#          'pear': 8130,
#          'half-and-half': 8064,
#          'italian parsley': 7986,
#          'macaroni': 7930,
#          'poultry seasoning': 7876,
#          'avocados': 7863,
#          'black beans rinsed': 7845,
#          'puree': 7835,
#          'oregano leaves': 7827,
#          'jalapeno': 7802,
#          'biscuit': 7791,
#          'hoisin': 7762,
#          'baby spinach': 7724,
#          'greek yogurt': 7691,
#          'yellow bell pepper': 7691,
#          'vegetable shortening': 7681,
#          'ripe bananas': 7656,
#          'yellow cornmeal': 7639,
#          'pimento': 7597,
#          'green olives': 7509,
#          'crescent roll': 7417,
#          'apple juice': 7414,
#          'quick oat': 7406,
#          'crabmeat': 7389,
#          'romaine lettuce': 7370,
#          'pizza': 7362,
#          'puff pastry': 7278,
#          'strawberry jello': 7251,
#          'rhubarb': 7247,
#          'hazelnut': 7218,
#          'bean sprout': 7218,
#          'chocolate pudding': 7158,
#          'sunflower seed': 7140,
#          'apple cider': 7121,
#          'half half': 7075,
#          'pumpkin puree': 7045,
#          'peppercorn': 7021,
#          'prosciutto': 7016,
#          'bittersweet chocolate': 7005,
#          'liquid smoke': 6945,
#          'roma tomato': 6918,
#          'lime zest': 6895,
#          'dark chocolate': 6878,
#          'oranges': 6856,
#          'goat cheese': 6795,
#          'pepperoni': 6757,
#          'topping': 6714,
#          'refried bean': 6690,
#          'mirin': 6661,
#          'chuck': 6640,
#          'cranberry juice': 6603,
#          'coriander seed': 6593,
#          'orange rind': 6592,
#          'smoked paprika': 6587,
#          'red': 6559,
#          'beef stock': 6546,
#          'celery stalk': 6542,
#          'roasted peanut': 6534,
#          'butternut squash': 6506,
#          'wheat germ': 6499,
#          'bourbon': 6487,
#          'yellow mustard': 6463,
#          'sake': 6455,
#          'lentil': 6427,
#          'sauerkraut': 6415,
#          'provolone cheese': 6411,
#          'orange peel': 6409,
#          'unsweetened applesauce': 6383,
#          'creamstyle corn': 6382,
#          'mixed vegetables': 6381,
#          'sharp cheese': 6374,
#          'limes': 6357,
#          'vanilla wafer': 6321,
#          'green peas': 6309,
#          'light soy': 6302,
#          'pork bean': 6302,
#          'purple onion': 6286,
#          'dark rum': 6263,
#          'beet': 6263,
#          'grape tomato': 6256,
#          'lasagna noodles': 6225,
#          'red kidney bean': 6200,
#          'scallop': 6175,
#          'miracle whip': 6158,
#          'pork tenderloin': 6152,
#          'romano cheese': 6145,
#          'pimentos': 6116,
#          'roasted red pepper': 6096,
#          'sweet red pepper': 6087,
#          'yellow squash': 6000,
#          'low-fat milk': 5974,
#          'yukon gold potato': 5911,
#          'lamb': 5879,
#          'couscous': 5878,
#          'ritz cracker': 5851,
#          'italian sausage': 5848,
#          'olives': 5822,
#          'syrup': 5809,
#          'linguine': 5781,
#          'blackberry': 5751,
#          'saffron': 5727,
#          'table': 5714,
#          'penne pasta': 5713,
#          'radishes': 5691,
#          'flax seed': 5685,
#          'lemon pepper': 5649,
#          'corn flakes': 5647,
#          'sherry wine': 5638,
#          'ranch dressing': 5607,
#          'currant': 5580,
#          'gruyere cheese': 5543,
#          'lettuce leaves': 5516,
#          'parsnip': 5495,
#          'meat': 5495,
#          'extra-virgin olive': 5494,
#          'quinoa': 5490,
#          'pesto': 5454,
#          'rice wine vinegar': 5450,
#          'basmati rice': 5418,
#          'plum': 5416,
#          'salmon': 5399,
#          'pretzel': 5380,
#          'vanilla bean': 5375,
#          'chicken wing': 5372,
#          'orange marmalade': 5334,
#          'creamed corn': 5329,
#          'corn starch': 5319,
#          'tomatoes juice': 5305,
#          'kalamata olives': 5275,
#          'green cabbage': 5223,
#          'shiitake mushroom': 5169,
#          'jalapenos': 5154,
#          'pistachios': 5140,
#          'granny smith apples': 5137,
#          'okra': 5128,
#          'the': 5125,
#          'mozzarella': 5121,
#          'rice krispy': 5102,
#          'cauliflower floret': 5099,
#          'red chili pepper': 5081,
#          'pure maple syrup': 5078,
#          'light cream': 5076,
#          'caramel': 5066,
#          'arugula': 5003,
#          'creme fraiche': 4988,
#          'red cabbage': 4980,
#          'hash brown': 4970,
#          'tahini': 4956,
#          'baby carrot': 4950,
#          'lemonade': 4912,
#          'chili bean': 4908,
#          'ripe tomato': 4907,
#          'chili pepper': 4903,
#          'lime wedges': 4900,
#          'onion flakes': 4900,
#          'garbanzo bean': 4876,
#          'sage leaves': 4873,
#          'cracker crumb': 4866,
#          'steak': 4832,
#          'arborio rice': 4822,
#          'red chili': 4817,
#          'orange juice concentrate': 4816,
#          'dressing': 4814,
#          'crouton': 4787,
#          'panko breadcrumb': 4766,
#          'vanilla yogurt': 4764,
#          'lemon jello': 4688,
#          'sweet paprika': 4686,
#          'lemon wedges': 4608,
#          'squash': 4583,
#          'pancetta': 4563,
#          'snow peas': 4559,
#          'pimiento': 4541,
#          'butterscotch chip': 4537,
#          'iceberg lettuce': 4536,
#          'italian dressing': 4504,
#          'kosher pepper': 4478,
#          'cajun seasoning': 4460,
#          'clam': 4457,
#          'round steak': 4434,
#          'peach': 4430,
#          'herb': 4401,
#          'anchovy fillet': 4351,
#          'turnip': 4343,
#          'light sour cream': 4343,
#          'ginger root': 4341,
#          'french bread': 4341,
#          'lima bean': 4329,
#          'tapioca': 4314,
#          'coriander leaves': 4298,
#          'wesson': 4296,
#          'hardcooked egg': 4283,
#          'green': 4280,
#          'light mayonnaise': 4278,
#          'fig': 4275,
#          'tea': 4244,
#          'kale': 4216,
#          'english cucumber': 4174,
#          'oreo cooky': 4174,
#          'longgrain rice': 4157,
#          'old fashioned oat': 4112,
#          'mace': 4102,
#          'pork sausage': 4063,
#          'vanilla flavoring': 4049,
#          'wild rice': 4043,
#          'anchovy': 4029,
#          'fennel bulb': 3990,
#          'chocolate syrup': 3990,
#          'espresso': 3969,
#          'cooled': 3963,
#          'mascarpone cheese': 3947,
#          'star anise': 3945,
#          'egg egg': 3943,
#          'baguette': 3941,
#          'vanilla essence': 3928,
#          'cheez whiz': 3922,
#          'sweet milk': 3912,
#          'soymilk': 3905,
#          'splenda granular': 3883,
#          'jalapeno chily': 3878,
#          'distilled vinegar': 3873,
#          'hash potato': 3863,
#          'mayo': 3856,
#          'basil leaf': 3850,
#          'cannellini bean': 3840,
#          'smoked sausage': 3826,
#          'spinach leaves': 3825,
#          'spanish onion': 3804,
#          'orange jello': 3803,
#          'corn meal': 3799,
#          'sundried tomato': 3776,
#          'baby spinach leaves': 3754,
#          'ghee': 3753,
#          'green chili pepper': 3743,
#          'crab meat': 3737,
#          'karo syrup': 3722,
#          'tomatoes green chily': 3714,
#          'cool whip whipped topping': 3714,
#          'broth': 3707,
#          'pineapple tidbit': 3698,
#          'lemongrass': 3680,
#          'lard': 3675,
#          'smoked salmon': 3675,
#          'turkey breast': 3672,
#          'marshmallow creme': 3669,
#          'salad dressing': 3666,
#          'green chiles': 3665,
#          'rosemary leaves': 3659,
#          'marshmallow cream': 3659,
#          'italian salad dressing': 3653,
#          'superfine': 3646,
#          'sweet': 3645,
#          'northern bean': 3632,
#          'sriracha': 3619,
#          'cremini mushroom': 3607,
#          'sweetened flaked coconut': 3604,
#          'pan': 3592,
#          'tart apples': 3589,
#          'brussels sprout': 3565,
#          'milk chocolate chip': 3557,
#          'hamburger bun': 3549,
#          'tequila': 3548,
#          'angel': 3531,
#          'old bay seasoning': 3489,
#          'sherry vinegar': 3471,
#          'pecans walnut': 3469,
#          'fettuccine': 3428,
#          'marinara': 3427,
#          'partskim mozzarella cheese': 3394,
#          'potato chip': 3381,
#          'taco': 3376,
#          'apples cored': 3374,
#          'enchilada': 3360,
#          'kahlua': 3345,
#          'mild cheddar cheese': 3345,
#          'cheddar': 3345,
#          'flank steak': 3341,
#          'parmigianoreggiano cheese': 3318,
#          'corned beef': 3312,
#          'dark corn syrup': 3302,
#          'wheat pastry': 3301,
#          'feta': 3294,
#          'sunflower': 3288,
#          'frosting': 3267,
#          'walnuts pecan': 3233,
#          'bacon fried': 3229,
#          'zest lemon': 3227,
#          'soft bread crumb': 3226,
#          'sweetened coconut': 3201,
#          'orzo pasta': 3193,
#          'angel hair pasta': 3192,
#          'cracked pepper': 3188,
#          'lipton onion': 3184,
#          'prunes': 3182,
#          'asparagus spear': 3177,
#          'self raising': 3166,
#          'unsweetened coconut': 3162,
#          'mexican cheese': 3158,
#          'asiago cheese': 3153,
#          'barley': 3148,
#          'light cream cheese': 3146,
#          'german chocolate': 3140,
#          'vermouth': 3130,
#          'lime jello': 3121,
#          'vidalia onion': 3117,
#          'glaze': 3115,
#          'wonton wrapper': 3103,
#          'miso': 3102,
#          'olive drizzling': 3097,
#          'dark soy': 3096,
#          'teriyaki': 3066,
#          'quickcooking oat': 3060,
#          'kalamata olive': 3059,
#          'cracker': 3052,
#          'green beans trimmed': 3040,
#          'lemon, zest': 3034,
#          'pimientos': 3027,
#          'vegetables': 3026,
#          'long-grain rice': 3024,
#          'lime, juice': 3016,
#          'pistachio pudding': 3015,
#          'watercress': 3010,
#          'dark sesame': 3000,
#          'beef stew meat': 2999,
#          'stuffing': 2987,
#          'onion ring': 2975,
#          'coffee granules': 2965,
#          'picante': 2961,
#          'chow mein noodles': 2961,
#          'wheat bread': 2955,
#          'green tomato': 2950,
#          'red chily': 2933,
#          'macadamia nut': 2932,
#          'phyllo': 2917,
#          'hamburger meat': 2903,
#          'monterey jack pepper cheese': 2895,
#          'unsweetened coconut milk': 2892,
#          'grand marnier': 2892,
#          'cardamom pod': 2857,
#          'granny smith apple': 2850,
#          'spicy mustard': 2845,
#          'yellow pepper': 2833,
#          'chickpeas rinsed': 2831,
#          'peppermint': 2820,
#          'baked shell': 2820,
#          'bacon dripping': 2818,
#          'berry': 2812,
#          'chunky salsa': 2811,
#          'pearl barley': 2808,
#          'cognac': 2798,
#          'pork loin': 2797,
#          'amaretto': 2784,
#          'curd cottage cheese': 2780,
#          'kidney beans rinsed': 2758,
#          'navy bean': 2747,
#          'portabella mushroom': 2744,
#          'halfandhalf cream': 2734,
#          'ribs celery': 2703,
#          'grain mustard': 2700,
#          'fish fillet': 2686,
#          'pork shoulder': 2670,
#          'rice noodles': 2669,
#          'curry leaves': 2668,
#          'fennel': 2667,
#          'chunky peanut': 2664,
#          'xanthan gum': 2663,
#          'sun-dried': 2654,
#          'saffron thread': 2648,
#          'napa cabbage': 2646,
#          'fontina cheese': 2644,
#          'saltine cracker': 2638,
#          'whip': 2622,
#          'cream whipped': 2619,
#          'stock': 2618,
#          'sun-dried tomato': 2614,
#          'sweet pickle relish': 2612,
#          'chicken bouillon granules': 2607,
#          'semi-sweet chocolate chip': 2606,
#          'half-and-half cream': 2602,
#          'bamboo shoot': 2601,
#          'clam juice': 2601,
#          'self rising': 2596,
#          'watermelon': 2590,
#          'mussel': 2579,
#          'roasting chicken': 2572,
#          'creole seasoning': 2570,
#          'green chili': 2544,
#          'sour milk': 2541,
#          'pecorino romano cheese': 2539,
#          'parmigiano-reggiano cheese': 2526,
#          'low-fat yogurt': 2519,
#          'ripe banana': 2518,
#          'chorizo sausage': 2512,
#          'pumpkin seed': 2497,
#          'wasabi': 2484,
#          'agave nectar': 2476,
#          'dog': 2474,
#          'celery leaves': 2472,
#          'cilantro leaf': 2467,
#          'juice lime': 2459,
#          'chili flakes': 2458,
#          'lemon pudding': 2445,
#          'pet milk': 2439,
#          'gravy': 2420,
#          'velveeta': 2392,
#          'polenta': 2387,
#          'deli ham': 2382,
#          'light coconut milk': 2378,
#          'land lakes': 2378,
#          'marinade': 2374,
#          'pastry': 2374,
#          'lemon juice lemon': 2374,
#          'smooth peanut': 2368,
#          'heavy cream whipped': 2367,
#          'strong coffee': 2366,
#          'rice wine': 2358,
#          'marsala wine': 2358,
#          'artichokes': 2355,
#          'english muffin': 2354,
#          'cantaloupe': 2349,
#          'ripe avocado': 2346,
#          'asparagus trimmed': 2346,
#          'gorgonzola': 2344,
#          'candied cherry': 2344,
#          'italian breadcrumb': 2343,
#          'red lentil': 2338,
#          'tarragon leaves': 2334,
#          'roll': 2323,
#          'potato starch': 2322,
#          'berry cranberry': 2308,
#          'light rum': 2307,
#          'chile': 2301,
#          'alfredo': 2300,
#          'lemonade concentrate': 2284,
#          'milk chocolate': 2283,
#          'seedless raisin': 2282,
#          'semisweet chocolate morsel': 2261,
#          'turbinado': 2247,
#          'grapeseed': 2245,
#          'semolina': 2240,
#          'chipotle chiles adobo': 2236,
#          'guacamole': 2228,
#          'smoked ham': 2227,
#          'pita bread': 2226,
#          'sherry wine vinegar': 2225,
#          'beef brisket': 2211,
#          'zesty italian dressing': 2209,
#          'ricotta': 2208,
#          'dill pickles': 2206,
#          'apricot jam': 2206,
#          'tortilla': 2198,
#          'chily': 2193,
#          'baby arugula': 2192,
#          'acorn squash': 2189,
#          'tamari': 2178,
#          'bakers semisweet chocolate': 2178,
#          'penne': 2173,
#          'chicken leg': 2170,
#          'golden syrup': 2169,
#          'cornflakes': 2169,
#          'marinated artichoke heart': 2169,
#          'sirloin': 2167,
#          'dill pickle': 2166,
#          'chicken drumstick': 2165,
#          'coconut cream': 2160,
#          'eggs egg': 2160,
#          'grapes': 2153,
#          'gin': 2150,
#          'salami': 2148,
#          'bulk pork sausage': 2145,
#          'beef chuck': 2141,
#          'golden': 2139,
#          'kielbasa': 2128,
#          'chipotle chile adobo': 2126,
#          'light olive': 2121,
#          'jicama': 2119,
#          'sweet corn': 2107,
#          'mint leaf': 2106,
#          'loaf french bread': 2106,
#          'unsweetened pineapple juice': 2103,
#          'tumeric': 2095,
#          'cashew nut': 2095,
#          'mushroom stem': 2093,
#          'cannellini beans rinsed': 2093,
#          'pork loin chop': 2090,
#          'olive vegetable': 2089,
#          'flatleaf parsley leaves': 2089,
#          'red chile': 2088,
#          'orange bell pepper': 2084,
#          'chuck roast': 2082,
#          'mayonnaise salad dressing': 2080,
#          'cherry jello': 2075,
#          'sirloin steak': 2068,
#          'anise seed': 2066,
#          'corn chip': 2061,
#          'bok choy': 2060,
#          'english peas': 2060,
#          'veal': 2056,
#          'lemon, juice': 2056,
#          'rotini pasta': 2054,
#          'ancho chile': 2053,
#          'red curry': 2043,
#          'cornbread': 2039,
#          'tater': 2039,
#          'ripe avocados': 2039,
#          'mayonaise': 2036,
#          'red capsicum': 2036,
#          'italian bread crumb': 2030,
#          'porcini mushroom': 2025,
#          'hominy': 2019,
#          'bouillon': 2019,
#          'bow tie pasta': 2019,
#          'pearl onion': 2018,
#          'kiwi fruit': 2016,
#          'arrowroot': 2009,
#          'seedless grapes': 1999,
#          'bicarbonate soda': 1986,
#          'port wine': 1986,
#          'palm': 1975,
#          'soya': 1970,
#          'yoghurt': 1969,
#          'pastry shell': 1963,
#          'blackeyed peas': 1957,
#          'lettuce leaf': 1956,
#          'grapefruit juice': 1942,
#          'loaf bread': 1939,
#          'crisco shortening': 1935,
#          'scant': 1935,
#          'mexican oregano': 1934,
#          'flavoring': 1933,
#          'french onion': 1931,
#          'silken tofu': 1930,
#          'scallions green': 1926,
#          'double cream': 1924,
#          'grit': 1915,
#          'dark molasses': 1914,
#          'wheat tortillas': 1898,
#          'sweet pepper': 1890,
#          'pasta shell': 1889,
#          'roma': 1889,
#          'mango chutney': 1884,
#          'savory': 1878,
#          'beef bouillon granules': 1875,
#          'beef consomme': 1858,
#          'almond milk': 1857,
#          'frenchstyle green bean': 1853,
#          'tilapia fillet': 1849,
#          'raspberry jello': 1849,
#          'beef roast': 1845,
#          'herb stuffing': 1845,
#          'panko bread crumb': 1837,
#          'jasmine rice': 1836,
#          'season': 1834,
#          'chicken stock broth': 1834,
#          'mixed salad green': 1831,
#          'sweet basil': 1825,
#          'chicken turkey': 1825,
#          'quick oatmeal': 1822,
#          'poblano pepper': 1820,
#          'rose': 1816,
#          'snap peas': 1812,
#          'reducedfat sour cream': 1808,
#          'meatball': 1806,
#          'jumbo shrimp': 1799,
#          'coconut flakes': 1795,
#          'apple cored': 1795,
#          'round': 1779,
#          'tomatillos': 1777,
#          'chicken liver': 1775,
#          'leg lamb': 1772,
#          'sweet chili': 1771,
#          'pudding': 1759,
#          'beef browned': 1753,
#          'grenadine': 1748,
#          'kiwi': 1741,
#          'pomegranate seed': 1741,
#          'pickling': 1741,
#          'radish': 1740,
#          'chia seed': 1738,
#          'shell pasta': 1736,
#          'mascarpone': 1734,
#          'black sesame seed': 1729,
#          'pomegranate juice': 1725,
#          'popped popcorn': 1723,
#          'edamame': 1713,
#          'baked bean': 1706,
#          'tarragon vinegar': 1705,
#          'mixed spice': 1702,
#          'flat-leaf parsley': 1699,
#          'french vanilla pudding': 1699,
#          'stew meat': 1698,
#          'chinese five spice': 1693,
#          'pizza crust': 1692,
#          'cream coconut': 1692,
#          'grnd beef': 1690,
#          'sundried': 1687,
#          'sourdough bread': 1687,
#          'almond flavoring': 1686,
#          'peanut chip': 1680,
#          'rye': 1679,
#          'sharp cheddar': 1679,
#          'tomatoes wedges': 1679,
#          'adobo': 1675,
#          'stevia': 1674,
#          'bacon grease': 1674,
#          'katakuriko': 1674,
#          'onion wedges': 1673,
#          '° °': 1672,
#          'andouille sausage': 1670,
#          'kaffir lime leaves': 1670,
#          'champagne vinegar': 1666,
#          'deep': 1662,
#          'champagne': 1661,
#          'coleslaw': 1658,
#          'jack cheese': 1657,
#          'tamari soy': 1655,
#          'basil pesto': 1649,
#          'prawn': 1647,
#          'butterscotch pudding': 1645,
#          'tuna steak': 1644,
#          'yellow corn meal': 1643,
#          'caramel cream topping': 1643,
#          'black-eyed peas': 1641,
#          'lime rind': 1636,
#          'cream potato': 1635,
#          'papaya': 1632,
#          'real': 1631,
#          'devil': 1628,
#          'oat bran': 1626,
#          'habanero pepper': 1624,
#          'tamarind': 1622,
#          'colby cheese': 1621,
#          'catfish fillet': 1618,
#          'red bean': 1616,
#          'vanilla bean split': 1615,
#          'scallions spring green onion': 1611,
#          'phyllo pastry': 1610,
#          'dark chocolate chip': 1608,
#          'herbes provence': 1603,
#          'raspberry jam': 1599,
#          'apricot nectar': 1595,
#          'beef turkey': 1592,
#          'jello': 1588,
#          'serrano pepper': 1586,
#          'black mustard seed': 1584,
#          'smoked bacon': 1584,
#          'dill seed': 1582,
#          'french fried onion': 1581,
#          'swiss chard': 1579,
#          'onion onion': 1579,
#          'allspice berry': 1577,
#          'italian bread': 1576,
#          'eagle brand sweetened milk': 1563,
#          'olive brushing': 1562,
#          'angel flake coconut': 1561,
#          'pork loin roast': 1560,
#          'idaho potato': 1558,
#          'karo': 1555,
#          'lemon flavoring': 1555,
#          'canadian bacon': 1554,
#          'olive flavored': 1552,
#          'chipotle pepper': 1552,
#          'rigatoni pasta': 1547,
#          'msg': 1546,
#          'dijonstyle mustard': 1545,
#          'breakstones knudsen sour cream': 1545,
#          'chipotle': 1542,
#          'creme cacao': 1541,
#          'degrees': 1541,
#          'capers rinsed': 1538,
#          'cool': 1537,
#          'golden mushroom': 1536,
#          'tuna flaked': 1535,
#          'pineapple chunks juice': 1534,
#          'flax seed meal': 1533,
#          'parmigianoreggiano': 1533,
#          'vegall': 1532,
#          'lawry': 1530,
#          'yam': 1524,
#          'basil basil': 1522,
#          'grapefruit': 1521,
#          'broccoli floweret': 1518,
#          'candied pineapple': 1515,
#          'potatoes chunk': 1515,
#          'selfraising': 1515,
#          'whiskey': 1514,
#          'corn kernel': 1512,
#          'pistachio nut': 1506,
#          'beef tenderloin': 1505,
#          'spice': 1505,
#          'ranch style bean': 1502,
#          'vegetable olive': 1501})
