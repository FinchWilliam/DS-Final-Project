# %% [markdown]
# # Data Loading
#  1. Load all datasets
#  2. Perform basic cleaning to make them all the same format
#  3. Save them

# %% [markdown]
# ### Libraries and such

# %%
import pandas as pd 
import numpy as np 
import os
import json
import string
import ast
import re
from nltk.corpus import stopwords
from collections import Counter
import utils.processing_functions as pf
stop_words = stopwords.words('english')
file_path = '../../Data/Raw Datasets/' # Adjust to your file path of choice, I have chosen a directory outside of the repo to save on space.

# %% [markdown]
# ## Check Each Dataset
#  - We will only be keeping the ingredients (as lists) and the ID (as an identifier)

# %% [markdown]
# ### [Dataset 1 (set1-f)](https://www.kaggle.com/datasets/kaggle/recipe-ingredients-dataset)
#  - This dataset was provided by [Yummly](http://www.yummly.com/)
#  - Viable

# %%
data1_train = pd.read_json(f'{file_path}set1-f/train.json')
data1_test = pd.read_json(f'{file_path}set1-f/train.json')

# %%
dataset1 = pd.concat([data1_test, data1_train], axis=0)
dataset1 = dataset1.drop(columns='cuisine')
dataset1.head()
# Out:
#       id                                        ingredients
# 0  10259  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213                [water, vegetable oil, wheat, salt]
# 4  13162  [black pepper, shallots, cornflour, cayenne pe...

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79548 entries, 0 to 39773
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           79548 non-null  int64
#  1   ingredients  79548 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.8+ MB

# %% [markdown]
# ### [Dataset 2 (set2-f)](https://www.kaggle.com/datasets/shuyangli94/food-com-recipes-and-user-interactions)
#  - Crawled data from Food.com (GeniusKitchen) online recipe aggregator
#  - Viable

# %%
data2 = pd.read_csv(f'{file_path}set2-f/RAW_recipes.csv')
data2
columns_to_drop = ['name', 'minutes', 'contributor_id', 'submitted', 'tags', 'nutrition', 'n_steps', 'steps', 'description', 'n_ingredients']
dataset2 = data2.drop(columns= columns_to_drop)
dataset2.head()
# Out:
#        id                                        ingredients
# 0  137739  ['winter squash', 'mexican seasoning', 'mixed ...
# 1   31490  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  112140  ['ground beef', 'yellow onions', 'diced tomato...
# 3   59389  ['spreadable cheese with garlic and herbs', 'n...
# 4   44061  ['tomato juice', 'apple cider vinegar', 'sugar...

# %% [markdown]
#  - Our ingredients column is actually a string that looks like a list, we will convert it to a list and move on

# %%
print(dataset2['ingredients'].head(5).apply(type))
# Out:
# 0    <class 'str'>
# 1    <class 'str'>
# 2    <class 'str'>
# 3    <class 'str'>
# 4    <class 'str'>
# Name: ingredients, dtype: object

# %%
dataset2['ingredients'] = dataset2['ingredients'].apply(lambda x: pf.convert_to_list(x))

# %%
print(dataset2['ingredients'].head(5).apply(type))
# Out:
# 0    <class 'list'>
# 1    <class 'list'>
# 2    <class 'list'>
# 3    <class 'list'>
# 4    <class 'list'>
# Name: ingredients, dtype: object

# %%
display(dataset2.head())
dataset2.info()
# Out:
#        id                                        ingredients
# 0  137739  [winter squash, mexican seasoning, mixed spice...
# 1   31490  [prepared pizza crust, sausage patty, eggs, mi...
# 2  112140  [ground beef, yellow onions, diced tomatoes, t...
# 3   59389  [spreadable cheese with garlic and herbs, new ...
# 4   44061  [tomato juice, apple cider vinegar, sugar, sal...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231637 entries, 0 to 231636
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           231637 non-null  int64
#  1   ingredients  231637 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ### [Dataset 3 (set3-f)](https://www.kaggle.com/datasets/irkaal/foodcom-recipes-and-reviews)
#  - Colaborator for data: Alvin
#  - Viable

# %%
data3 = pd.read_csv(f'{file_path}set3-f/recipes.csv')
data3.head()
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1        39                            Biryani      1567        elly9812
# 2        40                      Best Lemonade      1566  Stephen Little
# 3        41     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4        42                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime         DatePublished  \
# 0    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2     PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
# 3    PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# 2  This is from one of my  first Good House Keepi...
# 3  This dish is best prepared a day in advance to...
# 4  Make and share this Cabbage Soup recipe from F...
#
#                                               Images  ... SaturatedFatContent  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  ...                 1.3
# 1  c("https://img.sndimg.com/food/image/upload/w_...  ...                16.6
# 2  c("https://img.sndimg.com/food/image/upload/w_...  ...                 0.0
# 3  c("https://img.sndimg.com/food/image/upload/w_...  ...                 3.8
# 4  "https://img.sndimg.com/food/image/upload/w_55...  ...                 0.1
#
#   CholesterolContent SodiumContent CarbohydrateContent  FiberContent  \
# 0                8.0          29.8                37.1           3.6
# 1              372.8         368.4                84.4           9.0
# 2                0.0           1.8                81.5           0.4
# 3                0.0        1558.6                64.2          17.3
# 4                0.0         959.3                25.1           4.8
#
#    SugarContent  ProteinContent  RecipeServings  RecipeYield  \
# 0          30.2             3.2             4.0          NaN
# 1          20.4            63.4             6.0          NaN
# 2          77.2             0.3             4.0          NaN
# 3          32.1            29.3             2.0     4 kebabs
# 4          17.7             4.3             4.0          NaN
#
#                                   RecipeInstructions
# 0  c("Toss 2 cups berries with sugar.", "Let stan...
# 1  c("Soak saffron in warm milk for 5 minutes and...
# 2  c("Into a 1 quart Jar with tight fitting lid, ...
# 3  c("Drain the tofu, carefully squeezing out exc...
# 4  c("Mix everything together and bring to a boil...
#
# [5 rows x 28 columns]

# %%
dataset3 = pd.DataFrame()
dataset3['id'] = data3['RecipeId']
dataset3['ingredients'] = data3['RecipeIngredientParts']
dataset3.head()
# Out:
#    id                                        ingredients
# 0  38  c("blueberries", "granulated sugar", "vanilla ...
# 1  39  c("saffron", "milk", "hot green chili peppers"...
# 2  40  c("sugar", "lemons, rind of", "lemon, zest of"...
# 3  41  c("extra firm tofu", "eggplant", "zucchini", "...
# 4  42  c("plain tomato juice", "cabbage", "onion", "c...

# %% [markdown]
#  - need to do further editing to bring the ingredients list in line with the other datasets
#   - remove any that are a single ingredient

# %%
dataset3 = dataset3[dataset3['ingredients'].str.startswith('c(') == True]
dataset3.head()
# Out:
#    id                                        ingredients
# 0  38  c("blueberries", "granulated sugar", "vanilla ...
# 1  39  c("saffron", "milk", "hot green chili peppers"...
# 2  40  c("sugar", "lemons, rind of", "lemon, zest of"...
# 3  41  c("extra firm tofu", "eggplant", "zucchini", "...
# 4  42  c("plain tomato juice", "cabbage", "onion", "c...

# %% [markdown]
#  - convert to a list

# %%
dataset3['ingredients'] = dataset3['ingredients'].apply(lambda x: pf.convert_to_list(x, 1))
dataset3.head()
# Out:
#    id                                        ingredients
# 0  38  [blueberries, granulated sugar, vanilla yogurt...
# 1  39  [saffron, milk, hot green chili peppers, onion...
# 2  40  [sugar, lemons, rind of, lemon, zest of, fresh...
# 3  41  [extra firm tofu, eggplant, zucchini, mushroom...
# 4  42  [plain tomato juice, cabbage, onion, carrots, ...

# %%
dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 511626 entries, 0 to 522516
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           511626 non-null  int64
#  1   ingredients  511626 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 11.7+ MB

# %% [markdown]
# ### [Dataset 4 (set4-f)](https://www.kaggle.com/datasets/wilmerarltstrmberg/recipe-dataset-over-2m)
#  - Collaborator for data: Wilmer Arlt Strömberg
#  - Viable

# %%
data4 = pd.read_csv(f'{file_path}set4-f/recipes_data.csv')
data4.head()
# Out:
#                    title                                        ingredients  \
# 0    No-Bake Nut Cookies  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  Jewell Ball'S Chicken  ["1 small jar chipped beef, cut up", "4 boned ...
# 2            Creamy Corn  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3          Chicken Funny  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4   Reeses Cups(Candy)    ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
#
#                                                  NER               site
# 0  ["bite size shredded rice biscuits", "vanilla"...  www.cookbooks.com
# 1  ["cream of mushroom soup", "beef", "sour cream...  www.cookbooks.com
# 2  ["frozen corn", "pepper", "cream cheese", "gar...  www.cookbooks.com
# 3  ["chicken gravy", "cream of mushroom soup", "c...  www.cookbooks.com
# 4  ["graham cracker crumbs", "powdered sugar", "p...  www.cookbooks.com

# %%
dataset4 = pd.DataFrame()
dataset4['id'] = data4.index
dataset4['ingredients'] = data4['ingredients']

# %%
dataset4
# Out:
#               id                                        ingredients
# 0              0  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1              1  ["1 small jar chipped beef, cut up", "4 boned ...
# 2              2  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3              3  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4              4  ["1 c. peanut butter", "3/4 c. graham cracker ...
# ...          ...                                                ...
# 2231137  2231137  ["1/2 cup chocolate hazelnut spread (recommend...
# 2231138  2231138  ["1 dozen eggs", "1 paprika", "1 salt and pepp...
# 2231139  2231139  ["150 grams Daikon radish", "1 tbsp Sesame oil...
# 2231140  2231140  ["1 cup apple cider", "6 tablespoons sugar", "...
# 2231141  2231141  ["1 pound ground veal", "1/2 pound sweet Itali...
#
# [2231142 rows x 2 columns]

# %% [markdown]
# - This dataset has all the measurements in the ingredients lists, so will need to drop all of the numbers stop words

# %%
dataset4['ingredients'] = dataset4['ingredients'].apply(lambda x: pf.convert_to_list(x))

# %%
dataset4['ingredients'] = dataset4['ingredients'].apply(lambda x: pf.remove_stop_words(x, stop_words))
display(dataset4.head())
dataset4.info()
# Out:
#    id                                        ingredients
# 0   0  [c firmly packed brown sugar, c evaporated mil...
# 1   1  [small jar chipped beef cut, boned chicken bre...
# 2   2  [oz pkg frozen corn, oz pkg cream cheese cubed...
# 3   3  [large whole chicken, oz cans chicken gravy, o...
# 4   4  [c peanut butter, c graham cracker crumbs, c m...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2231142 entries, 0 to 2231141
# Data columns (total 2 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   ingredients  object
# dtypes: int64(1), object(1)
# memory usage: 34.0+ MB

# %% [markdown]
# ### [Dataset 5 (set5-f)](https://www.kaggle.com/datasets/sterby/german-recipes-dataset)
#  - metadata crawled from chefkoch.de*.
#  - Non-Viable

# %%
data5 = pd.read_json(f'{file_path}set5-f/recipes.json')
data5
# Out:
#                                                      Url  \
# 0       https://www.chefkoch.de/rezepte/185441079701305/
# 1      https://www.chefkoch.de/rezepte/2718181424631245/
# 2        https://www.chefkoch.de/rezepte/46341015661368/
# 3        https://www.chefkoch.de/rezepte/51051018014178/
# 4      https://www.chefkoch.de/rezepte/1555771262860408/
# ...                                                  ...
# 12185  https://www.chefkoch.de/rezepte/1547251261244879/
# 12186    https://www.chefkoch.de/rezepte/47411016028870/
# 12187  https://www.chefkoch.de/rezepte/1102041216136522/
# 12188      https://www.chefkoch.de/rezepte/897988359371/
# 12189    https://www.chefkoch.de/rezepte/34751011686647/
#
#                                             Instructions  \
# 0      Die Eier hart kochen. Dann pellen und mit eine...
# 1      Vorab folgende Bemerkung: Alle Mengen sind Cir...
# 2      Die Kirschen abtropfen lassen, dabei den Saft ...
# 3      Den Spargel säubern, die holzigen Enden abschn...
# 4      Kohlrabi schälen und klein würfeln. Mit der Br...
# ...                                                  ...
# 12185  In einem nicht allzu großen Topf die Butter er...
# 12186  Gurke waschen und in dünne Scheiben schneiden....
# 12187  Die Gurken schälen und längs halbieren. Das In...
# 12188  Die Knochen mit der Hälfte des Wurzelwerkes, d...
# 12189  Aus Mehl, Hefe, den Gewürzen, Ei, Milch und de...
#
#                                              Ingredients  Day  \
# 0      [600 g Hackfleisch, halb und halb, 800 g Sauer...    1
# 1      [1 kg Strauchtomate(n), 1 Gemüsezwiebel(n), 1 ...    1
# 2      [1 Glas Kirsche(n), 1 Pck. Vanillepuddingpulve...    1
# 3      [500 g Spargel, grüner, 300 ml Brühe oder Fond...    1
# 4      [250 g Kohlrabi, 150 ml Gemüsebrühe, 150 ml Mi...    1
# ...                                                  ...  ...
# 12185  [3 EL Butter, 800 g Rinderbraten (Schulter ode...    1
# 12186  [1/2 Salatgurke(n), 250 g Käse (Emmentaler), 1...    1
# 12187  [1 kg Schmorgurke(n), 1 kl. Dose/n Tomate(n), ...    1
# 12188  [Für den Fond:, 500 g Knochen vom Wild, 1/2Bun...    1
# 12189  [375 g Mehl (Weizenmehl, Weizenvollkornmehl), ...    1
#
#                                                     Name  Year      Month  \
# 0                                 Gebratener Hasenrücken  2009    January
# 1                                        Pilz Stroganoff  2017       July
# 2                                   Kaninchen a la Gioff  2007    January
# 3                         Spanisches Knoblauch-Kaninchen  2013      April
# 4                  Gnocchi - Hack - Pfanne mit Basilikum  2017     August
# ...                                                  ...   ...        ...
# 12185                              Herzhafte Pfannkuchen  2019    January
# 12186                         Tomaten-Zucchini-Spaghetti  2004  September
# 12187  Am Spieß gebratenes Schweinefleisch mit Malzex...  2012  September
# 12188                                      Geflügelsalat  2003   February
# 12189                          Serbischer Paprikaeintopf  2003    October
#
#          Weekday
# 0       Thursday
# 1       Saturday
# 2         Monday
# 3         Monday
# 4        Tuesday
# ...          ...
# 12185    Tuesday
# 12186  Wednesday
# 12187   Saturday
# 12188   Saturday
# 12189  Wednesday
#
# [12190 rows x 8 columns]

# %% [markdown]
#  - Dataset not in english, will skip as we are not currently looking to use a translator on everything

# %% [markdown]
# ### [Dataset 6 (set6-f)](https://www.kaggle.com/datasets/canggih/indonesian-food-recipes)
#  - Collaborator for data: Canggih P Wibowo
#  - Non-Viable

# %%
data6 = pd.read_csv(f'{file_path}set6-f/dataset-ayam.csv')
data6.head()
# Out:
#                       Title  \
# 0          Ayam Woku Manado
# 1  Ayam goreng tulang lunak
# 2          Ayam cabai kawin
# 3               Ayam Geprek
# 4               Minyak Ayam
#
#                                          Ingredients  \
# 0  1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...
# 1  1 kg ayam (dipotong sesuai selera jangan kecil...
# 2  1/4 kg ayam--3 buah cabai hijau besar--7 buah ...
# 3  250 gr daging ayam (saya pakai fillet)--Secuku...
# 4  400 gr kulit ayam & lemaknya--8 siung bawang p...
#
#                                                Steps  Loves  \
# 0  Cuci bersih ayam dan tiriskan. Lalu peras jeru...      1
# 1  Haluskan bumbu2nya (BaPut, ketumbar, kemiri, k...      1
# 2  Panaskan minyak di dalam wajan. Setelah minyak...      2
# 3  Goreng ayam seperti ayam krispi--Ulek semua ba...     10
# 4  Cuci bersih kulit ayam. Sisihkan--Ambil 50 ml ...      4
#
#                                           URL
# 0          /id/resep/4473027-ayam-woku-manado
# 1  /id/resep/4471956-ayam-goreng-tulang-lunak
# 2          /id/resep/4473057-ayam-cabai-kawin
# 3               /id/resep/4473023-ayam-geprek
# 4               /id/resep/4427438-minyak-ayam

# %% [markdown]
#  - Dataset 6 also not in english, will skip this set

# %% [markdown]
# ### [Dataset 7 (set7-f)](https://www.kaggle.com/datasets/bhavyadhingra00020/healthy-indian-recipes)
#  - Collaborator for data: Bhavya Dhingra
#  - Non-Viable

# %%
data7 = pd.read_csv(f'{file_path}set7-f/IndianHealthyRecipe.csv')
data7
# Out:
#                                      Dish Name  \
# 0                            Pistachio chicken
# 1                             Tangy Fried Okra
# 2                        Healthy Chicken Korma
# 3                            Brown Lentil Dhal
# 4                           Thari Wala Chicken
# ..                                         ...
# 144  Vegan Wild Rice, Cumin & Chickpea Burgers
# 145                            Vegetable Pilau
# 146                  Watermelon and Feta Chaat
# 147                    Zambezi Baked Sea Bream
# 148                                      Zhoug
#
#                                   Description   Spice     Prep Time   Views  \
# 0    Mild chicken in a creamy pistachio sauce    mild  Prep 10 mins   11604
# 1                         Bhindi with Amchoor  medium  Prep 10 mins   49899
# 2              Chicken in Creamy Almond Sauce    mild  Prep 10 mins  115569
# 3                        Sabut Masoor di Dhal  medium  Prep 10 mins  146798
# 4                       Healthy Chicken Curry  medium  Prep 10 mins  262696
# ..                                        ...     ...           ...     ...
# 144                        Channa Chaul Tikki  medium  Prep 10 mins   12641
# 145                      Mixed Vegetable Rice  medium  Prep 10 mins   69937
# 146    Indian Style Watermelon and Feta Salad  medium  Prep 40 mins   16652
# 147                         Shama with relish  medium   Prep 5 mins   11808
# 148              Middle Eastern Coriander Dip  medium   Prep 5 mins   67834
#
#      Rating  Number of Votes  Serves       Dietary Info Cook Time  \
# 0       4.1             18.0     4.0  ['CONTAINS-NUTS']   30 mins
# 1       4.6             35.0     4.0     ['VEGETARIAN']   15 mins
# 2       3.6            163.0     4.0  ['CONTAINS-NUTS']   20 mins
# 3       3.7             87.0     4.0     ['VEGETARIAN']   20 mins
# 4       3.5            343.0     4.0   ['LACTOSE-FREE']   40 mins
# ..      ...              ...     ...                ...       ...
# 144     4.2              9.0     4.0     ['VEGETARIAN']   15 mins
# 145     4.0             15.0     4.0     ['VEGETARIAN']   20 mins
# 146     4.4             11.0     6.0     ['VEGETARIAN']   15 mins
# 147     4.0              7.0     2.0   ['LACTOSE-FREE']   20 mins
# 148     3.7              3.0     4.0     ['VEGETARIAN']    5 mins
#
#                                            Ingredients  \
# 0    1) 600g chicken thighs, cut into chunks\n2) 10...
# 1    1) 500g okra\n2) 3 tbsp mustard oil\n3) 1 onio...
# 2    1) 6-8 tbsp natural yoghurt\n2) 1 tsp turmeric...
# 3      1) 200g brown lentils\n2) Approx. 1L of water\n
# 4    1) 8 pieces of chicken (4 legs cut into thigh ...
# ..                                                 ...
# 144  1) 200g cooked and cooled wild rice\n2) 200g t...
# 145  1) 50g peas\n2) 1 carrot (diced small)\n3) 100...
# 146  1) 250g atta\n2) salt pinch\n3) 1 tsp ajwain\n...
# 147  1) 2 whole sea bream (sea bass fillets if you ...
# 148  1) 4 cloves garlic, roughly chopped\n2) 2 bunc...
#
#                                           Instructions
# 0    1) Boil enough water to cover the pistachios, ...
# 1    1) Wash and thoroughly dry the okra (kitchen r...
# 2    1) Grind your whole spices in a spice grinder....
# 3    1) Place the lentils in the pressure cooker wi...
# 4    1) Skin the chicken, removing any excess fat.\...
# ..                                                 ...
# 144  1) Cook the rice as per the instructions on th...
# 145  1) Wash the rice until water runs clear and se...
# 146  1) Add the flour to a bowl and mix in the salt...
# 147  1) Heat your oven to 180ºC\n2) Remove any scal...
# 148  1) Toast the cardamom and cumin until fragrant...
#
# [149 rows x 12 columns]

# %% [markdown]
# - Dataset 7 does not have ingredients, will skip this set

# %% [markdown]
# ### [Dataset 8 (set8-d)](https://www.kaggle.com/datasets/ai-first/cocktail-ingredients)
#  - Collaborators for data: AIFirst, K Scott Mader
#  - Start of our cocktail sets
#   - Viable

# %%
data8 = pd.read_csv(f'{file_path}set8-d/all_drinks.csv')
data8.head()
# Out:
#    Unnamed: 0                              strDrink         dateModified  \
# 0           0  '57 Chevy with a White License Plate  2016-07-18 22:49:04
# 1           1                        1-900-FUK-MEUP  2016-07-18 22:27:04
# 2           2                      110 in the shade  2016-02-03 14:51:57
# 3           3                151 Florida Bushwacker  2016-07-18 22:28:43
# 4           4                           155 Belmont  2016-10-05 12:36:28
#
#    idDrink strAlcoholic           strCategory  \
# 0    14029    Alcoholic              Cocktail
# 1    15395    Alcoholic                  Shot
# 2    15423    Alcoholic                  Beer
# 3    14588    Alcoholic  Milk / Float / Shake
# 4    15346    Alcoholic              Cocktail
#
#                                        strDrinkThumb             strGlass  \
# 0  http://www.thecocktaildb.com/images/media/drin...       Highball glass
# 1  http://www.thecocktaildb.com/images/media/drin...  Old-fashioned glass
# 2  http://www.thecocktaildb.com/images/media/drin...           Beer Glass
# 3  http://www.thecocktaildb.com/images/media/drin...             Beer mug
# 4  http://www.thecocktaildb.com/images/media/drin...     White wine glass
#
#   strIBA  strIngredient1  ... strMeasure15 strMeasure2      strMeasure3  \
# 0    NaN  Creme de Cacao  ...          NaN       1 oz
# 1    NaN  Absolut Kurant  ...          NaN     1/4 oz           1/4 oz
# 2    NaN           Lager  ...          NaN     1.5 oz
# 3    NaN      Malibu rum  ...          NaN     1/2 oz   1/2 oz Bacardi
# 4    NaN        Dark rum  ...          NaN    2 shots           1 shot
#
#    strMeasure4  strMeasure5  strMeasure6 strMeasure7 strMeasure8 strMeasure9  \
# 0                                                            NaN         NaN
# 1      1/4 oz       1/4 oz       1/4 oz      1/2 oz      1/4 oz
# 2                                                            NaN         NaN
# 3        1 oz         1 oz         3 oz        1 oz       1 cup
# 4      1 shot
#
#   strVideo
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 41 columns]

# %%
data8.columns
# Out:
# Index(['Unnamed: 0', 'strDrink', 'dateModified', 'idDrink', 'strAlcoholic',
#        'strCategory', 'strDrinkThumb', 'strGlass', 'strIBA', 'strIngredient1',
#        'strIngredient10', 'strIngredient11', 'strIngredient12',
#        'strIngredient13', 'strIngredient14', 'strIngredient15',
#        'strIngredient2', 'strIngredient3', 'strIngredient4', 'strIngredient5',
#        'strIngredient6', 'strIngredient7', 'strIngredient8', 'strIngredient9',
#        'strInstructions', 'strMeasure1', 'strMeasure10', 'strMeasure11',
#        'strMeasure12', 'strMeasure13', 'strMeasure14', 'strMeasure15',
#        'strMeasure2', 'strMeasure3', 'strMeasure4', 'strMeasure5',
#        'strMeasure6', 'strMeasure7', 'strMeasure8', 'strMeasure9', 'strVideo'],
#       dtype='object')

# %%
columns_to_combine = ['strIngredient1',
       'strIngredient10', 'strIngredient11', 'strIngredient12',
       'strIngredient13', 'strIngredient14', 'strIngredient15',
       'strIngredient2', 'strIngredient3', 'strIngredient4', 'strIngredient5',
       'strIngredient6', 'strIngredient7', 'strIngredient8', 'strIngredient9']
dataset8 = pd.DataFrame()
dataset8['id'] = data8['idDrink']
dataset8['ingredients'] = data8[columns_to_combine].apply(lambda row: row.tolist(), axis = 1)
dataset8.head()
# Out:
#       id                                        ingredients
# 0  14029  [Creme de Cacao, nan, nan, nan, nan, nan, nan,...
# 1  15395  [Absolut Kurant, nan, nan, nan, nan, nan, nan,...
# 2  15423  [Lager, nan, nan, nan, nan, nan, nan, Tequila,...
# 3  14588  [Malibu rum, nan, nan, nan, nan, nan, nan, Lig...
# 4  15346  [Dark rum, nan, nan, nan, nan, nan, nan, Light...

# %%
dataset8['ingredients'] = dataset8['ingredients'].apply(pf.remove_nans_from_list)
dataset8
# Out:
#         id                                        ingredients
# 0    14029                            [Creme de Cacao, Vodka]
# 1    15395  [Absolut Kurant, Grand Marnier, Chambord raspb...
# 2    15423                                   [Lager, Tequila]
# 3    14588  [Malibu rum, Light rum, 151 proof rum, Dark Cr...
# 4    15346         [Dark rum, Light rum, Vodka, Orange juice]
# ..     ...                                                ...
# 541  14065                          [Amaretto, Rum, Kool-Aid]
# 542  14594               [Cointreau, Lemon juice, Ice, Lemon]
# 543  15691  [Beer, Root beer, Lemonade, Coca-Cola, 7-Up, C...
# 544  16963                                      [Vodka, Ouzo]
# 545  15328  [Sambuca, Bailey's irish cream, White Creme de...
#
# [546 rows x 2 columns]

# %% [markdown]
# ### [Dataset 9 (set9-d)](https://www.kaggle.com/datasets/shuyangli94/cocktails-hotaling-co)
#  - This dataset contains cocktails collected by alcohol importer and distiller Hotaling & Co.
#  - Viable

# %%
data9 = pd.read_csv(f'{file_path}set9-d/hotaling_cocktails - Cocktails.csv')
data9.head()
# Out:
#                Cocktail Name          Bartender      Bar/Company  \
# 0             Flor de Amaras     Kelly McCarthy              NaN
# 1            The Happy Place  Elizabeth Montana  Forgery & Verso
# 2     Bon Voyage Pisco Punch        Jon Morales              NaN
# 3  Still Life of a Pineapple    Daniel Braganca          Backbar
# 4        The Bittered Valley         Nik Virrey              NaN
#
#         Location                                        Ingredients  \
# 0         Boston  1.5 oz Mezcal, 1 oz Hibiscus Simple Syrup*, .5...
# 1  San Francisco  2 oz Junipero Gin, .75 oz House-made Cranberry...
# 2  San Francisco  1500 ml BarSol Selecto Italia Pisco, 750 ml Le...
# 3     Somerville  1.5 oz BarSol Primero Quebranta Pisco, .75 oz ...
# 4        Seattle  1.25 oz Luxardo Maraschino Liqueur, 4 drops Ac...
#
#                                      Garnish   Glassware  \
# 0                            Marigold Petals         NaN
# 1  Dehydrated Lemon Wheel, Sprig of Rosemary         NaN
# 2                                        NaN  Punch Bowl
# 3                                        NaN         NaN
# 4                                        NaN         NaN
#
#                                          Preparation  \
# 0  *Hibiscus Simple Syrup:\n1:1 w/ a cup of dried...
# 1  *House-made Cranberry syrup: \n-- 2 cups Fresh...
# 2  *Pineapple Gomme: \nMix equal parts (1.5 cups)...
# 3  *Pineapple Syrup:\n<em>Equal parts pineapple b...
# 4  1st glass ingredients:\nLuxardo Maraschino, Ac...
#
#                                               Notes
# 0                                               NaN
# 1  Junipero Gin 20th Anniversary Signature Cocktail
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %%
print(data9['Ingredients'].head(5).apply(type))
# Out:
# 0    <class 'str'>
# 1    <class 'str'>
# 2    <class 'str'>
# 3    <class 'str'>
# 4    <class 'str'>
# Name: Ingredients, dtype: object

# %%
dataset9 = pd.DataFrame()
dataset9['id'] = data9.index
dataset9['ingredients'] = data9['Ingredients'].apply(lambda x: x.split(", "))
display(dataset9)
dataset9['ingredients'] = dataset9['ingredients'].apply(lambda x: pf.remove_stop_words(x, stop_words))
display(dataset9.head())
dataset9.info()
# Out:
#       id                                        ingredients
# 0      0  [1.5 oz Mezcal, 1 oz Hibiscus Simple Syrup*, ....
# 1      1  [2 oz Junipero Gin, .75 oz House-made Cranberr...
# 2      2  [1500 ml BarSol Selecto Italia Pisco, 750 ml L...
# 3      3  [1.5 oz BarSol Primero Quebranta Pisco, .75 oz...
# 4      4  [1.25 oz Luxardo Maraschino Liqueur, 4 drops A...
# ..   ...                                                ...
# 682  682  [1.5 oz Luxardo Bitter Bianco, .75 oz Tempus F...
# 683  683  [1.5 oz H by HINE, .5 oz Jamaican Rum, 1 tsp C...
# 684  684  [1 oz Luxardo Bitter Bianco, 1 oz Lustau Oloro...
# 685  685  [2 oz Rye Whiskey, 5 oz Punt e Mes, .5 oz Luxa...
# 686  686  [.75 oz Luxardo Maraschino Liqueur, .75 oz Gre...
#
# [687 rows x 2 columns]
#    id                                        ingredients
# 0   0  [oz Mezcal, oz Hibiscus Simple Syrup, oz Lime ...
# 1   1  [oz Junipero Gin, oz Housemade Cranberry Syrup...
# 2   2  [ml BarSol Selecto Italia Pisco, ml Lemon Juic...
# 3   3  [oz BarSol Primero Quebranta Pisco, oz Dry Ver...
# 4   4  [oz Luxardo Maraschino Liqueur, drops Acid pho...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 687 entries, 0 to 686
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           687 non-null    int64
#  1   ingredients  687 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 10.9+ KB

# %%
pf.counting(dataset9['ingredients'])
# Out:
# Counter({'oz Lemon Juice': 88,
#          'oz Kings Ginger Liqueur': 78,
#          'oz Luxardo Maraschino Liqueur': 77,
#          'oz Junipero Gin': 75,
#          'oz No London Dry Gin': 69,
#          'dash Angostura Bitters': 55,
#          'oz H HINE': 47,
#          'oz Lime Juice': 46,
#          'oz Fresh Lemon Juice': 44,
#          'oz Pink Pigeon Rum': 35,
#          'oz Simple Syrup': 35,
#          'oz Simple syrup': 31,
#          'oz Luxardo Bitter Bianco': 30,
#          'oz Luxardo Sangue Morlacco Cherry Liqueur': 29,
#          'oz Lemon juice': 29,
#          'oz Luxardo Amaretto di Saschira': 28,
#          'oz Mezcal': 25,
#          'oz Fresh Lime Juice': 25,
#          'oz Karlssons Gold Vodka': 25,
#          'oz Luxardo Amaro Abano': 24,
#          'oz Luxardo Triplum Triple Sec': 22,
#          'oz Luxardo Apricot Liqueur': 21,
#          'oz Hophead Vodka': 19,
#          'dash Orange Bitters': 19,
#          'oz Tempus Fugit Alessio Vermouth di Torino Rosso': 18,
#          'oz Luxardo Bitter': 17,
#          'oz Dry Vermouth': 16,
#          'oz Glenrothes Vintage Reserve': 16,
#          'oz BarSol Primero Quebranta Pisco': 15,
#          'oz Green Chartreuse': 15,
#          'oz Lime juice': 15,
#          'oz Chinaco Blanco Tequila': 15,
#          'oz Nikka Whisky Taketsuru Pure Malt  YO': 15,
#          'oz Fresh lime juice': 14,
#          'dash Angostura bitters': 14,
#          'oz Nikka Coffey Grain Whisky': 14,
#          'oz Luxardo Fernet': 13,
#          'oz Pineapple Juice': 13,
#          'oz Luxardo Aperitivo': 13,
#          'oz Fresh lemon juice': 13,
#          'oz Egg White': 12,
#          'oz Old Tom Gin': 12,
#          'Egg White': 12,
#          'dash Tempus Fugit Abbotts Bitters': 11,
#          'oz BarSol Perfecto Amor Aperitif Wine': 11,
#          'oz Hirsch Small Batch Reserve Bourbon': 11,
#          'dash Peychauds Bitters': 11,
#          'oz Lemon': 10,
#          'oz Tempus Fugit Kina LAero dOr': 10,
#          'oz Velvet Falernum': 10,
#          'oz C Drouin Calvados Selection': 10,
#          'oz Tempus Fugit Alessio Vermouth Bianco': 10,
#          'oz Grapefruit Juice': 10,
#          'oz Luxardo Limoncello': 10,
#          'oz Lime': 9,
#          'oz BarSol Selecto Italia Pisco': 9,
#          'oz Egg white': 9,
#          'oz Maurin Quina': 9,
#          'oz Orange Juice': 8,
#          'oz Benedictine': 8,
#          'oz Pages Elderflower Syrup': 8,
#          'oz Bourbon': 7,
#          'oz Small Hand Foods Pineapple Gum Syrup': 7,
#          'oz Fresh Grapefruit Juice': 7,
#          'oz Campari': 7,
#          'oz Prosecco': 7,
#          'whole Egg': 7,
#          'oz Chinaco Reposado Tequila': 7,
#          'oz Cranberry Juice': 6,
#          'oz Honey Syrup': 6,
#          'oz Rye Whiskey': 6,
#          'ml Pink Pigeon Rum': 6,
#          'oz Agave Nectar': 6,
#          'ml Kings Ginger Liqueur': 6,
#          'oz Orgeat': 6,
#          'oz Grenadine': 6,
#          'oz Honey': 6,
#          'oz St Germain': 5,
#          'oz Ypioca Brasilizar Cachaca Prata Reserva Especial': 5,
#          'oz Gin': 5,
#          'oz Old Potrero Straight Rye Whiskey': 5,
#          'bsp Luxardo Maraschino Liqueur': 5,
#          'dash Bittermens Xocolatl Mole Bitters': 5,
#          'oz The Genuine Curacao Liqueur Orange': 5,
#          'oz Genevieve Gin': 5,
#          'dash Celery Bitters': 5,
#          'Egg white': 5,
#          'oz Cocchi Americano': 5,
#          'oz Orange juice': 5,
#          'oz Oloroso Sherry': 5,
#          'Tbsp Sugar': 5,
#          'oz Ypiòca': 5,
#          'oz English Harbour Rum': 5,
#          'oz Heavy Cream': 5,
#          'muddled': 5,
#          'Raspberries': 5,
#          'oz Punt e Mes': 5,
#          'dash Bitters': 5,
#          'oz Lillet Blanc': 4,
#          'dash Absinthe': 4,
#          'oz Cointreau': 4,
#          'oz Champagne': 4,
#          'Mint Leaves': 4,
#          'oz Pineapple juice': 4,
#          'oz Sweet Vermouth': 4,
#          'dash Lemon Bitters': 4,
#          'oz Club soda': 4,
#          'oz Ypioca Brasilizar Cachaca Prata Classica': 4,
#          'oz Club Soda': 4,
#          'Mint leaves': 4,
#          'oz Chateau de Montifaud Pineau des Charentes Blanc': 4,
#          'oz The Genuine Curacao Liqueur Blue': 4,
#          'oz Elderflower Liqueur': 4,
#          'oz FeverTree Tonic Water': 4,
#          'oz Ginger Beer': 4,
#          'oz Apple Cider': 4,
#          'dash Chocolate Bitters': 4,
#          'oz Christmas Spirit': 4,
#          'oz Tempus Fugit Gran Classico Bitter': 4,
#          'oz Honey syrup': 4,
#          'oz C Drouin Pommeau de Normandie': 4,
#          'dash Mole Bitters': 4,
#          'oz Cynar': 4,
#          'oz Falernum': 4,
#          'oz BarSol Supremo Moste Verde Italia Pisco': 4,
#          'oz Tempus Fugit Liqueur de Violettes': 4,
#          'oz Fresh grapefruit juice': 4,
#          'oz Cream': 4,
#          'oz Aperol': 4,
#          'oz Soda Water': 4,
#          'oz Luxardo Orgeat Syrup': 4,
#          'oz Vodka': 4,
#          'dash Regans Orange Bitters': 4,
#          'oz Dolin Dry Vermouth': 4,
#          'oz Briottet Creme de Banane': 4,
#          'oz Luxardo Espresso Italian Liqueur': 3,
#          'oz Dry Curacao': 3,
#          'dash Orange bitters': 3,
#          'oz Dubonnet Rouge': 3,
#          'dash Grapefruit Bitters': 3,
#          'top Ginger Beer': 3,
#          'oz Tonic Water': 3,
#          'top Ginger Ale': 3,
#          'splash Soda Water': 3,
#          'fill Champagne': 3,
#          'oz Chateau de Montifaud Pineau des Charentes Rose': 3,
#          'oz Topo Chico Mineral Water': 3,
#          'part No London Dry Gin': 3,
#          'oz St Germaine Elderflower Liqueur': 3,
#          'dash Luxardo Maraschino Liqueur': 3,
#          'top Sparkling Wine': 3,
#          'oz Ginger Syrup': 3,
#          'oz BarSol Pisco': 3,
#          'oz Carpano Antica': 3,
#          'oz Demerara Syrup': 3,
#          'oz Milk': 3,
#          'juiced': 3,
#          'part Fresh Lime Juice': 3,
#          'oz Lustau Amontillado Sherry': 3,
#          'oz St Elizabeth Allspice Dram': 3,
#          'float Ginger beer': 3,
#          'oz Chinaco Anejo Tequila': 3,
#          'oz Yellow Chartreuse': 3,
#          'Basil Leaves': 3,
#          'dash Simple Syrup': 3,
#          'oz Blanco Tequila': 3,
#          'oz Brandy': 3,
#          'oz Tempus Fugit Creme de Cacao': 3,
#          'oz Cocchi Americano Rosa': 3,
#          'oz Condensed milk': 3,
#          'pinch Salt': 3,
#          'oz Grapefruit juice': 3,
#          'oz Pineapple Gomme Syrup': 3,
#          'oz Bols Genever': 3,
#          'oz Aged Rum': 3,
#          'oz Small Hand Foods Orgeat': 3,
#          'top Soda Water': 2,
#          'ml Lemon Juice': 2,
#          'oz Manzanilla Sherry': 2,
#          'top Tonic': 2,
#          'oz Cognac': 2,
#          'dash Fennel Bitters': 2,
#          'oz Denizen Aged White Rum': 2,
#          'oz FeverTree Lemonade': 2,
#          'oz BenRiach Curiositas Single Malt  YO': 2,
#          'oz Briottet Creme de Mure Blackberry': 2,
#          'oz Coconut Rum': 2,
#          'oz Blood Orange Juice': 2,
#          'dash Apple Bitters': 2,
#          'oz Rich Simple Syrup': 2,
#          'oz Applejack': 2,
#          'oz Pineau des Charentes': 2,
#          'dash Vieux Pontarlier Absinthe Francaise Superieure': 2,
#          'oz Mexican Coca Cola': 2,
#          'oz Hot Water': 2,
#          'dash Cinnamon Tincture': 2,
#          'part Briottet Creme de Cassis': 2,
#          'oz Chateau de Montifaud Cognac VSOP': 2,
#          'dash Regans Orange Bitters No': 2,
#          'oz Pear Brandy': 2,
#          'oz Fino Sherry': 2,
#          'cube Brown Sugar': 2,
#          'oz Bacardi Superior Rum': 2,
#          'oz Cannella Cinnamon Cordial': 2,
#          'oz Curacao': 2,
#          'dash Rhubarb Bitters': 2,
#          'oz Coconut Water': 2,
#          'fill Soda Water': 2,
#          'oz Vanilla Syrup': 2,
#          'oz Rose Wine': 2,
#          'oz Agave Syrup': 2,
#          'oz English Harbour Rum  YO': 2,
#          'oz  YO Sherry': 2,
#          'oz Luxardo Cherry Syrup jar cherries': 2,
#          'oz Montelobos Mezcal': 2,
#          'oz Giffard Pamplemousse': 2,
#          'oz Salers Gentiane Aperitif': 2,
#          'bsp Luxardo Amaro Abano': 2,
#          'oz Bonal': 2,
#          'oz Coconut Milk': 2,
#          'oz Coconut Cream': 2,
#          'oz Pomegranate Juice': 2,
#          'Cinnamon': 2,
#          'grated': 2,
#          'Strawberries': 2,
#          'oz JH Cutter Whisky': 2,
#          'oz Soda water': 2,
#          'dash Black Walnut Bitters': 2,
#          'dash Angostura Orange Bitters': 2,
#          'oz Pineapple Gum': 2,
#          'tincture Peychauds Bitters': 2,
#          'dash Fee Brothers Black Walnut Bitters': 2,
#          'oz HINE Rare VSOP': 2,
#          'oz Cocchi Vermouth di Torino': 2,
#          'float Ginger Beer': 2,
#          'oz Absinthe': 2,
#          'oz Light Rum': 2,
#          'top Club Soda': 2,
#          'dash Luxardo Fernet': 2,
#          'oz Briottet Creme de Framboise Raspberry': 2,
#          'oz Angostura Bitters': 2,
#          'ml Egg white': 2,
#          'oz Cinnamon Syrup': 2,
#          'oz Fresh orange juice': 2,
#          'Lime': 2,
#          'oz DAristi Xtabentun Honey Liqueur': 2,
#          'oz Tonic water': 2,
#          'part Agave': 2,
#          'part Ypioca Brasilizar Cachaca Prata Reserva Especial': 2,
#          'oz Drambuie': 2,
#          'dash Bittermens Elemakule Tiki Bitters': 2,
#          'c Orange Juice': 2,
#          'Allspice Berries': 2,
#          'Cloves': 2,
#          'tsp Demerara Sugar': 2,
#          'dash Miracle Mile Forbidden Barrel Aged Bitters': 2,
#          'bsp Benedictine': 2,
#          'Passion fruit': 2,
#          'dash Fee Brothers Aztec Chocolate Bitters': 2,
#          'part Kings Ginger Liqueur': 2,
#          'oz Housemade Orgeat': 2,
#          'leaves Mint leaves': 2,
#          'oz Vanilla flavored Vodka': 2,
#          'oz Fresh sweet n sour mix': 2,
#          'oz Creme de Cacao': 2,
#          'splash Club Soda': 2,
#          'oz Cinnamon honey syrup': 2,
#          'oz Hard Apple Cider': 2,
#          'oz Cream Coconut': 2,
#          'dash The Bitter Truth Orange Bitters': 2,
#          'Cucumber slices': 2,
#          'dash Aromatic Bitters': 2,
#          'pieces Ginger root': 2,
#          'oz Peach Puree': 2,
#          'oz Sparkling Wine': 2,
#          'oz Mint sprigs': 2,
#          'Kumquats': 2,
#          'Lemon Peel': 2,
#          'Whole Egg': 2,
#          'oz Cola': 2,
#          'oz Pear flavored Vodka': 2,
#          'oz Cranberry juice': 2,
#          'oz Fresh lime sweet n sour mix': 2,
#          'top FeverTree Tonic Water': 2,
#          'oz Triple Sec': 2,
#          'Ice Cubes': 2,
#          'oz Sugar Syrup': 2,
#          'Fresh Mint': 2,
#          'ml Luxardo Maraschino Liqueur': 2,
#          'ml Luxardo Sangue Morlacco Cherry Liqueur': 2,
#          'rinse Vieux Pontarlier Absinthe Francaise Superieure': 2,
#          'oz The Genuine Curacao Liqueur Clear': 2,
#          'float Tonic Water': 2,
#          'oz Monin Cane Syrup': 2,
#          'oz Fresh Lemon': 2,
#          'oz Fresh sweet n sour': 2,
#          'oz Passion fruit puree': 2,
#          'oz Lustau East India Solera': 2,
#          'oz Small Hand Foods Gum Syrup': 2,
#          'oz FeverTree Soda': 2,
#          'oz Rittenhouse Straight Rye Whisky': 2,
#          'dash Chocolate bitters': 2,
#          'oz Fresh Squeezed Lemon Juice': 2,
#          'tsp Demerara Syrup': 2,
#          'bottle Kings Ginger Liqueur': 2,
#          'Star Anise': 2,
#          'ml bottle Karlssons Gold Vodka': 2,
#          'oz Tempus Fugit Alessio Vermouth Chinato': 2,
#          'oz Dolin Rouge Vermouth': 2,
#          'oz Pedro Ximenez Sherry': 2,
#          'oz Giffard Banane du Brésil': 2,
#          'oz Peychauds Bitters': 2,
#          'oz Luxardo Angioletto Hazelnut Liqueur': 2,
#          'top Soda': 2,
#          'oz Hibiscus Simple Syrup': 1,
#          'oz Housemade Cranberry Syrup': 1,
#          'dash Forgery Earth Day Bitters': 1,
#          'mist Laphroaig': 1,
#          'ml BarSol Selecto Italia Pisco': 1,
#          'ml Pineapple Gomme Syrup': 1,
#          'oz Fee Bros Lemon Bitters': 1,
#          'float Old Vine Zin': 1,
#          'oz Pineapple Syrup': 1,
#          'bsp Vieux Pontarlier Absinthe Francaise Superieure': 1,
#          'drops Acid phosphate': 1,
#          'dash Scrappys Aromatic Bitters': 1,
#          'oz Housemade Simple Syrup': 1,
#          'Sugar Snap Peas': 1,
#          'oz Ginger Liqueur': 1,
#          'oz Pure Cane Simple Syrup': 1,
#          'count Deschutes Fresh Squeezed IPA tap': 1,
#          'oz Homemade milk chocolate': 1,
#          'oz Hazelnut Cinnamon syrup': 1,
#          'oz Marshmallow whip cream': 1,
#          'oz Ginger snaps': 1,
#          'oz Jasmine TeaRiceInfused Junipero Gin': 1,
#          'oz Leopold Bros Sour Apple Liqueur': 1,
#          'oz Housemade Honey Syrup': 1,
#          'oz LoFi Gentian Amaro': 1,
#          'dash Salted Chocolate Bitters': 1,
#          'oz Monin Strawberry Puree': 1,
#          'oz Lemon Sour': 1,
#          'oz Lemon Lime Soda': 1,
#          'Basil Leaf': 1,
#          'dash Rose Water': 1,
#          'oz Lime Sour': 1,
#          'oz Monin Apple Puree': 1,
#          'oz Banks  Rum': 1,
#          'dash Fee Brothers Rhubard bitters': 1,
#          'c Junipero Gin': 1,
#          'c C Drouin Calvados Selection': 1,
#          'c Lemon Juice': 1,
#          'c GingerVanilla Syrup': 1,
#          'bottle Sparkling Rose': 1,
#          'oz Osha Falernum': 1,
#          'oz Elder Flower Liquor': 1,
#          'oz Carrot Juice': 1,
#          'top Pear Cider': 1,
#          'oz Single Malt Scotch': 1,
#          'top Anchor California Lager': 1,
#          'oz Junmai Sake': 1,
#          'dash Coconut Vinegar': 1,
#          'oz Cherry Herring': 1,
#          'oz Fresh Egg White': 1,
#          'oz Brokers Gin': 1,
#          'oz Celery Root Puree': 1,
#          'oz Fresh Passion Fruit': 1,
#          'oz Condense Milk': 1,
#          'oz Brown Sugar Syrup': 1,
#          'oz Egg Whites': 1,
#          'oz High West Oat Whisky': 1,
#          'oz Peach Shrub': 1,
#          'oz Sweetened Condensed Milk': 1,
#          'oz Passion Fruit fresh puree': 1,
#          'oz Pilon Syrup': 1,
#          'oz Banks  Island Rum': 1,
#          'tsp Vieux Pontarlier Absinthe Francaise Superieure': 1,
#          'oz PineappleInfused Mezcal': 1,
#          'oz Strawberry Syrup': 1,
#          'splash FernetBranca': 1,
#          'float Luxardo Fernet': 1,
#          'oz Liqueur de Violette': 1,
#          'oz Bourbon Rye': 1,
#          'oz Coldpressed Apple Cider': 1,
#          'oz HoneyGinger Syrup': 1,
#          'tsp GhostPepperInfused Campari': 1,
#          'oz East Imperial Superior Tonic': 1,
#          'Assorted Complementing Botanicals': 1,
#          'oz BarSol Selecto Acholado Pisco': 1,
#          'drops Angostura Bitters': 1,
#          'part Chilled Dry Champagne': 1,
#          'part Chilled Dry White Wine': 1,
#          'oz Citrus Agave Blend': 1,
#          'oz Plymouth Gin': 1,
#          'oz Contratto Bianco Vermouth': 1,
#          'oz House Ginger Beer': 1,
#          'oz John D Taylors Velvet Falernum': 1,
#          'Cucumber wheels': 1,
#          'Mint sprig': 1,
#          'oz Ginger beer': 1,
#          'oz Dolin Genepy': 1,
#          'oz Leopold Bros Bitter': 1,
#          'Red Hawaiian Salt': 1,
#          'oz F Meyer Mirabelle Yellow Plum': 1,
#          'oz Horchata': 1,
#          'oz Glenrothes': 1,
#          'dash Honey': 1,
#          'soaked Peychauds Bitters': 1,
#          'oz Avuá Prata Cachaça': 1,
#          'oz London Dry Gin': 1,
#          'dash Citric Acid': 1,
#          'drops Orange Flower Water': 1,
#          'oz Vermouth del Professore': 1,
#          'dash St George Absinthe': 1,
#          'part Real Cranberry Juice': 1,
#          'part Luxardo Fernet': 1,
#          'part Lime juice': 1,
#          'part Puer Black Tea': 1,
#          'oz Watermelon': 1,
#          'Lemon Juice': 1,
#          'oz Wild Turkey  Bourbon': 1,
#          'oz Strawberry': 1,
#          'Black Pepper Balsamic Shrub': 1,
#          'oz Clarified Milk': 1,
#          'drops Vanilla': 1,
#          'drops Cranberry Bitters': 1,
#          'oz Cold Blue Bottle Coffee': 1,
#          'oz Luxardo Anisette': 1,
#          'oz Tempus Fugit Alessio Vino Chinato': 1,
#          'oz FigInfused C Drouin Calvados Selection': 1,
#          'ml FeverTree Bitter Lemon': 1,
#          'oz Fresh Squeezed Pineapple Juice': 1,
#          'oz Fresh Coconut Water': 1,
#          'dashes Dr Adams Bokers bitters': 1,
#          'oz Rich Cane Syrup': 1,
#          'dash Cinnamon Bitters': 1,
#          'ml Amer Picon': 1,
#          'ml House Cola Syrup': 1,
#          'oz Squeeze Lime': 1,
#          'oz Italian Sparkling Water': 1,
#          'splash Sparkling Water': 1,
#          'oz FeverTree Indian Tonic': 1,
#          'scoop Vanilla Ice Cream': 1,
#          'oz Martini  Rossi Sweet Vermouth': 1,
#          'oz Blended Scotch': 1,
#          'top Hot Water': 1,
#          'oz LemonJuice': 1,
#          'oz Monin French Raspberry Syrup': 1,
#          'oz Nikka Coffey Grain Whiskey': 1,
#          'oz Tempus Fugit Creme de Noyaux': 1,
#          'oz Heavy Whipping Cream': 1,
#          'oz Grahams  Year Tawny Port': 1,
#          'oz Ale': 1,
#          'drops Dale DeGroffs Pimento Aromatic Bitters': 1,
#          'oz Rich Wild Sage Honey Syrup': 1,
#          'dash Whiskey Barrel Aged Bitters': 1,
#          'oz Spring Water': 1,
#          'oz Blanc Vermouth': 1,
#          'oz Housemade Yellow Shawtreuse': 1,
#          'oz Tonic': 1,
#          'dash Coriander Tincture': 1,
#          'oz Round Pond Blood Orange Syrup': 1,
#          'splash Sparkling Wine': 1,
#          'oz Round Pond Meyer Lemon Syrup': 1,
#          'splash Soda water': 1,
#          'oz Rhubarb Infused Gin': 1,
#          'Soda': 1,
#          'oz Old Forester Bourbon': 1,
#          'oz Giffard Crème de Pêche de Vigne': 1,
#          'oz Honey syrup local honey cut  water': 1,
#          'oz Tomato Juice': 1,
#          'tsp Demitris Bloody Mary Seasoning': 1,
#          'oz Freshpressed Lemon Juice': 1,
#          'oz Snake Oils Housemade Sarsaparilla Syrup': 1,
#          'oz Carbonated Water': 1,
#          'dash Snake Oils Housemade Pomegranate Bitters': 1,
#          'oz Apricot brandy': 1,
#          'oz Dry vermouth': 1,
#          'oz Sweet vermouth': 1,
#          'Salt': 1,
#          'oz Lacuesta Blanco Vermouth': 1,
#          'bsp GermainRobin Absinthe': 1,
#          'dash Scrappy’s Lime Bitters': 1,
#          'oz Apricot EaudeVie': 1,
#          'oz NoriInfused Sake': 1,
#          'dash Islay Scotch': 1,
#          'oz Nocino': 1,
#          'oz Glenrothes Bourbon Reserve': 1,
#          'oz Chamomile Tea Syrup': 1,
#          'part Gin': 1,
#          'part Luxardo Apricot Liqueur': 1,
#          'part Casoni': 1,
#          'part Dry Vermouth': 1,
#          'part Unfiltered Apple Juice': 1,
#          'part Fresh Lemon Juice': 1,
#          'part Rich Simple Syrup': 1,
#          'part Jasmine Green Tea': 1,
#          'Gin Barrel Aged Orange Bitters': 1,
#          'Fresh Basil Leaves': 1,
#          'oz Ypioca Brasilizar Cachaca Ouro Reserva Especial': 1,
#          'oz JalapenoOrange Simple Syrup': 1,
#          'dash Orange Flower Water': 1,
#          'drops Mole Bitters': 1,
#          'oz Don Ciccio  Figli Concerto': 1,
#          'oz Vanilla Marinade': 1,
#          'oz Amontillado Sherry': 1,
#          'bsp Tempus Fugit Creme de Noyaux': 1,
#          'oz Penny Blue Mauritian Rum': 1,
#          'dash Celery Shrub': 1,
#          'dash Housemade Tarragon Tincture': 1,
#          'oz Orange Liquor': 1,
#          'oz Housemade Spiced Pumpkin Puree': 1,
#          'top Apple Cider': 1,
#          'oz Zirbenz Stone Pine': 1,
#          'oz Fresh Strawberry Juice w Xanthan Gum': 1,
#          'oz Ca Secco Sparkling': 1,
#          'bsp Luxardo Cherry Syrup': 1,
#          'oz Perfect Puree Apricot': 1,
#          'oz Honey Syrup  honey  water': 1,
#          'Nutmeg': 1,
#          'Cherries': 1,
#          'Watermelon': 1,
#          'cube': 1,
#          'oz Bay Leaf Syrup': 1,
#          'dash Salt Tincture': 1,
#          'oz Rhubarb Cucumber  MintInfused Junipero Gin': 1,
#          'oz Rhubarb Juice': 1,
#          'oz Rhubarb Syrup': 1,
#          'dash Fee Brothers Celery Bitters': 1,
#          'dash Fee Bros Rhubarb bitters': 1,
#          'oz Averna Amaro': 1,
#          'oz Alvear PX Sherry': 1,
#          'oz Honey Jalapeño syrup': 1,
#          'oz Olive Juice': 1,
#          'dash Dry Vermouth': 1,
#          'dash Fee Brothers Gin Barrel Aged Bitters': 1,
#          'oz Pear Sage Foam': 1,
#          'float Prosecco': 1,
#          'oz Jack Daniels': 1,
#          'oz Cane Sugar Syrup': 1,
#          'oz Noilly Prat Ambre Vermouth': 1,
#          'oz Rich Simple': 1,
#          'float Dry Sparkling Wine': 1,
#          'oz Averna': 1,
#          'oz El Tesoro Reposado Tequila': 1,
#          'oz Grüner Veltliner': 1,
#          'bsp Sweet Marmalade': 1,
#          'oz Gran Duque Alba Solera gran Reserva brandy': 1,
#          'oz Carpano Antica Vermouth': 1,
#          'tincture Angostura bitters': 1,
#          'oz Esprit de June': 1,
#          'oz Citadelle Gin': 1,
#          'oz Rose Poached Pear Syrup': 1,
#          'oz FeverTree Sparkling Lemon': 1,
#          'oz Marrakesh Mint Tea': 1,
#          'oz Dale DeGroffs Pimento Aromatic Bitters': 1,
#          'oz Moroccan Mint Tea chilled': 1,
#          'oz The Kings Ginger': 1,
#          'oz Rich Honey Syrup': 1,
#          'bsp Kalani Coconut Liqueur': 1,
#          'oz Orangescented Maple Syrup': 1,
#          'fill Anchor California Lager': 1,
#          'oz H HINE Brown ButterInfused': 1,
#          'top IPA': 1,
#          'oz Breckles Brown Ale': 1,
#          'oz Bywater Spice Mix': 1,
#          'oz ColdBrew Coffee': 1,
#          'dash Fee Brothers Orange Bitters': 1,
#          'oz Barr Hill Gin': 1,
#          'oz Winter Spice Brown Sugar Syrup': 1,
#          'oz Barolo Chinato': 1,
#          'oz Reisetbauer Carrot Eau De Vie': 1,
#          'part Rooibus Tea steeped cooled': 1,
#          'part Mulled Cider cooled': 1,
#          'part Clover Honey Syrup': 1,
#          'part Cava': 1,
#          'Angostura': 1,
#          'oz Nikka Whisky Miyagikyo Single Malt  YO': 1,
#          'oz Rare Wine Co Charleston Sercial Madeira': 1,
#          'oz Small Hands Food orgeat': 1,
#          'oz Clover Honey Syrup': 1,
#          'oz Pimms': 1,
#          'bsp Luxardo Amaretto di Saschira': 1,
#          'leaves Basil leaves': 1,
#          'oz BenRiach Single Malt  YO': 1,
#          'bsp Calisaya': 1,
#          'dash The Bitter Truth Grapefruit Bitters': 1,
#          'oz Dolin Blanc': 1,
#          'oz Castilian Tincture': 1,
#          'oz Avua Cachaca Prata': 1,
#          'oz Brokers London Dry Gin': 1,
#          'dash Toasted Coconut Tincture': 1,
#          'dash Almond Extract': 1,
#          'top FeverTree Mediterranean Tonic Water': 1,
#          'oz Apple Water': 1,
#          'ml Citric Acid Solution': 1,
#          'oz Daristi  YR Rum': 1,
#          'oz Tahitian Vanilla Bean Syrup': 1,
#          'oz Hot coffee': 1,
#          'oz Homemade Irish Cream': 1,
#          'oz Simple Syrup optional': 1,
#          'tincture Grapefruit bitters': 1,
#          'oz Giffard Elderflower Liqueur': 1,
#          'drops Chili Tincture': 1,
#          'Luxardo Maraschino Cherries': 1,
#          'oz CocaCola': 1,
#          'oz Domingo Perez Marin la Guita Manzanilla Sherry': 1,
#          'oz Chartreuse': 1,
#          'oz Juice Orange': 1,
#          'oz Absolut Vodka': 1,
#          'oz GingerCinnamon Syrup': 1,
#          'dash Bar Keep Lavender Spice Bitters': 1,
#          'pieces Lime': 1,
#          'dash Peach bitters': 1,
#          'oz Pear  Celery Puree': 1,
#          'spoon Sugar': 1,
#          'oz Sweetened Apple Cider': 1,
#          'dash Baked Apple Bitters': 1,
#          'oz Hibiscusrose syrup': 1,
#          'oz Jummai Ginjo Sake': 1,
#          'oz Dill Cordial': 1,
#          'oz Meyer Lemon Juice': 1,
#          'oz Yuzu Juice': 1,
#          'oz Fresh egg White': 1,
#          'ml Dry Oloroso Sherry': 1,
#          'VanillaSalt Spray': 1,
#          'ml Campari': 1,
#          'ml Lavender syrup': 1,
#          'ml Lemon juice': 1,
#          'ml Orange juice': 1,
#          'oz El Dorado  Year Old Rum': 1,
#          'oz Hamilton Black Jamaican Pot Still Rum': 1,
#          'tsp St Elizabeth Allspice Dram': 1,
#          'top Founders Porter': 1,
#          'Tbsp Luxardo Bitter': 1,
#          'dash Milk powder cream': 1,
#          'oz Peach Brandy': 1,
#          'Pink Peppercorns': 1,
#          'ml Fresh lemon juice': 1,
#          'ml Gomme syrup': 1,
#          'oz Giffard Abricot du Roussillon': 1,
#          'oz Jalapeño Syrup': 1,
#          'oz Cinnamon': 1,
#          'oz Reeds Premium Ginger Brew': 1,
#          'tsp Seedless Blackberry Jam': 1,
#          'oz Blended Lightly Aged Rum': 1,
#          'oz Blended Aged Rum': 1,
#          'oz SC Demerara Syrup': 1,
#          'oz Fresh Lemon Juice optional': 1,
#          'oz Prichards Lincoln County Lightning': 1,
#          'oz CinnamonCandied Ginger Syrup': 1,
#          'oz Japanese Whisky': 1,
#          'oz Amaro Angeleno': 1,
#          'float Bitter Lemon Soda': 1,
#          'oz White dry whitepreferably Sauvignon': 1,
#          'oz Jamaica basil flower syrup': 1,
#          'part Ypioca Brasilizar Cachaca Prata Classica': 1,
#          'part Ancho Reyes Ancho Chile Liqueur': 1,
#          'part Lillet Rose': 1,
#          'part Guava Nectar': 1,
#          'top Banfi Rosa Regale Sparkling Wine': 1,
#          'oz Fresh Cantaloupe Juice': 1,
#          'oz Beet Sugar Water': 1,
#          'oz Darjeeling simple syrup': 1,
#          'oz Spice Syrup': 1,
#          'oz FeverTree Tonic': 1,
#          'bottle Lager': 1,
#          'bsp Real Lemon Juice': 1,
#          'bsp StrawberryRaspberry Simple Syrup': 1,
#          'oz Woodchuck Pumpkin Cider': 1,
#          'oz Spiced Butter': 1,
#          'pkg': 1,
#          'oz Cranberries': 1,
#          'c Brown Sugar': 1,
#          'c Kings Ginger Liqueur': 1,
#          'whole Pepper Corns': 1,
#          'stick': 1,
#          'oz White Rum': 1,
#          'Roasted Cherries': 1,
#          'oz Black Rum': 1,
#          'tsp Everclear': 1,
#          'oz Karlssons Gold Vodka CoffeeInfused': 1,
#          'oz Café Moka': 1,
#          'oz Cardamom syrup': 1,
#          'Tbsp Soy milk coffee foam': 1,
#          'pinch Espresso powder': 1,
#          'oz Karlssons Gold Vodka RootInfused': 1,
#          'oz Cardamaro': 1,
#          'oz GradeA dark maple syrup': 1,
#          'oz Fentemans ginger beer': 1,
#          'inch Whole licorice root': 1,
#          'oz Burned Demerara Sugar Syrup': 1,
#          'tincture Bobs Vanilla Bitters': 1,
#          'oz Vanilla Powder': 1,
#          'oz Rothman  Winter Orchard Pear Liqueur': 1,
#          'tincture Fee Brothers Cranberry Bitters': 1,
#          'Fresh Cranberries': 1,
#          'oz Boiron Kalamansi Juice': 1,
#          'oz Thai Basil Syrup': 1,
#          'oz Fentimans Ginger Beer': 1,
#          'oz OatmealInfused Karlssons Gold Vodka': 1,
#          'oz Molasses': 1,
#          'bsp Pumpkin Puree': 1,
#          'tincture Fee Brothers Black Walnut Bitters': 1,
#          'oz Kaffir lime  tamarind compound syrup': 1,
#          'oz Apple  CinnamonInfused Karlssons Gold Vodka': 1,
#          'oz J T Taylors Falernum': 1,
#          'oz Fresh Cider': 1,
#          'tincture Bar Keep Baked apple bitters': 1,
#          'oz Lemon curd large bar spoon': 1,
#          'oz Brut Champagne': 1,
#          'oz Spiced apple shrub': 1,
#          'oz Chilled club soda': 1,
#          'oz Homemade orgeat': 1,
#          'dash Fee Bros Orange bitters': 1,
#          'ml No London Dry Gin': 1,
#          'ml Red Vermouth Antica Formula': 1,
#          'ml Good quality sharp lemonade': 1,
#          'oz Raspberrywhite pepper syrup': 1,
#          'oz Fresh cucumber juice': 1,
#          'pc Fresh mint': 1,
#          'dashes Celery bitters': 1,
#          'oz Apple Cider Reduction': 1,
#          'oz CinnamonChipotle Syrup': 1,
#          'dash Housemade Apple Pie Bitters': 1,
#          'ml Lychee juice': 1,
#          'oz Xtabentun Liqueur honey': 1,
#          'anis': 1,
#          'part Red Vermouth Antica Formula': 1,
#          'part Good quality sharp lemonade': 1,
#          'oz Spiced Apricot Syrup': 1,
#          'Egg Whites': 1,
#          'top Anchor Christmas Ale': 1,
#          'Strawberry': 1,
#          'oz Sliced plum': 1,
#          'sprigs Mint sprig': 1,
#          'oz Nikka Coffey Malt Whisky': 1,
#          'Lime Wedges': 1,
#          'oz Dolin Vermouth': 1,
#          'oz Pomegranate Syrup': 1,
#          'large Mint Leaves': 1,
#          'oz Pierre Ferrand Dry Orange Curacao': 1,
#          'dash The Bitter Truth Jerry Thomas Bitters': 1,
#          'oz Heavy cream': 1,
#          'drops Agave Nectar': 1,
#          'cubes Sugar': 1,
#          'oz Root  Cherry Almond Simple Syrup': 1,
#          'oz Nigori sake Unfiltered': 1,
#          'oz Fresh Shibori Yuzu juice': 1,
#          'oz Simple syrup  sugar water': 1,
#          'pc Thai chili': 1,
#          'sprigs Fresh cilantro stems': 1,
#          'oz Potato juice': 1,
#          'bsp Black pepper': 1,
#          'bsp Salt': 1,
#          'Half Small Cucumber': 1,
#          'Medium Carrot': 1,
#          'Green Apple': 1,
#          'cored': 1,
#          'Kale Leaves': 1,
#          'Big Handful Spinach Leaves': 1,
#          'Small Hunk Ginger': 1,
#          'oz Pastis Prado': 1,
#          'oz Fresh pressed Apple Cider': 1,
#          'stick Cinnamon stick': 1,
#          'oz Prickly Pear Puree': 1,
#          'oz Agave': 1,
#          'oz Fresh pineapple juice': 1,
#          'dashes Angostura bitters': 1,
#          'c Pink Pigeon Rum': 1,
#          'c Pineapple Juice': 1,
#          'c Ginger Ale': 1,
#          'c Grenadine': 1,
#          'FreshSqueezed Lime Juice': 1,
#          'oz Compas Box Great King Street Blended Scotch Whisky': 1,
#          'oz Byrrh Grand Quinquina': 1,
#          'oz Anchor Christmas Ale': 1,
#          'dash Bittercube Corazon Bitters': 1,
#          'oz Oloroso  Moscatel Blend': 1,
#          'dash The Bitter Truth Xocolate Bitters': 1,
#          'Walnut Oil': 1,
#          'oz Perfect Puree White Peach': 1,
#          'oz Batavia Arrack': 1,
#          'oz Bay LeafInfused Honey Syrup': 1,
#          'oz Clovers Gingersnap': 1,
#          'pinch Cinnamon': 1,
#          'part Junipero Gin': 1,
#          'part Campari': 1,
#          'part Sweet Vermouth': 1,
#          'oz Sparkling Apple Juice': 1,
#          'oz Seltzer': 1,
#          'oz Walnut Liqueur': 1,
#          'dash Pear Bitters': 1,
#          'oz No London Dry Gin H HINE': 1,
#          'float Sparkling Wine': 1,
#          'oz Minta Soda': 1,
#          'pinch Citric Acid Lime Juice': 1,
#          'scoop Pineapple Sorbet': 1,
#          'oz Ginger Brown': 1,
#          'dash Hella hula bitters': 1,
#          'beans Cocao beans': 1,
#          'large Basil Leaves': 1,
#          'whole Black Peppercorns': 1,
#          'oz Cane sugar syrup': 1,
#          'oz Orange Cordial': 1,
#          'bsp Luxardo Sangue Morlacco Cherry Liqueur': 1,
#          'Luxardo Cherry muddled': 1,
#          'dash Cherry Bitters': 1,
#          'Sun Gold Cherry Tomatoes': 1,
#          'Lovage Leaves': 1,
#          'oz Agave Syrup  agave water': 1,
#          'pinch Hepps Ghost Pepper Salt': 1,
#          'oz Tipplemans Barrel Smoked Maple Syrup': 1,
#          'disc Orange': 1,
#          'disc Lemon': 1,
#          'slice Peach': 1,
#          'bsp El Guapo Tonic Syrup': 1,
#          'dash El Guapo Tonic Bitters': 1,
#          'Cucumber Slices': 1,
#          'Mint Sprig': 1,
#          'oz Fresh Ginger Syrup': 1,
#          'slice Orange slice': 1,
#          'dash Chinese Five Spice Bitters': 1,
#          'dash Housemade Rasta Bitters': 1,
#          'pieces Chopped pineapple': 1,
#          'pieces Pineapple': 1,
#          'pieces Red bell pepper': 1,
#          'oz Breck Bourbon': 1,
#          'oz Dancing Pines Black Walnut Bourbon': 1,
#          'oz Wild Hibiscus Tea': 1,
#          'top Sparkling Water': 1,
#          'Roasted Cherry': 1,
#          'oz CherryInfused Vodka': 1,
#          'tsp Amaro di Angostura': 1,
#          'tsp Luxardo Maraschino Liqueur': 1,
#          'spg Basil': 1,
#          'oz Luxardo Sour Cherry Syrup Previously Amarena': 1,
#          'float Mango Flavored Rum': 1,
#          'Kiwi': 1,
#          'Lychee': 1,
#          'oz Bulleit Rye': 1,
#          'oz Fever Tree Ginger Beer': 1,
#          'large chunks Pineapple': 1,
#          'oz White Port': 1,
#          'oz Honey Cinnamon Syrup': 1,
#          'Muddled Sage Leaves': 1,
#          'dash Simple syrup': 1,
#          'oz New York Apple Whiskey': 1,
#          'oz Lemongrass ginger syrup': 1,
#          'oz Sweetened Condensed Coconut Milk': 1,
#          'oz Almond Milk': 1,
#          'handful Fresh Raspberries': 1,
#          'dash Rubarb Bitters': 1,
#          'oz Nikka Whisky Yoichi Single Malt  YO': 1,
#          'cubes Tonic Water Ice Cubes': 1,
#          'Concord grapes': 1,
#          'Blackberries': 1,
#          'oz Crème Yvette': 1,
#          'oz Garrison Brothers Flagship Bourbon': 1,
#          'dash Australian Bitters Company Aromatic Bitters': 1,
#          'Lime wedges': 1,
#          'Pinapple wheel': 1,
#          'oz Gomme syrup': 1,
#          'float Pisco': 1,
#          'oz Lime Sweet n Sour mix': 1,
#          'oz Cucumber wheels': 1,
#          'oz Sprigs Mint': 1,
#          'oz Rhum Agricolestyle': 1,
#          'oz Brandy de Jerez': 1,
#          'sprigs Mint': 1,
#          'float Luxardo Amaretto di Saschira': 1,
#          'Fresh Thyme': 1,
#          'ml Champagne': 1,
#          'oz Mai Tai Mix': 1,
#          'float English Harbour Rum': 1,
#          'oz Sherry': 1,
#          'oz Watermelon Liqueur': 1,
#          'oz Bonded Rye': 1,
#          'oz DOM Benedictine': 1,
#          'fill Club Soda': 1,
#          'oz Brandy de Jerez Foie GrasInfused': 1,
#          'drops Truffle Tincture': 1,
#          'Atomized Pipe Tobacco Essence': 1,
#          'oz Pierre Ferrand Curaçao': 1,
#          'oz Gordy’s Cocktail Pickle Brine': 1,
#          'oz Watermelon Juice': 1,
#          'oz Cherry Brandy': 1,
#          'tsp Lemon Juice': 1,
#          'Simple Syrup': 1,
#          'oz Ginger Citrus Agave Blend': 1,
#          'oz Ginger Ale': 1,
#          'wedge Lemon juice': 1,
#          'top FeverTree Ginger Ale': 1,
#          'lemon Lemon': 1,
#          'fill Tonic water': 1,
#          'top Steam Beer': 1,
#          'oz Chateau de Montifaud Cognac VS': 1,
#          'oz Orgeat Almond Syrup': 1,
#          'top Lemonade': 1,
#          'oz Chateau de Montifaud Cognac XO': 1,
#          'oz Chateau de Montifaud XO Silver': 1,
#          'tsp Extra Dry Vermouth': 1,
#          'Amalfi Lemon': 1,
#          'oz Grapefruit flavored Vodka': 1,
#          'float Pomegranate liqueur': 1,
#          'scoop Lemon sorbet': 1,
#          'scoop Blood orange sorbet': 1,
#          'oz Chateau de Montifaud Reserve Speciale Michel Vallet': 1,
#          'oz Chocolate Liqueur': 1,
#          'oz Heavy cream flavored Hum Liqueur': 1,
#          'coffee spoon Sugar Syrup': 1,
#          'Sliced Green Lemon': 1,
#          'oz Sparkling Water': 1,
#          'oz SageCilantroLime Syrup': 1,
#          'rinse Montanaro Vermouth': 1,
#          'Pomegranate Ice Cube': 1,
#          'oz HoneyPear Liqueur': 1,
#          'oz Pinch Cardamom': 1,
#          'oz Dehydrated pear slice': 1,
#          'ml Bitter': 1,
#          'ml Bourbon': 1,
#          'part Ancho ChileInfused Simple Syrup': 1,
#          'oz Coconut milk': 1,
#          'oz Peach Juice': 1,
#          'cube Brown sugar': 1,
#          'splash Bitter': 1,
#          'tsp Simple Syrup': 1,
#          'strip Cucumber': 1,
#          'dash Lemon Juice': 1,
#          'rinse Eau de Vie': 1,
#          'oz Braulio Amaro': 1,
#          'oz Vieux Pontarlier Absinthe Francaise Superieure': 1,
#          'tsp Sugar': 1,
#          'ml Gin': 1,
#          'ml Luxardo Orgeat Syrup': 1,
#          'oz Seersucker Gin': 1,
#          'oz Sauternes': 1,
#          'dash Orange Blossom Water': 1,
#          'slices Satsuma slices': 1,
#          'oz Sioux City Sarsparilla Soda': 1,
#          'oz GingerCardamomHoney Syrup': 1,
#          'oz Fresh Apple Juice': 1,
#          'oz Serrano Pepper Syrup': 1,
#          'oz Mango Juice': 1,
#          'ml Fresh lime': 1,
#          'slice Fresh ginger': 1,
#          'strawberries Strawberriesmuddled': 1,
#          'dash Dr Adams Bokers bitters': 1,
#          'oz Chinaco Reposado': 1,
#          'dash Fire Damnation bitters': 1,
#          'splash Club soda': 1,
#          'oz Housemade Allspice Dram': 1,
#          'oz Hangar  Buddhas Hand Citron Vodka': 1,
#          'tsp Giffard Banane du Brésil': 1,
#          'tsp Honey Syrup': 1,
#          'oz Funkin Passion Fruit Puree': 1,
#          'oz Fresh squeezed lime': 1,
#          'leaves Mint Leaves': 1,
#          'oz Lemon Verbena Cordial': 1,
#          'top Mixwell Young Ginger Ale': 1,
#          'oz Rich Brown Sugar Simple Syrup': 1,
#          'Large Pieces Candied Ginger': 1,
#          'oz Orange marmalade syrup': 1,
#          'oz Bergamot tea foam': 1,
#          'oz White peach puree': 1,
#          'oz Hibiscus syrup': 1,
#          'oz Ginger ale': 1,
#          'oz Mandarine Napoleon': 1,
#          'oz Castelvetrano Olive Brine': 1,
#          'oz Sathenay Crème de Peche': 1,
#          'oz  Dashes Orange Bitters': 1,
#          'splash Lemon Juice': 1,
#          'splash Orange Juice': 1,
#          'oz Fresh Ruby Red Grapefruit Juice': 1,
#          'oz Cream Half  Half': 1,
#          'dash Angostura bitters optional': 1,
#          'oz Vanilla Agave Nectar': 1,
#          'oz Seltzer Water': 1,
#          'oz Pressed Apple Juice': 1,
#          'tsp Triple Sec': 1,
#          'Tbsp Lime Juice': 1,
#          'oz Lavander syrup': 1,
#          'oz Citrusflavored Vodka': 1,
#          'dash Fee Bros Rhubard Bitters': 1,
#          'dash Green Tabasco': 1,
#          'oz Lemorton Pommeau de Normandie': 1,
#          'oz Housemade Green Apple Purée': 1,
#          'oz Ancho Reyes Chile Liqueur': 1,
#          'oz Aviation Gin': 1,
#          'dash Bittercube Bitters Jamaican': 1,
#          'oz FeverTree Ginger Beer': 1,
#          'ml Monkey Shoulder Blended Scotch Whisky': 1,
#          'ml Mezcal': 1,
#          'ml Agave Syrup': 1,
#          'ml Lime Juice': 1,
#          'top Prosecco': 1,
#          'ml H HINE': 1,
#          'ml Calvados': 1,
#          'ml Tempus Fugit Alessio Vermouth Bianco': 1,
#          'oz Grand Marnier': 1,
#          ...})

# %% [markdown]
# ### [Dataset 10 (set10-d)](https://www.kaggle.com/datasets/aadyasingh55/cocktails)
#  - Collaborators for data: Aadya Singh
#  - Viable

# %%
data10 = pd.read_csv(f'{file_path}set10-d/final_cocktails.csv')
data10.head()
# Out:
#    Unnamed: 0  id  name  alcoholic        category       glassType  \
# 0           0   0    A1  Alcoholic        Cocktail  Cocktail glass
# 1           1   1   ABC  Alcoholic            Shot      Shot glass
# 2           2   2   Ace  Alcoholic        Cocktail   Martini Glass
# 3           3   3  ACID  Alcoholic            Shot      Shot glass
# 4           4   4  Adam  Alcoholic  Ordinary Drink  Cocktail glass
#
#                                         instructions  \
# 0  Pour all ingredients into a cocktail shaker, m...
# 1                           Layered in a shot glass.
# 2  Shake all the ingredients in a cocktail shaker...
# 3  Poor in the 151 first followed by the 101 serv...
# 4  In a shaker half-filled with ice cubes, combin...
#
#                                       drinkThumbnail  \
# 0  https://www.thecocktaildb.com/images/media/dri...
# 1  https://www.thecocktaildb.com/images/media/dri...
# 2  https://www.thecocktaildb.com/images/media/dri...
# 3  https://www.thecocktaildb.com/images/media/dri...
# 4  https://www.thecocktaildb.com/images/media/dri...
#
#                                          ingredients  \
# 0  ['Gin', 'Grand Marnier', 'Lemon Juice', 'Grena...
# 1      ['Amaretto', 'Baileys irish cream', 'Cognac']
# 2  ['Gin', 'Grenadine', 'Heavy cream', 'Milk', 'E...
# 3                   ['151 proof rum', 'Wild Turkey']
# 4           ['Dark rum', 'Lemon juice', 'Grenadine']
#
#                                   ingredientMeasures  \
# 0  ['1 3/4 shot ', '1 Shot ', '1/4 Shot', '1/8 Sh...
# 1                           ['1/3 ', '1/3 ', '1/3 ']
# 2  ['2 shots ', '1/2 shot ', '1/2 shot ', '1/2 sh...
# 3                         ['1 oz Bacardi ', '1 oz ']
# 4                       ['2 oz ', '1 oz ', '1 tsp ']
#
#                                                 text
# 0  question Generate a cocktail with Gin Grand Ma...
# 1  question Generate a cocktail with Amaretto Bai...
# 2  question Generate a cocktail with Gin Grenadin...
# 3  question Generate a cocktail with 151 proof ru...
# 4  question Generate a cocktail with Dark rum Lem...

# %%
dataset10 = pd.DataFrame()
dataset10['id'] = data10['id']
dataset10['ingredients'] = data10['ingredients'].apply(lambda x: pf.convert_to_list(x))
display(dataset10.head())
dataset10.info()
# Out:
#    id                                     ingredients
# 0   0    [Gin, Grand Marnier, Lemon Juice, Grenadine]
# 1   1         [Amaretto, Baileys irish cream, Cognac]
# 2   2  [Gin, Grenadine, Heavy cream, Milk, Egg White]
# 3   3                    [151 proof rum, Wild Turkey]
# 4   4              [Dark rum, Lemon juice, Grenadine]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425 entries, 0 to 424
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           425 non-null    int64
#  1   ingredients  425 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 6.8+ KB

# %% [markdown]
# ### [Dataset 11 (set11-d)](https://www.kaggle.com/datasets/laurinbrechter/cocktail-popularity)
#  - Collaborators for data: Laurin Brechter
#  - Non-Viable

# %%
data11 = pd.read_csv(f'{file_path}set11-d/data.csv')
data11.head()
# Out:
#    Unnamed: 0 place                name  year  month  visitors
# 0           0    1            '57 Chevy  2001  total      1512
# 1           1    2           Caipirinha  2001  total      1301
# 2           2    3   Long Island Icetea  2001  total       903
# 3           3    4          Piña Colada  2001  total       601
# 4           4    5          Tall Blonde  2001  total       573

# %% [markdown]
#  - Dataset 11 has no relevant data

# %% [markdown]
# ### [Dataset 12 (set12-d)](https://www.kaggle.com/datasets/jenlooper/mr-boston-cocktail-dataset)
#  - Collaborators for data: Jen Looper
#  - Viable

# %%
data12 = pd.read_csv(f'{file_path}set12-d/mr-boston-flattened.csv')
data12.head()
# Out:
#                    name               category measurement-1  \
# 0               Gauguin      Cocktail Classics          2 oz
# 1       Fort Lauderdale      Cocktail Classics      1 1/2 oz
# 2             Apple Pie  Cordials and Liqueurs          3 oz
# 3  Cuban Cocktail No. 1      Cocktail Classics        1/2 oz
# 4           Cool Carlos      Cocktail Classics      1 1/2 oz
#
#        ingredient-1 measurement-2          ingredient-2 measurement-3  \
# 0         Light Rum          1 oz   Passion Fruit Syrup          1 oz
# 1         Light Rum        1/2 oz        Sweet Vermouth        1/4 oz
# 2    Apple schnapps          1 oz     Cinnamon schnapps           NaN
# 3   Juice of a Lime        1/2 oz        Powdered Sugar          2 oz
# 4          Dark rum          2 oz       Cranberry Juice          2 oz
#
#        ingredient-3 measurement-4      ingredient-4 measurement-5  \
# 0       Lemon Juice          1 oz        Lime Juice           NaN
# 1   Juice of Orange        1/4 oz   Juice of a Lime           NaN
# 2       Apple slice           NaN               NaN           NaN
# 3         Light Rum           NaN               NaN           NaN
# 4   Pineapple Juice          1 oz    Orange curacao          1 oz
#
#   ingredient-5 measurement-6 ingredient-6  \
# 0          NaN           NaN          NaN
# 1          NaN           NaN          NaN
# 2          NaN           NaN          NaN
# 3          NaN           NaN          NaN
# 4     Sour Mix           NaN          NaN
#
#                                         instructions                glass  \
# 0  Combine ingredients with a cup of crushed ice ...  Old-Fashioned Glass
# 1  Shake with ice and strain into old-fashioned g...  Old-Fashioned Glass
# 2  Pour into ice-filled old-fashioned glass. Garn...  Old-Fashioned Glass
# 3    Shake with ice and  strain into cocktail glass.       Cocktail Glass
# 4  Mix all ingredients except curacao with ice, s...        Collins Glass
#
#          glass-size
# 0     6 to 8 ounces
# 1     6 to 8 ounces
# 2     6 to 8 ounces
# 3  6 or more ounces
# 4   14 to 16 ounces

# %%
display(data12.info())
data12.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           990 non-null    object
#  1   category       990 non-null    object
#  2   measurement-1  980 non-null    object
#  3   ingredient-1   989 non-null    object
#  4   measurement-2  955 non-null    object
#  5   ingredient-2   987 non-null    object
#  6   measurement-3  847 non-null    object
#  7   ingredient-3   894 non-null    object
#  8   measurement-4  600 non-null    object
#  9   ingredient-4   584 non-null    object
#  10  measurement-5  307 non-null    object
#  11  ingredient-5   321 non-null    object
#  12  measurement-6  71 non-null     object
#  13  ingredient-6   159 non-null    object
#  14  instructions   990 non-null    object
#  15  glass          985 non-null    object
#  16  glass-size     979 non-null    object
# dtypes: object(17)
# memory usage: 131.6+ KB
# None
# Index(['name', 'category', 'measurement-1', 'ingredient-1', 'measurement-2',
#        'ingredient-2', 'measurement-3', 'ingredient-3', 'measurement-4',
#        'ingredient-4', 'measurement-5', 'ingredient-5', 'measurement-6',
#        'ingredient-6', 'instructions', 'glass', 'glass-size'],
#       dtype='object')

# %%
columns_to_combine = ['ingredient-1', 'ingredient-2', 'ingredient-3', 'ingredient-4', 'ingredient-5', 'ingredient-6']
dataset12 = pd.DataFrame()
dataset12['id'] = data12.index
dataset12['ingredients'] = data12[columns_to_combine].apply(lambda row: row.tolist(), axis = 1)
dataset12['ingredients'] = dataset12['ingredients'].apply(pf.remove_nans_from_list)
dataset12
# Out:
#       id                                        ingredients
# 0      0  [ Light Rum,  Passion Fruit Syrup,  Lemon Juic...
# 1      1  [ Light Rum,  Sweet Vermouth,  Juice of Orange...
# 2      2  [ Apple schnapps,  Cinnamon schnapps,  Apple s...
# 3      3    [ Juice of a Lime,  Powdered Sugar,  Light Rum]
# 4      4  [ Dark rum,  Cranberry Juice,  Pineapple Juice...
# ..   ...                                                ...
# 985  985  [Lime wedge, superfine sugar,  Gin,  Triple Se...
# 986  986  [ Juice of Orange,  Dry Vermouth,  Sweet Vermo...
# 987  987                 [ Gin,  Dry Vermouth,  Triple Sec]
# 988  988              [ Gin,  Triple Sec,  Pineapple Juice]
# 989  989  [ Gin,  Grapefruit Juice,  Fresh Lime Juice,  ...
#
# [990 rows x 2 columns]

# %% [markdown]
# ### [Dataset 13 (set13-d)](https://www.kaggle.com/datasets/kashishparmar02/cocktailcrazedataset)
#  - Collaborators for data: Kashish Parmar
#  - Non-Viable

# %%
data13 = pd.read_csv(f'{file_path}set13-d/data (1).csv')
data13
# Out:
#      Unnamed: 0  idDrink                  strDrink          strCategory  \
# 0             0    17222                        A1             Cocktail
# 1             1    13501                       ABC                 Shot
# 2             2    17225                       Ace             Cocktail
# 3             3    14610                      ACID                 Shot
# 4             4    17837                      Adam       Ordinary Drink
# ..          ...      ...                       ...                  ...
# 421         421    17027              Zima Blaster       Ordinary Drink
# 422         422    14594            Zizi Coin-coin  Punch / Party Drink
# 423         423    15801           Zimadori Zinger  Punch / Party Drink
# 424         424    14065           Zippy's Revenge             Cocktail
# 425         425    14157  Ziemes Martini Apfelsaft       Ordinary Drink
#
#     strAlcoholic                  strGlass        strIngredient1  \
# 0      Alcoholic            Cocktail glass                   Gin
# 1      Alcoholic                Shot glass              Amaretto
# 2      Alcoholic             Martini Glass                   Gin
# 3      Alcoholic                Shot glass         151 proof rum
# 4      Alcoholic            Cocktail glass              Dark rum
# ..           ...                       ...                   ...
# 421    Alcoholic           Hurricane glass                  Zima
# 422    Alcoholic  Margarita/Coupette glass             Cointreau
# 423    Alcoholic             Collins glass  Midori melon liqueur
# 424    Alcoholic       Old-fashioned glass              Amaretto
# 425    Alcoholic             Collins Glass              Vermouth
#
#                  strIngredient2 initial
# 0                 Grand Marnier       A
# 1           Baileys irish cream       A
# 2                     Grenadine       A
# 3                   Wild Turkey       A
# 4                   Lemon juice       A
# ..                          ...     ...
# 421  Chambord raspberry liqueur       Z
# 422                 Lemon juice       Z
# 423                        Zima       Z
# 424                         Rum       Z
# 425                 Apple juice       Z
#
# [426 rows x 9 columns]

# %% [markdown]
#  - Dataset 13 is incomplete with only 2 ingredients per drink it does not have full recipes.

# %% [markdown]
# ### [Dataset 14 (set14-d)](https://www.kaggle.com/datasets/svetlanagruzdeva/cocktails-data)
#  - Collaborators: Svetlana Gruzdeva
#  - Viable

# %%
data14 = pd.read_csv(f'{file_path}set14-d/data_cocktails.csv')
data14
# Out:
#       Unnamed: 0                              strDrink   strCategory  \
# 0              0  '57 Chevy with a White License Plate      Cocktail
# 1              1  '57 Chevy with a White License Plate      Cocktail
# 2              2                        1-900-FUK-MEUP          Shot
# 3              3                        1-900-FUK-MEUP          Shot
# 4              4                        1-900-FUK-MEUP          Shot
# ...          ...                                   ...           ...
# 1776        1776                             Zorbatini      Cocktail
# 1777        1777                             Zorbatini      Cocktail
# 1778        1778                                 Zorro  Coffee / Tea
# 1779        1779                                 Zorro  Coffee / Tea
# 1780        1780                                 Zorro  Coffee / Tea
#
#                  strGlass         strIngredients        Alc_type Basic_taste  \
# 0          Highball glass   Creme De Cacao White  Creamy Liqueur         NaN
# 1          Highball glass                  Vodka           Vodka         NaN
# 2     Old-fashioned glass          Grand Marnier      Triple Sec         NaN
# 3     Old-fashioned glass   Midori Melon Liqueur   Sweet Liqueur         NaN
# 4     Old-fashioned glass             Malibu Rum             Rum         NaN
# ...                   ...                    ...             ...         ...
# 1776       Cocktail glass                  Vodka           Vodka         NaN
# 1777       Cocktail glass                   Ouzo            Ouzo         NaN
# 1778           Coffee Mug                Sambuca         Sambuca         NaN
# 1779           Coffee Mug   Bailey'S Irish Cream  Creamy Liqueur         NaN
# 1780           Coffee Mug  White Creme De Menthe   Sweet Liqueur         NaN
#
#                                         strInstructions     strMeasures  \
# 0     1. Fill a rocks glass with ice 2.add white cre...      1 oz white
# 1     1. Fill a rocks glass with ice 2.add white cre...            1 oz
# 2     Shake ingredients in a mixing tin filled with ...          1/4 oz
# 3     Shake ingredients in a mixing tin filled with ...          1/4 oz
# 4     Shake ingredients in a mixing tin filled with ...          1/4 oz
# ...                                                 ...             ...
# 1776  Prepare like a Martini. Garnish with a green o...  1 1/4 oz stoli
# 1777  Prepare like a Martini. Garnish with a green o...          1/4 oz
# 1778  add all and pour black coffee and add whipped ...            2 cl
# 1779  add all and pour black coffee and add whipped ...            2 cl
# 1780  add all and pour black coffee and add whipped ...            2 cl
#
#       Value_ml  Value_gr Garnish_amount Garnish_type
# 0         30.0       NaN            NaN          NaN
# 1         30.0       NaN            NaN          NaN
# 2          7.5       NaN            NaN          NaN
# 3          7.5       NaN            NaN          NaN
# 4          7.5       NaN            NaN          NaN
# ...        ...       ...            ...          ...
# 1776      37.5       NaN            NaN          NaN
# 1777       7.5       NaN            NaN          NaN
# 1778      20.0       NaN            NaN          NaN
# 1779      20.0       NaN            NaN          NaN
# 1780      20.0       NaN            NaN          NaN
#
# [1781 rows x 13 columns]

# %%
dataset14 = pd.DataFrame(data14.groupby('strDrink')['strIngredients'].apply(lambda x: x.tolist())).reset_index()
dataset14['id'] = dataset14.index
dataset14['ingredients'] = dataset14['strIngredients']
dataset14 = dataset14.drop(columns=['strDrink', 'strIngredients'])
display(dataset14.head())
dataset14.info()
# Out:
#    id                                        ingredients
# 0   0                      [Creme De Cacao White, Vodka]
# 1   1  [Grand Marnier, Midori Melon Liqueur, Malibu R...
# 2   2                                   [Tequila, Lager]
# 3   3  [Dark Creme De Cacao, Coconut Liqueur, Light R...
# 4   4         [Light Rum, Orange Juice, Vodka, Dark Rum]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473 entries, 0 to 472
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           473 non-null    int64
#  1   ingredients  473 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 7.5+ KB

# %% [markdown]
# ## Save Datasets:
#  - We will keep the following sets:
#  - Food
#     - Datasets 1/2/3/4
#  - Drinks
#     - Datasets 8/9/10/12/14

# %%
final_food = pd.concat([dataset1, dataset2, dataset3, dataset4], axis = 0)
final_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3053953 entries, 0 to 2231141
# Data columns (total 2 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   ingredients  object
# dtypes: int64(1), object(1)
# memory usage: 69.9+ MB

# %%
final_drink = pd.concat([dataset8, dataset9, dataset10, dataset12, dataset14], axis = 0)
final_drink.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3121 entries, 0 to 472
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           3121 non-null   int64
#  1   ingredients  3121 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 73.1+ KB

# %% [markdown]
#  - With 3 million rows of data for food and only 3000 rows for drinks I expect to get wildly differing results in terms of effectiveness, we may end up combining the two together but I wanted them seperate for now

# %%
final_food.to_csv(f'{file_path}food_full.csv', header=True)
final_drink.to_csv(f'{file_path}drink_full.csv', header=True)

# %%
final_food.to_pickle(f'{file_path}food_full.pkl')
final_drink.to_pickle(f'{file_path}drink_full.pkl')
