# %%
import pandas as pd 
from itertools import combinations
from collections import Counter
import numpy as np
import utils.model_functions as mf

# %% [markdown]
# Load our dataset

# %%
df = pd.read_pickle("../../Data/clean_food.pkl")
df.head()
# Out:
#       id                                        ingredients
# 0  10259  [romaine lettuce, black olives, grape, black p...
# 1  25693  [black pepper, black pepper, thyme, egg, yello...
# 2  20130  [egg, black pepper, mayonnaise, green chili pe...
# 4  13162  [black pepper, shallot, cayenne pepper, onion,...
# 5   6602  [egg, ginger root, cinnamon, milk, vanilla, gi...

# %% [markdown]
# Create our pairs (will use these to build out our similarity matrix)

# %%
df['pairs'] = df['ingredients'].apply(lambda x: list(combinations(x,2)))
df.head()
# Out:
#       id                                        ingredients  \
# 0  10259  [romaine lettuce, black olives, grape, black p...
# 1  25693  [black pepper, black pepper, thyme, egg, yello...
# 2  20130  [egg, black pepper, mayonnaise, green chili pe...
# 4  13162  [black pepper, shallot, cayenne pepper, onion,...
# 5   6602  [egg, ginger root, cinnamon, milk, vanilla, gi...
#
#                                                pairs
# 0  [(romaine lettuce, black olives), (romaine let...
# 1  [(black pepper, black pepper), (black pepper, ...
# 2  [(egg, black pepper), (egg, mayonnaise), (egg,...
# 4  [(black pepper, shallot), (black pepper, cayen...
# 5  [(egg, ginger root), (egg, cinnamon), (egg, mi...

# %% [markdown]
# Build out our pair counts so we can get a matrix

# %%
pair_counts = Counter()
for pairs_list in df['pairs']:
    pair_counts.update(pairs_list)
pair_counts
# Out:
# Counter({('onion', 'black pepper'): 286750,
#          ('egg', 'vanilla'): 255669,
#          ('olives', 'black pepper'): 203958,
#          ('cloves', 'black pepper'): 189311,
#          ('egg', 'milk'): 165382,
#          ('onion', 'cloves'): 160204,
#          ('olives', 'cloves'): 131422,
#          ('egg', 'black pepper'): 108883,
#          ('milk', 'egg'): 105121,
#          ('milk', 'vanilla'): 104064,
#          ('olives', 'onion'): 91723,
#          ('egg', 'cinnamon'): 87941,
#          ('cloves', 'olives'): 82094,
#          ('onion', 'parsley'): 81403,
#          ('black pepper', 'onion'): 76802,
#          ('black pepper', 'olives'): 76594,
#          ('beef', 'onion'): 75377,
#          ('onion', 'egg'): 75120,
#          ('parsley', 'black pepper'): 71847,
#          ('milk', 'black pepper'): 70270,
#          ('chicken', 'black pepper'): 68959,
#          ('onion', 'celery'): 66860,
#          ('black pepper', 'parsley'): 63083,
#          ('lemon juice', 'black pepper'): 63063,
#          ('celery', 'black pepper'): 62624,
#          ('cloves', 'parsley'): 61846,
#          ('olives', 'parsley'): 61709,
#          ('beef', 'black pepper'): 61593,
#          ('vanilla', 'egg'): 60321,
#          ('onion', 'chicken'): 60203,
#          ('onion', 'milk'): 59743,
#          ('black pepper', 'cloves'): 58808,
#          ('onion', 'olives'): 58786,
#          ('carrot', 'black pepper'): 58409,
#          ('potato', 'black pepper'): 57142,
#          ('onion', 'carrot'): 55334,
#          ('cinnamon', 'egg'): 54267,
#          ('onion', 'cheddar cheese'): 52898,
#          ('black pepper', 'egg'): 52614,
#          ('onion', 'chili pepper'): 51750,
#          ('cinnamon', 'nutmeg'): 51265,
#          ('onion', 'oregano'): 50689,
#          ('thyme', 'black pepper'): 50029,
#          ('egg', 'onion'): 49870,
#          ('cinnamon', 'vanilla'): 49483,
#          ('basil', 'black pepper'): 48423,
#          ('egg', 'egg'): 47838,
#          ('olives', 'basil'): 47395,
#          ('onion', 'thyme'): 47315,
#          ('egg', 'pecan'): 45973,
#          ('oregano', 'black pepper'): 45611,
#          ('cloves', 'onion'): 45607,
#          ('black pepper', 'black pepper'): 44893,
#          ('olives', 'lemon juice'): 44392,
#          ('onion', 'green pepper'): 44220,
#          ('cloves', 'basil'): 43751,
#          ('onion', 'cumin'): 43631,
#          ('vanilla', 'cinnamon'): 42047,
#          ('egg', 'cream'): 41628,
#          ('onion', 'worcestershire'): 41560,
#          ('cinnamon', 'cloves'): 41418,
#          ('olives', 'parmesan cheese'): 40972,
#          ('onion', 'bay'): 40954,
#          ('onion', 'basil'): 40892,
#          ('egg', 'nutmeg'): 40885,
#          ('cloves', 'oregano'): 40831,
#          ('celery', 'onion'): 40816,
#          ('black pepper', 'parmesan cheese'): 40693,
#          ('onion', 'mushroom'): 40169,
#          ('potato', 'onion'): 40168,
#          ('cream cheese', 'vanilla'): 40163,
#          ('chicken', 'onion'): 40119,
#          ('onion', 'parmesan cheese'): 40072,
#          ('egg', 'lemon juice'): 39928,
#          ('vanilla', 'milk'): 39237,
#          ('cloves', 'egg'): 39043,
#          ('cloves', 'cumin'): 38526,
#          ('chicken breast', 'black pepper'): 38318,
#          ('olives', 'oregano'): 37559,
#          ('cloves', 'parmesan cheese'): 37392,
#          ('carrot', 'onion'): 36839,
#          ('onion', 'sour cream'): 36833,
#          ('cocoa', 'vanilla'): 36805,
#          ('cloves', 'lemon juice'): 36722,
#          ('cloves', 'chicken'): 36387,
#          ('onion', 'potato'): 36087,
#          ('cloves', 'thyme'): 35816,
#          ('parmesan cheese', 'black pepper'): 35662,
#          ('cumin', 'black pepper'): 35348,
#          ('black pepper', 'milk'): 35306,
#          ('mayonnaise', 'black pepper'): 35209,
#          ('onion', 'beef'): 35180,
#          ('egg', 'nut'): 35010,
#          ('olives', 'thyme'): 34425,
#          ('mushroom', 'black pepper'): 34413,
#          ('egg', 'chocolate'): 34087,
#          ('cloves', 'cilantro'): 33926,
#          ('cream cheese', 'egg'): 33902,
#          ('egg', 'cloves'): 33252,
#          ('cloves', 'red pepper'): 33029,
#          ('egg', 'sour cream'): 32838,
#          ('egg', 'lemon'): 32717,
#          ('milk', 'cinnamon'): 32702,
#          ('chili pepper', 'black pepper'): 32270,
#          ('vanilla', 'pecan'): 31898,
#          ('worcestershire', 'black pepper'): 31680,
#          ('onion', 'lemon juice'): 31632,
#          ('black pepper', 'chicken'): 31382,
#          ('black pepper', 'thyme'): 31043,
#          ('green onion', 'black pepper'): 30906,
#          ('cloves', 'bay'): 30803,
#          ('olives', 'olives'): 30772,
#          ('egg', 'walnut'): 30721,
#          ('paprika', 'black pepper'): 30672,
#          ('onion', 'red pepper'): 30621,
#          ('olives', 'red pepper'): 30459,
#          ('onion', 'cilantro'): 30337,
#          ('black pepper', 'lemon juice'): 30309,
#          ('cloves', 'ginger'): 30046,
#          ('olives', 'chicken'): 29923,
#          ('onion', 'mustard'): 29839,
#          ('onion', 'paprika'): 29741,
#          ('milk', 'cheddar cheese'): 29573,
#          ('black pepper', 'cheddar cheese'): 29534,
#          ('cloves', 'chili pepper'): 29025,
#          ('bacon', 'black pepper'): 29008,
#          ('green pepper', 'black pepper'): 28881,
#          ('olives', 'egg'): 28660,
#          ('ginger', 'cloves'): 28500,
#          ('carrot', 'cloves'): 28330,
#          ('lemon juice', 'olives'): 28302,
#          ('onion', 'vinegar'): 28263,
#          ('egg', 'buttermilk'): 28073,
#          ('soy', 'black pepper'): 28041,
#          ('egg', 'olives'): 27986,
#          ('sour cream', 'black pepper'): 27946,
#          ('milk', 'onion'): 27906,
#          ('onion', 'rice'): 27906,
#          ('bay', 'black pepper'): 27573,
#          ('egg', 'parsley'): 27561,
#          ('carrot', 'celery'): 27310,
#          ('black pepper', 'basil'): 27293,
#          ('red pepper', 'black pepper'): 27198,
#          ('cheddar cheese', 'black pepper'): 26929,
#          ('egg', 'coconut'): 26842,
#          ('vanilla', 'chocolate'): 26781,
#          ('beef', 'egg'): 26485,
#          ('bacon', 'onion'): 26429,
#          ('gram', 'gram'): 26222,
#          ('egg', 'almond'): 26173,
#          ('olives', 'cumin'): 26062,
#          ('vanilla', 'vanilla'): 25906,
#          ('egg', 'cheddar cheese'): 25717,
#          ('parsley', 'olives'): 25683,
#          ('red onion', 'black pepper'): 25666,
#          ('potato', 'milk'): 25578,
#          ('cinnamon', 'milk'): 25453,
#          ('olives', 'wine'): 25407,
#          ('mustard', 'black pepper'): 25367,
#          ('chicken breast', 'onion'): 25041,
#          ('shallot', 'black pepper'): 25038,
#          ('black pepper', 'paprika'): 25029,
#          ('olives', 'lemon'): 25019,
#          ('egg', 'parmesan cheese'): 24861,
#          ('soy', 'sesame seed'): 24843,
#          ('soy', 'ginger'): 24826,
#          ('black pepper', 'oregano'): 24817,
#          ('cloves', 'cinnamon'): 24764,
#          ('olives', 'carrot'): 24447,
#          ('cinnamon', 'ginger'): 24207,
#          ('dijon mustard', 'black pepper'): 24112,
#          ('lemon', 'black pepper'): 23996,
#          ('onion', 'cayenne pepper'): 23932,
#          ('green pepper', 'onion'): 23858,
#          ('cream cheese', 'milk'): 23810,
#          ('olives', 'cilantro'): 23682,
#          ('potato', 'egg'): 23646,
#          ('cream', 'vanilla'): 23322,
#          ('cream', 'black pepper'): 23307,
#          ('nutmeg', 'egg'): 23278,
#          ('lemon juice', 'cloves'): 23196,
#          ('ginger', 'black pepper'): 23188,
#          ('chili pepper', 'cumin'): 23159,
#          ('celery', 'parsley'): 23157,
#          ('beef', 'cloves'): 23078,
#          ('cilantro', 'black pepper'): 22947,
#          ('cloves', 'carrot'): 22934,
#          ('egg', 'raisin'): 22920,
#          ('soy', 'cloves'): 22881,
#          ('egg', 'cream cheese'): 22676,
#          ('lemon', 'lemon juice'): 22369,
#          ('carrot', 'parsley'): 22329,
#          ('vanilla', 'nut'): 22090,
#          ('chicken', 'cloves'): 21905,
#          ('black pepper', 'cilantro'): 21897,
#          ('chicken', 'parsley'): 21729,
#          ('black pepper', 'sour cream'): 21719,
#          ('lemon juice', 'lemon'): 21711,
#          ('basil', 'olives'): 21543,
#          ('cloves', 'wine'): 21452,
#          ('cloves', 'soy'): 21434,
#          ('wine', 'black pepper'): 21422,
#          ('beef', 'chili pepper'): 21408,
#          ('milk', 'nutmeg'): 21314,
#          ('cloves', 'lemon'): 21242,
#          ('celery', 'cloves'): 21127,
#          ('bread', 'egg'): 21097,
#          ('onion', 'ginger'): 20783,
#          ('black pepper', 'cayenne pepper'): 20685,
#          ('cocoa', 'egg'): 20453,
#          ('onion', 'mayonnaise'): 20147,
#          ('black pepper', 'red pepper'): 20142,
#          ('cloves', 'milk'): 20118,
#          ('mushroom', 'onion'): 20108,
#          ('parsley', 'cloves'): 20086,
#          ('egg', 'cocoa'): 20079,
#          ('rosemary', 'black pepper'): 19994,
#          ('onion', 'wine'): 19967,
#          ('vinegar', 'black pepper'): 19897,
#          ('lemon juice', 'parsley'): 19857,
#          ('black pepper', 'carrot'): 19582,
#          ('bread', 'black pepper'): 19555,
#          ('black pepper', 'lemon'): 19544,
#          ('onion', 'soy'): 19531,
#          ('basil', 'parmesan cheese'): 19500,
#          ('chicken breast', 'cloves'): 19397,
#          ('egg', 'bread'): 19333,
#          ('onion', 'onion'): 19333,
#          ('onion', 'mozzarella cheese'): 19204,
#          ('black pepper', 'worcestershire'): 19187,
#          ('milk', 'milk'): 19177,
#          ('egg', 'oatmeal'): 19129,
#          ('sour cream', 'cheddar cheese'): 19046,
#          ('vanilla', 'walnut'): 19038,
#          ('milk', 'cream'): 19036,
#          ('chicken breast', 'olives'): 18899,
#          ('mayonnaise', 'lemon juice'): 18825,
#          ('vanilla', 'cream'): 18801,
#          ('black pepper', 'bay'): 18717,
#          ('mayonnaise', 'onion'): 18674,
#          ('cream cheese', 'sour cream'): 18649,
#          ('chicken', 'milk'): 18557,
#          ('egg', 'ginger'): 18491,
#          ('onion', 'ketchup'): 18442,
#          ('chocolate', 'vanilla'): 18417,
#          ('olives', 'bay'): 18397,
#          ('black pepper', 'green onion'): 18328,
#          ('olives', 'rosemary'): 18323,
#          ('egg', 'banana'): 18203,
#          ('red bell pepper', 'black pepper'): 18188,
#          ('beef', 'cheddar cheese'): 18107,
#          ('celery', 'carrot'): 18066,
#          ('olives', 'red onion'): 18042,
#          ('cloves', 'cloves'): 18037,
#          ('cumin', 'cilantro'): 18036,
#          ('apple', 'cinnamon'): 18015,
#          ('onion', 'cheese'): 18008,
#          ('buttermilk', 'vanilla'): 18007,
#          ('egg', 'semi-sweet chocolate'): 17867,
#          ('cheddar cheese', 'onion'): 17802,
#          ('cheddar cheese', 'egg'): 17782,
#          ('onion', 'cream'): 17655,
#          ('rice', 'black pepper'): 17650,
#          ('basil', 'oregano'): 17580,
#          ('zucchini', 'black pepper'): 17499,
#          ('lemon juice', 'egg'): 17439,
#          ('yellow onion', 'black pepper'): 17205,
#          ('rice', 'onion'): 17185,
#          ('celery', 'chicken'): 17174,
#          ('honey', 'black pepper'): 17155,
#          ('lime juice', 'black pepper'): 17136,
#          ('parsley', 'egg'): 17062,
#          ('onion', 'corn'): 17034,
#          ('olives', 'shallot'): 17020,
#          ('egg', 'mayonnaise'): 17000,
#          ('cocoa', 'milk'): 16993,
#          ('cinnamon', 'raisin'): 16989,
#          ('vanilla', 'coconut'): 16982,
#          ('cloves', 'cayenne pepper'): 16979,
#          ('onion', 'bacon'): 16881,
#          ('cloves', 'paprika'): 16881,
#          ('sour cream', 'onion'): 16873,
#          ('black pepper', 'celery'): 16852,
#          ('milk', 'parmesan cheese'): 16840,
#          ('cloves', 'nutmeg'): 16821,
#          ('onion', 'green bell pepper'): 16764,
#          ('cream', 'egg'): 16532,
#          ('buttermilk', 'egg'): 16503,
#          ('red onion', 'olives'): 16499,
#          ('ginger', 'cinnamon'): 16487,
#          ('pecan', 'vanilla'): 16447,
#          ('onion', 'cinnamon'): 16359,
#          ('chili pepper', 'onion'): 16351,
#          ('lemon', 'egg'): 16341,
#          ('black pepper', 'chili pepper'): 16311,
#          ('red wine vinegar', 'black pepper'): 16252,
#          ('chicken', 'chicken'): 16184,
#          ('parsley', 'lemon juice'): 16151,
#          ('ginger', 'soy'): 16143,
#          ('cheddar cheese', 'milk'): 16125,
#          ('carrot', 'bay'): 16122,
#          ('cloves', 'green onion'): 16100,
#          ('sour cream', 'egg'): 16073,
#          ('carrot', 'thyme'): 16022,
#          ('nutmeg', 'vanilla'): 16020,
#          ('cinnamon', 'allspice'): 16016,
#          ('milk', 'parsley'): 15977,
#          ('beef', 'worcestershire'): 15962,
#          ('onion', 'bell pepper'): 15953,
#          ('black pepper', 'wine'): 15950,
#          ('chicken breast', 'chicken'): 15939,
#          ('chicken', 'celery'): 15925,
#          ('corn', 'black pepper'): 15924,
#          ('black pepper', 'cream'): 15892,
#          ('sour cream', 'vanilla'): 15860,
#          ('cinnamon', 'pecan'): 15856,
#          ('olives', 'chili pepper'): 15818,
#          ('olives', 'celery'): 15815,
#          ('egg', 'mustard'): 15810,
#          ('vanilla', 'nutmeg'): 15778,
#          ('potato', 'carrot'): 15746,
#          ('thyme', 'parsley'): 15733,
#          ('lime juice', 'cilantro'): 15728,
#          ('cayenne pepper', 'black pepper'): 15671,
#          ('black pepper', 'potato'): 15665,
#          ('onion', 'green chili pepper'): 15644,
#          ('parsley', 'onion'): 15595,
#          ('parmesan cheese', 'parsley'): 15554,
#          ('cream cheese', 'onion'): 15510,
#          ('black pepper', 'mushroom'): 15508,
#          ('black pepper', 'cumin'): 15488,
#          ('black pepper', 'mozzarella cheese'): 15479,
#          ('milk', 'pecan'): 15475,
#          ('carrot', 'chicken'): 15454,
#          ('nutmeg', 'cinnamon'): 15439,
#          ('chicken', 'olives'): 15420,
#          ('chocolate', 'egg'): 15411,
#          ('milk', 'lemon juice'): 15390,
#          ('vanilla', 'oatmeal'): 15352,
#          ('spinach', 'black pepper'): 15308,
#          ('oregano', 'basil'): 15284,
#          ('potato', 'parsley'): 15275,
#          ('cloves', 'beef'): 15214,
#          ('celery', 'mayonnaise'): 15172,
#          ('onion', 'cream mushroom'): 15093,
#          ('potato', 'olives'): 15063,
#          ('cloves', 'worcestershire'): 15060,
#          ('black pepper', 'beef'): 15033,
#          ('cinnamon', 'walnut'): 14992,
#          ('cloves', 'coriander'): 14961,
#          ('ginger', 'egg'): 14956,
#          ('oatmeal', 'cinnamon'): 14929,
#          ('beef', 'oregano'): 14865,
#          ('onion', 'coriander'): 14864,
#          ('mozzarella cheese', 'parmesan cheese'): 14832,
#          ('cloves', 'rosemary'): 14824,
#          ('cream cheese', 'black pepper'): 14746,
#          ('cream cheese', 'lemon juice'): 14743,
#          ('celery', 'thyme'): 14725,
#          ('beef', 'parsley'): 14724,
#          ('carrot', 'olives'): 14721,
#          ('cloves', 'lime juice'): 14711,
#          ('onion', 'bread'): 14613,
#          ('cloves', 'cream'): 14607,
#          ('oatmeal', 'egg'): 14537,
#          ('parsley', 'parmesan cheese'): 14525,
#          ('olives', 'mozzarella cheese'): 14520,
#          ('oatmeal', 'vanilla'): 14507,
#          ('green bell pepper', 'black pepper'): 14502,
#          ('chicken stock', 'black pepper'): 14493,
#          ('egg', 'cream tartar'): 14440,
#          ('egg', 'orange'): 14402,
#          ('potato', 'cloves'): 14399,
#          ('oregano', 'olives'): 14366,
#          ('lemon', 'olives'): 14352,
#          ('corn syrup', 'vanilla'): 14267,
#          ('carrot', 'potato'): 14259,
#          ('black pepper', 'nutmeg'): 14235,
#          ('vanilla', 'semi-sweet chocolate'): 14224,
#          ('celery', 'egg'): 14203,
#          ('olives', 'mushroom'): 14188,
#          ('cloves', 'sour cream'): 14188,
#          ('cilantro', 'lime juice'): 14144,
#          ('onion', 'red bell pepper'): 14134,
#          ('celery', 'bay'): 14110,
#          ('thyme', 'olives'): 14041,
#          ('onion', 'chicken stock'): 14007,
#          ('olives', 'milk'): 13971,
#          ('parmesan cheese', 'egg'): 13969,
#          ('onion', 'turmeric'): 13947,
#          ('shrimp', 'black pepper'): 13943,
#          ('vanilla', 'cocoa'): 13923,
#          ('red onion', 'cloves'): 13914,
#          ('vanilla', 'almond'): 13901,
#          ('olives', 'paprika'): 13890,
#          ('basil', 'cloves'): 13813,
#          ('olives', 'red wine vinegar'): 13679,
#          ('chicken', 'egg'): 13576,
#          ('cloves', 'potato'): 13576,
#          ('parmesan cheese', 'olives'): 13561,
#          ('peanut', 'vanilla'): 13560,
#          ('cloves', 'mushroom'): 13544,
#          ('basil', 'parsley'): 13487,
#          ('coconut', 'vanilla'): 13463,
#          ('onion', 'green onion'): 13413,
#          ('onion', 'curry'): 13400,
#          ('olives', 'red bell pepper'): 13384,
#          ('black pepper', 'soy'): 13337,
#          ('olives', 'green onion'): 13300,
#          ('beef', 'milk'): 13270,
#          ('cumin', 'chili pepper'): 13236,
#          ('olives', 'balsamic vinegar'): 13232,
#          ('onion', 'nutmeg'): 13191,
#          ('parsley', 'basil'): 13187,
#          ('chicken', 'carrot'): 13130,
#          ('nutmeg', 'cloves'): 13106,
#          ('wheat', 'egg'): 13106,
#          ('sage', 'black pepper'): 13098,
#          ('olives', 'cream'): 13081,
#          ('paprika', 'onion'): 13056,
#          ('olives', 'dijon mustard'): 13016,
#          ('green onion', 'cloves'): 13014,
#          ('black pepper', 'mustard'): 13009,
#          ('ketchup', 'black pepper'): 12998,
#          ('red pepper', 'cloves'): 12983,
#          ('banana', 'vanilla'): 12970,
#          ('egg', 'mozzarella cheese'): 12932,
#          ('lemon juice', 'onion'): 12898,
#          ('wine', 'parsley'): 12863,
#          ('bread', 'milk'): 12856,
#          ('canola', 'black pepper'): 12832,
#          ('mushroom', 'parsley'): 12783,
#          ('chicken', 'lemon juice'): 12699,
#          ('celery', 'milk'): 12670,
#          ('soy', 'green onion'): 12668,
#          ('cinnamon', 'black pepper'): 12657,
#          ('cloves', 'mozzarella cheese'): 12652,
#          ('chicken', 'parmesan cheese'): 12638,
#          ('egg', 'apple'): 12628,
#          ('almond', 'egg'): 12578,
#          ('black pepper', 'rice'): 12550,
#          ('cinnamon', 'nut'): 12527,
#          ('parsley', 'thyme'): 12482,
#          ('cilantro', 'olives'): 12480,
#          ('shallot', 'cloves'): 12451,
#          ('chicken', 'thyme'): 12450,
#          ('mushroom', 'cloves'): 12442,
#          ('cumin', 'cloves'): 12440,
#          ('balsamic vinegar', 'black pepper'): 12411,
#          ('cloves', 'cheddar cheese'): 12394,
#          ('worcestershire', 'onion'): 12360,
#          ('parsley', 'oregano'): 12342,
#          ('red pepper', 'olives'): 12329,
#          ('cloves', 'celery'): 12323,
#          ('cumin', 'olives'): 12285,
#          ('cloves', 'chicken stock'): 12284,
#          ('beef', 'sour cream'): 12283,
#          ('yellow onion', 'cloves'): 12280,
#          ('olives', 'cayenne pepper'): 12267,
#          ('cloves', 'rice'): 12236,
#          ('carrot', 'egg'): 12227,
#          ('nutmeg', 'milk'): 12182,
#          ('thyme', 'cloves'): 12178,
#          ('cheddar cheese', 'sour cream'): 12176,
#          ('nutmeg', 'black pepper'): 12169,
#          ('broccoli', 'black pepper'): 12157,
#          ('lemon juice', 'vanilla'): 12123,
#          ('thyme', 'bay'): 12108,
#          ('milk', 'coconut'): 12096,
#          ('onion', 'rosemary'): 12092,
#          ('olives', 'honey'): 12084,
#          ('pecan', 'egg'): 12076,
#          ('milk', 'chocolate'): 12062,
#          ('ginger', 'cilantro'): 12046,
#          ('oregano', 'parmesan cheese'): 12030,
#          ('bay', 'parsley'): 12010,
#          ('green pepper', 'cloves'): 11972,
#          ('ginger', 'sesame seed'): 11971,
#          ('onion', 'lemon'): 11971,
#          ('onion', 'sage'): 11964,
#          ('chicken', 'cheddar cheese'): 11923,
#          ('oregano', 'parsley'): 11884,
#          ('onion', 'cream chicken'): 11860,
#          ('egg', 'vinegar'): 11740,
#          ('olives', 'chicken breast'): 11740,
#          ('onion', 'jalapeno'): 11726,
#          ('cumin', 'onion'): 11718,
#          ('bread', 'onion'): 11701,
#          ('black pepper', 'bacon'): 11623,
#          ('red bell pepper', 'cloves'): 11598,
#          ('black pepper', 'bread'): 11582,
#          ('egg', 'green onion'): 11568,
#          ('beef', 'green pepper'): 11560,
#          ('cilantro', 'cloves'): 11553,
#          ('egg', 'pineapple'): 11542,
#          ('oregano', 'cloves'): 11533,
#          ('cloves', 'sesame seed'): 11511,
#          ('broccoli', 'onion'): 11493,
#          ('potato', 'cheddar cheese'): 11487,
#          ('lemon juice', 'cinnamon'): 11483,
#          ('black pepper', 'ginger'): 11456,
#          ('egg', 'honey'): 11419,
#          ('cumin', 'coriander'): 11398,
#          ('raisin', 'cinnamon'): 11385,
#          ('mushroom', 'parmesan cheese'): 11347,
#          ('black pepper', 'mayonnaise'): 11301,
#          ('black pepper', 'chicken breast'): 11277,
#          ('bay', 'cloves'): 11272,
#          ('olives', 'feta cheese'): 11262,
#          ('milk', 'bread'): 11261,
#          ('egg', 'carrot'): 11250,
#          ('scallion', 'black pepper'): 11230,
#          ('celery', 'green pepper'): 11229,
#          ('black pepper', 'chives'): 11214,
#          ('cinnamon', 'cinnamon'): 11206,
#          ('carrot', 'milk'): 11182,
#          ('beef', 'parmesan cheese'): 11174,
#          ('onion', 'zucchini'): 11170,
#          ('red onion', 'cilantro'): 11166,
#          ('dijon mustard', 'olives'): 11115,
#          ('hamburger', 'onion'): 11106,
#          ('olives', 'potato'): 11083,
#          ('olives', 'lime juice'): 11046,
#          ('vinegar', 'onion'): 11017,
#          ('olives', 'sour cream'): 10990,
#          ('chives', 'black pepper'): 10969,
#          ('olives', 'chicken stock'): 10949,
#          ('cumin', 'oregano'): 10919,
#          ('bay', 'thyme'): 10914,
#          ('chili pepper', 'cloves'): 10911,
#          ('chicken', 'cilantro'): 10899,
#          ('ketchup', 'worcestershire'): 10895,
#          ('oregano', 'onion'): 10891,
#          ('black pepper', 'red onion'): 10876,
#          ('sour cream', 'green onion'): 10853,
#          ('olives', 'beef'): 10841,
#          ('mustard', 'onion'): 10827,
#          ('milk', 'cloves'): 10821,
#          ('shallot', 'olives'): 10819,
#          ('sesame seed', 'soy'): 10773,
#          ('cabbage', 'black pepper'): 10762,
#          ('cream cheese', 'pecan'): 10760,
#          ('milk', 'lemon'): 10692,
#          ('onion', 'red wine'): 10690,
#          ('cilantro', 'cumin'): 10668,
#          ('bacon', 'egg'): 10624,
#          ('milk', 'sour cream'): 10623,
#          ('mozzarella cheese', 'black pepper'): 10620,
#          ('soy', 'onion'): 10603,
#          ('zucchini', 'onion'): 10596,
#          ('green onion', 'parsley'): 10572,
#          ('chili pepper', 'cilantro'): 10558,
#          ('onion', 'spinach'): 10545,
#          ('parmesan cheese', 'basil'): 10544,
#          ('chicken', 'sour cream'): 10541,
#          ('egg', 'canola'): 10515,
#          ('milk', 'nut'): 10500,
#          ('beef', 'carrot'): 10476,
#          ('parmesan cheese', 'mozzarella cheese'): 10466,
#          ('egg', 'worcestershire'): 10421,
#          ('black pepper', 'rosemary'): 10419,
#          ('chili pepper', 'cheddar cheese'): 10419,
#          ('cumin', 'cayenne pepper'): 10397,
#          ('pumpkin', 'cinnamon'): 10346,
#          ('mayonnaise', 'parsley'): 10335,
#          ('vanilla', 'raisin'): 10330,
#          ('cream cheese', 'cheddar cheese'): 10313,
#          ('jalapeno', 'black pepper'): 10309,
#          ('potato', 'celery'): 10308,
#          ('cloves', 'chicken breast'): 10296,
#          ('beef', 'mushroom'): 10277,
#          ('lemon', 'cloves'): 10272,
#          ('sesame seed', 'black pepper'): 10240,
#          ('black pepper', 'vinegar'): 10228,
#          ('vinegar', 'mustard'): 10220,
#          ('egg', 'basil'): 10205,
#          ('chili pepper', 'oregano'): 10200,
#          ('chicken', 'rice'): 10181,
#          ('cloves', 'honey'): 10174,
#          ('cinnamon', 'lemon juice'): 10138,
#          ('olives', 'zucchini'): 10129,
#          ('celery', 'lemon juice'): 10126,
#          ('ginger', 'nutmeg'): 10123,
#          ('mushroom', 'egg'): 10119,
#          ('mayonnaise', 'cheddar cheese'): 10118,
#          ('coriander', 'black pepper'): 10076,
#          ('parsley', 'lemon'): 10072,
#          ('pineapple', 'pecan'): 10065,
#          ('pork', 'black pepper'): 10059,
#          ('cream cheese', 'mayonnaise'): 10036,
#          ('beef', 'celery'): 10020,
#          ('bacon', 'cloves'): 10009,
#          ('olives', 'mint'): 10002,
#          ('cloves', 'turmeric'): 9988,
#          ('olives', 'cheddar cheese'): 9949,
#          ('cream mushroom', 'onion'): 9948,
#          ('honey', 'cinnamon'): 9937,
#          ('wheat', 'cinnamon'): 9917,
#          ('onion', 'chicken breast'): 9913,
#          ('vanilla', 'lemon'): 9908,
#          ('egg', 'paprika'): 9907,
#          ('chicken breast', 'parsley'): 9901,
#          ('carrot', 'basil'): 9895,
#          ('mayonnaise', 'sour cream'): 9894,
#          ('thyme', 'onion'): 9893,
#          ('olives', 'yellow onion'): 9889,
#          ('red pepper', 'onion'): 9876,
#          ('banana', 'egg'): 9876,
#          ('beef', 'mozzarella cheese'): 9872,
#          ('cinnamon', 'apple'): 9869,
#          ('celery rib', 'black pepper'): 9864,
#          ('celery', 'olives'): 9857,
#          ('green onion', 'olives'): 9844,
#          ('bell pepper', 'black pepper'): 9831,
#          ('green onion', 'cilantro'): 9821,
#          ('onion', 'juice'): 9821,
#          ('chicken', 'soy'): 9814,
#          ('potato', 'sour cream'): 9814,
#          ('chicken breast', 'lemon juice'): 9798,
#          ('green onion', 'egg'): 9780,
#          ('sour cream', 'milk'): 9776,
#          ('spinach', 'egg'): 9761,
#          ('bay', 'onion'): 9757,
#          ('olives', 'ginger'): 9756,
#          ('cloves', 'allspice'): 9756,
#          ('onion', 'shrimp'): 9749,
#          ('onion', 'lime juice'): 9747,
#          ('vanilla', 'cream cheese'): 9733,
#          ('black pepper', 'shallot'): 9723,
#          ('chicken', 'green onion'): 9699,
#          ('parmesan cheese', 'cloves'): 9690,
#          ('oregano', 'thyme'): 9679,
#          ('spinach', 'parmesan cheese'): 9671,
#          ('cloves', 'shrimp'): 9645,
#          ('milk', 'cream cheese'): 9645,
#          ('mayonnaise', 'egg'): 9640,
#          ('honey', 'vanilla'): 9634,
#          ('raisin', 'egg'): 9634,
#          ('onion', 'celery rib'): 9629,
#          ('red bell pepper', 'olives'): 9625,
#          ('egg', 'bacon'): 9592,
#          ('green bean', 'black pepper'): 9575,
#          ('chicken', 'mushroom'): 9557,
#          ('onion', 'celery seed'): 9555,
#          ('chicken breast', 'sour cream'): 9530,
#          ('beef', 'cumin'): 9529,
#          ('honey', 'egg'): 9503,
#          ('rosemary', 'olives'): 9487,
#          ('egg', 'oregano'): 9461,
#          ('milk', 'almond'): 9460,
#          ('black pepper', 'dijon mustard'): 9437,
#          ('olives', 'cinnamon'): 9436,
#          ('cucumber', 'black pepper'): 9434,
#          ('milk', 'mustard'): 9425,
#          ('onion', 'peas'): 9409,
#          ('lemon', 'vanilla'): 9406,
#          ('beef', 'potato'): 9368,
#          ('cabbage', 'onion'): 9364,
#          ('dill', 'black pepper'): 9364,
#          ('red wine vinegar', 'olives'): 9360,
#          ('sour cream', 'lemon juice'): 9360,
#          ('honey', 'cloves'): 9350,
#          ('cloves', 'red bell pepper'): 9342,
#          ('lime juice', 'cloves'): 9342,
#          ('gram', 'egg'): 9321,
#          ('milk', 'olives'): 9315,
#          ('mushroom', 'milk'): 9311,
#          ('almond', 'almond'): 9309,
#          ('chicken', 'bay'): 9299,
#          ('red pepper', 'parsley'): 9298,
#          ('sesame seed', 'sesame seed'): 9294,
#          ('vanilla', 'lemon juice'): 9286,
#          ('onion', 'kidney bean'): 9278,
#          ('egg', 'blueberry'): 9278,
#          ('orange juice', 'orange'): 9262,
#          ('egg', 'peanut'): 9257,
#          ('cloves', 'red wine'): 9257,
#          ('basil', 'mozzarella cheese'): 9248,
#          ('celery', 'potato'): 9243,
#          ('chicken breast', 'parmesan cheese'): 9238,
#          ('lemon juice', 'worcestershire'): 9231,
#          ('mushroom', 'chicken'): 9228,
#          ('egg', 'soy'): 9208,
#          ('cream cheese', 'green onion'): 9205,
#          ('milk', 'cocoa'): 9195,
#          ('curry', 'black pepper'): 9194,
#          ('beef', 'basil'): 9179,
#          ('lime juice', 'olives'): 9174,
#          ('egg', 'cheese'): 9139,
#          ('semi-sweet chocolate', 'vanilla'): 9131,
#          ('chicken breast', 'mushroom'): 9112,
#          ('cider vinegar', 'black pepper'): 9093,
#          ('mustard', 'worcestershire'): 9093,
#          ('onion', 'tabasco'): 9082,
#          ('rice', 'egg'): 9076,
#          ('graham', 'vanilla'): 9075,
#          ('green onion', 'soy'): 9071,
#          ('zucchini', 'olives'): 9069,
#          ('oregano', 'mozzarella cheese'): 9047,
#          ('olives', 'spinach'): 9042,
#          ('celery', 'mushroom'): 9039,
#          ('chicken', 'basil'): 9036,
#          ('egg', 'pumpkin'): 9035,
#          ('beef', 'ketchup'): 9024,
#          ('corn', 'egg'): 9018,
#          ('egg', 'orange juice'): 8997,
#          ('cream', 'milk'): 8991,
#          ('worcestershire', 'mustard'): 8988,
#          ('olives', 'red wine'): 8982,
#          ('sour cream', 'mayonnaise'): 8963,
#          ('cream mushroom', 'black pepper'): 8945,
#          ('paprika', 'cayenne pepper'): 8930,
#          ('almond', 'vanilla'): 8919,
#          ('cloves', 'spinach'): 8918,
#          ('black pepper', 'chicken stock'): 8915,
#          ('green bell pepper', 'cloves'): 8897,
#          ('jalapeno', 'cilantro'): 8869,
#          ('milk', 'raisin'): 8849,
#          ('walnut', 'vanilla'): 8831,
#          ('black pepper', 'honey'): 8820,
#          ('chicken', 'cumin'): 8809,
#          ('black pepper', 'cinnamon'): 8809,
#          ('milk', 'peanut'): 8807,
#          ('canola', 'cloves'): 8796,
#          ('broccoli', 'cheddar cheese'): 8789,
#          ('carrot', 'soy'): 8788,
#          ('graham', 'egg'): 8780,
#          ('green pepper', 'celery'): 8778,
#          ('egg', 'corn syrup'): 8773,
#          ('lemon', 'parsley'): 8772,
#          ('milk', 'banana'): 8765,
#          ('celery', 'green onion'): 8717,
#          ('beef', 'olives'): 8715,
#          ('vanilla', 'sour cream'): 8714,
#          ('black pepper', 'canola'): 8694,
#          ('wine vinegar', 'black pepper'): 8673,
#          ('corn', 'onion'): 8670,
#          ('parmesan cheese', 'onion'): 8663,
#          ('cloves', 'red onion'): 8653,
#          ('shallot', 'parsley'): 8642,
#          ('mint', 'black pepper'): 8629,
#          ('egg', 'strawberry'): 8629,
#          ('cloves', 'mint'): 8622,
#          ('cream chicken', 'onion'): 8612,
#          ('soy', 'red pepper'): 8604,
#          ('ginger', 'onion'): 8604,
#          ('chicken breast', 'soy'): 8600,
#          ('mushroom', 'olives'): 8597,
#          ('breadcrumb', 'black pepper'): 8573,
#          ('mayonnaise', 'green onion'): 8553,
#          ('cream mushroom', 'milk'): 8547,
#          ('green pepper', 'cheddar cheese'): 8538,
#          ('onion', 'pimiento'): 8536,
#          ('olives', 'soy'): 8515,
#          ('olives', 'caper'): 8509,
#          ('olives', 'shrimp'): 8503,
#          ('green pepper', 'chili pepper'): 8502,
#          ('chicken', 'cream chicken'): 8500,
#          ('olives', 'chives'): 8488,
#          ('chicken breast', 'egg'): 8468,
#          ('milk', 'chicken'): 8460,
#          ('sour cream', 'parsley'): 8454,
#          ('ham', 'black pepper'): 8428,
#          ('graham', 'cream cheese'): 8425,
#          ('olives', 'worcestershire'): 8410,
#          ('cream', 'parmesan cheese'): 8396,
#          ('cloves', 'zucchini'): 8387,
#          ('lemon', 'lemon'): 8387,
#          ('zucchini', 'cloves'): 8366,
#          ('soy', 'honey'): 8363,
#          ('celery', 'worcestershire'): 8315,
#          ('sesame seed', 'ginger'): 8314,
#          ('peanut', 'egg'): 8283,
#          ('black pepper', 'lime juice'): 8248,
#          ('turkey', 'black pepper'): 8233,
#          ('egg', 'wheat'): 8220,
#          ('chicken breast', 'milk'): 8216,
#          ('celery', 'cheddar cheese'): 8210,
#          ('vinegar', 'cloves'): 8206,
#          ('basil', 'thyme'): 8206,
#          ('honey', 'olives'): 8202,
#          ('onion', 'monterey jack cheese'): 8201,
#          ('green bell pepper', 'onion'): 8195,
#          ('black pepper', 'sesame seed'): 8182,
#          ('onion', 'catsup'): 8179,
#          ('beef', 'rice'): 8175,
#          ('ricotta', 'egg'): 8172,
#          ('nut', 'vanilla'): 8169,
#          ('cloves', 'scallion'): 8161,
#          ('vanilla', 'peanut'): 8155,
#          ('black bean', 'cilantro'): 8147,
#          ('beef', 'beef'): 8142,
#          ('chicken', 'cream'): 8136,
#          ('cloves', 'vinegar'): 8131,
#          ('vanilla', 'banana'): 8127,
#          ('beef chuck', 'onion'): 8117,
#          ('ginger', 'coriander'): 8112,
#          ('chicken', 'potato'): 8103,
#          ('black pepper', 'corn'): 8099,
#          ('celery', 'basil'): 8099,
#          ('bell pepper', 'onion'): 8093,
#          ('cloves', 'dijon mustard'): 8090,
#          ('chicken', 'oregano'): 8082,
#          ('black pepper', 'cheese'): 8077,
#          ('onion', 'broccoli'): 8077,
#          ('walnut', 'egg'): 8069,
#          ('cream chicken', 'cheddar cheese'): 8060,
#          ('black pepper', 'ketchup'): 8052,
#          ('milk', 'cheese'): 8045,
#          ('cloves', 'curry'): 8020,
#          ('egg', 'celery'): 8007,
#          ('pork', 'onion'): 8005,
#          ('green pepper', 'vinegar'): 7971,
#          ('ketchup', 'mustard'): 7968,
#          ('red wine', 'black pepper'): 7967,
#          ('cheddar cheese', 'green onion'): 7955,
#          ('cloves', 'red wine vinegar'): 7951,
#          ('zucchini', 'egg'): 7950,
#          ('black pepper', 'green pepper'): 7942,
#          ('bacon', 'cheddar cheese'): 7917,
#          ('pecan', 'cinnamon'): 7910,
#          ('black pepper', 'shrimp'): 7906,
#          ('celery', 'rice'): 7887,
#          ('onion', 'cider vinegar'): 7882,
#          ('oatmeal', 'milk'): 7877,
#          ('cream chicken', 'black pepper'): 7875,
#          ('black pepper', 'scallion'): 7864,
#          ('beef', 'bay'): 7857,
#          ('milk', 'oatmeal'): 7857,
#          ('shrimp', 'cloves'): 7856,
#          ('coconut', 'egg'): 7856,
#          ('milk', 'walnut'): 7854,
#          ('thyme', 'chicken'): 7852,
#          ('cream mushroom', 'cheddar cheese'): 7851,
#          ('potato', 'chicken'): 7825,
#          ('onion', 'cabbage'): 7814,
#          ('egg', 'allspice'): 7810,
#          ('sesame seed', 'cloves'): 7803,
#          ('basil', 'egg'): 7787,
#          ('raisin', 'vanilla'): 7784,
#          ('milk', 'honey'): 7778,
#          ('egg', 'zucchini'): 7763,
#          ('mayonnaise', 'mustard'): 7761,
#          ('half-and-half cream', 'black pepper'): 7760,
#          ('ginger', 'green onion'): 7758,
#          ('carrot', 'lemon juice'): 7750,
#          ('apple', 'egg'): 7747,
#          ('oregano', 'red pepper'): 7737,
#          ('chicken breast', 'cilantro'): 7731,
#          ('black pepper', 'sage'): 7721,
#          ('celery', 'oregano'): 7718,
#          ('avocado', 'black pepper'): 7708,
#          ('pineapple', 'nut'): 7707,
#          ('cream chicken', 'sour cream'): 7706,
#          ('red pepper', 'parmesan cheese'): 7702,
#          ('chicken breast', 'cream chicken'): 7677,
#          ('chicken breast', 'green onion'): 7676,
#          ('ketchup', 'onion'): 7674,
#          ('spinach', 'onion'): 7665,
#          ('cream cheese', 'cream'): 7654,
#          ('egg', 'potato'): 7636,
#          ('onion', 'italian'): 7631,
#          ('canola', 'onion'): 7611,
#          ('chocolate', 'milk'): 7603,
#          ('egg', 'half-and-half cream'): 7595,
#          ('zucchini', 'parmesan cheese'): 7588,
#          ('canola', 'egg'): 7587,
#          ('cumin', 'paprika'): 7586,
#          ('cinnamon', 'honey'): 7586,
#          ('bacon', 'parsley'): 7582,
#          ('cinnamon', 'cream cheese'): 7573,
#          ('olives', 'coriander'): 7564,
#          ('onion', 'black bean'): 7557,
#          ('cinnamon', 'oatmeal'): 7555,
#          ('red bell pepper', 'cilantro'): 7552,
#          ('oregano', 'cumin'): 7552,
#          ('cream', 'parsley'): 7548,
#          ('pumpkin', 'egg'): 7548,
#          ('chili pepper', 'cayenne pepper'): 7544,
#          ('allspice', 'cloves'): 7539,
#          ('orange', 'orange juice'): 7536,
#          ('mayonnaise', 'celery'): 7535,
#          ('milk', 'paprika'): 7519,
#          ('cloves', 'corn'): 7503,
#          ('basil', 'onion'): 7499,
#          ('egg', 'chicken'): 7498,
#          ('carrot', 'oregano'): 7495,
#          ('cloves', 'mustard'): 7492,
#          ('zucchini', 'basil'): 7485,
#          ('cloves', 'shallot'): 7481,
#          ('green onion', 'cheddar cheese'): 7477,
#          ('egg', 'beef'): 7476,
#          ('mushroom', 'sour cream'): 7471,
#          ('cream chicken', 'milk'): 7471,
#          ('turkey', 'onion'): 7460,
#          ('egg', 'mushroom'): 7445,
#          ('juice', 'black pepper'): 7433,
#          ('bay', 'olives'): 7431,
#          ('chili pepper', 'olives'): 7426,
#          ('ricotta', 'parmesan cheese'): 7422,
#          ('mushroom', 'cheddar cheese'): 7422,
#          ('egg', 'breadcrumb'): 7420,
#          ('chicken', 'ginger'): 7411,
#          ('cumin', 'cinnamon'): 7408,
#          ('paprika', 'parsley'): 7408,
#          ('bacon', 'milk'): 7402,
#          ('shrimp', 'onion'): 7401,
#          ('avocado', 'cilantro'): 7400,
#          ('paprika', 'olives'): 7398,
#          ('cream cheese', 'worcestershire'): 7388,
#          ('pecan', 'milk'): 7376,
#          ('red onion', 'parsley'): 7373,
#          ('lemon juice', 'milk'): 7356,
#          ('olives', 'sage'): 7352,
#          ('balsamic vinegar', 'olives'): 7350,
#          ('red pepper', 'basil'): 7340,
#          ('parmesan cheese', 'oregano'): 7339,
#          ('green onion', 'sesame seed'): 7309,
#          ('green chili pepper', 'black pepper'): 7302,
#          ('chicken', 'chili pepper'): 7290,
#          ('chicken breast', 'cheddar cheese'): 7286,
#          ('sweetened milk', 'vanilla'): 7285,
#          ('beef', 'mustard'): 7285,
#          ('black pepper', 'red bell pepper'): 7274,
#          ('soy', 'cilantro'): 7271,
#          ('cumin', 'sour cream'): 7269,
#          ('green onion', 'lemon juice'): 7269,
#          ('broccoli', 'milk'): 7259,
#          ('bread', 'parsley'): 7256,
#          ('ginger', 'vanilla'): 7255,
#          ('egg', 'corn'): 7251,
#          ('egg', 'thyme'): 7246,
#          ('beef', 'thyme'): 7235,
#          ('parsley', 'milk'): 7234,
#          ('vanilla pudding', 'milk'): 7223,
#          ('thyme', 'rosemary'): 7213,
#          ('asparagus', 'black pepper'): 7211,
#          ('wine', 'olives'): 7211,
#          ('banana', 'milk'): 7210,
#          ('wheat', 'vanilla'): 7209,
#          ('honey', 'ginger'): 7200,
#          ('carrot', 'cilantro'): 7193,
#          ('onion', 'spaghetti'): 7190,
#          ('peas', 'black pepper'): 7177,
#          ('yogurt', 'black pepper'): 7174,
#          ('coriander', 'cumin'): 7169,
#          ('carrot', 'beef'): 7169,
#          ('oregano', 'egg'): 7168,
#          ('ginger', 'lemon juice'): 7164,
#          ('thyme', 'egg'): 7146,
#          ('eggplant', 'black pepper'): 7145,
#          ('vanilla', 'buttermilk'): 7137,
#          ('green pepper', 'mushroom'): 7137,
#          ('rosemary', 'thyme'): 7136,
#          ('potato', 'cinnamon'): 7130,
#          ('canola', 'vanilla'): 7122,
#          ('onion', 'cream cheese'): 7120,
#          ('onion', 'allspice'): 7114,
#          ('onion', 'salsa'): 7111,
#          ('parsley', 'bay'): 7095,
#          ('carrot', 'green onion'): 7091,
#          ('onion', 'half-and-half cream'): 7090,
#          ('green pepper', 'egg'): 7077,
#          ('potato', 'thyme'): 7072,
#          ('mayonnaise', 'worcestershire'): 7063,
#          ('parsley', 'paprika'): 7055,
#          ('vanilla', 'strawberry'): 7051,
#          ('wheat', 'milk'): 7037,
#          ('olives', 'cherry'): 7035,
#          ('cinnamon', 'cream'): 7030,
#          ('carrot', 'mushroom'): 7029,
#          ('mushroom', 'basil'): 7028,
#          ('carrot', 'ginger'): 7026,
#          ('cheese', 'black pepper'): 7026,
#          ('paprika', 'cumin'): 7019,
#          ('red bell pepper', 'onion'): 7012,
#          ('ginger', 'turmeric'): 7005,
#          ('egg', 'applesauce'): 7005,
#          ('cinnamon', 'lemon'): 7003,
#          ('honey', 'lemon juice'): 7002,
#          ('mayonnaise', 'parmesan cheese'): 7002,
#          ('paprika', 'cloves'): 6997,
#          ('cloves', 'green chili pepper'): 6996,
#          ('black bean', 'cumin'): 6996,
#          ('shrimp', 'parsley'): 6978,
#          ('green onion', 'mayonnaise'): 6968,
#          ('cloves', 'green pepper'): 6965,
#          ('cloves', 'jalapeno'): 6961,
#          ('milk', 'worcestershire'): 6951,
#          ('cheddar cheese', 'mayonnaise'): 6937,
#          ('worcestershire', 'cloves'): 6932,
#          ('orange', 'egg'): 6924,
#          ('green chili pepper', 'cheddar cheese'): 6921,
#          ('egg', 'gram'): 6920,
#          ('black bean', 'black pepper'): 6919,
#          ('coconut', 'pecan'): 6917,
#          ('cream cheese', 'cinnamon'): 6917,
#          ('chili pepper', 'sour cream'): 6906,
#          ('ginger', 'red pepper'): 6901,
#          ('olives', 'green bell pepper'): 6901,
#          ...})

# %% [markdown]
# Create our dataframe of how often ingredients are used together

# %%
unique_ingredients = set()
for ingredient in df['ingredients']:
    unique_ingredients.update(ingredient)
unique_ingredients = sorted(list(unique_ingredients))

cooccurrence_matrix = np.zeros((len(unique_ingredients), len(unique_ingredients)))
ingredient_to_index = {ingredient: i for i, ingredient in enumerate(unique_ingredients)}
for ingredients in df['ingredients']:
    for i, ingredient1 in enumerate(ingredients):
        for j, ingredient2 in enumerate(ingredients):
            if i != j:
                index1 = ingredient_to_index[ingredient1]
                index2 = ingredient_to_index[ingredient2]
                cooccurrence_matrix[index1, index2] += 1

cooccurrence_df = pd.DataFrame(cooccurrence_matrix, index=unique_ingredients, columns=unique_ingredients)
cooccurrence_df
# Out:
#                         acorn squash  adobo  agave nectar  alfredo  allspice  \
# acorn squash                     8.0    0.0           0.0      0.0      94.0
# adobo                            0.0   84.0           5.0      2.0      44.0
# agave nectar                     0.0    5.0         286.0      0.0      31.0
# alfredo                          0.0    2.0           0.0     56.0       0.0
# allspice                        94.0   44.0          31.0      0.0     486.0
# ...                              ...    ...           ...      ...       ...
# yellow squash                    8.0    3.0           1.0     11.0      16.0
# yogurt                          20.0   46.0          35.0      0.0     526.0
# yukon gold potato               10.0    8.0           3.0      6.0      55.0
# zesty italian dressing           1.0    4.0           0.0      1.0       1.0
# zucchini                        51.0   55.0          33.0     87.0     479.0
#
#                         allspice berry  almond  almond milk  amaretto  \
# acorn squash                       0.0    38.0          1.0       2.0
# adobo                              1.0    10.0          1.0       0.0
# agave nectar                       1.0   415.0         64.0       4.0
# alfredo                            0.0    14.0          0.0       0.0
# allspice                          28.0   861.0         34.0      12.0
# ...                                ...     ...          ...       ...
# yellow squash                      0.0    47.0          0.0       0.0
# yogurt                            11.0  1195.0         39.0      16.0
# yukon gold potato                 11.0    25.0         10.0       0.0
# zesty italian dressing             0.0    10.0          0.0       0.0
# zucchini                          14.0   505.0         28.0       4.0
#
#                         american cheese  ...  yellow bell pepper  yellow corn  \
# acorn squash                        4.0  ...                 9.0          0.0
# adobo                              14.0  ...                26.0          5.0
# agave nectar                        0.0  ...                 6.0          1.0
# alfredo                            12.0  ...                13.0          1.0
# allspice                            4.0  ...                63.0         11.0
# ...                                 ...  ...                 ...          ...
# yellow squash                      43.0  ...               140.0         13.0
# yogurt                             16.0  ...                92.0         16.0
# yukon gold potato                   8.0  ...                39.0          6.0
# zesty italian dressing              1.0  ...                 8.0          2.0
# zucchini                           86.0  ...               780.0         21.0
#
#                         yellow mustard  yellow onion  yellow pepper  \
# acorn squash                       0.0          75.0            1.0
# adobo                             12.0         121.0            5.0
# agave nectar                       5.0          14.0            6.0
# alfredo                            2.0          50.0            2.0
# allspice                         103.0         612.0           18.0
# ...                                ...           ...            ...
# yellow squash                      3.0         213.0           53.0
# yogurt                            35.0         442.0           56.0
# yukon gold potato                 40.0         492.0           10.0
# zesty italian dressing             3.0          12.0           22.0
# zucchini                          54.0        1137.0          379.0
#
#                         yellow squash  yogurt  yukon gold potato  \
# acorn squash                      8.0    20.0               10.0
# adobo                             3.0    46.0                8.0
# agave nectar                      1.0    35.0                3.0
# alfredo                          11.0     0.0                6.0
# allspice                         16.0   526.0               55.0
# ...                               ...     ...                ...
# yellow squash                     4.0    44.0               11.0
# yogurt                           44.0  1266.0               84.0
# yukon gold potato                11.0    84.0              102.0
# zesty italian dressing           11.0     2.0                9.0
# zucchini                       2427.0   691.0              108.0
#
#                         zesty italian dressing  zucchini
# acorn squash                               1.0      51.0
# adobo                                      4.0      55.0
# agave nectar                               0.0      33.0
# alfredo                                    1.0      87.0
# allspice                                   1.0     479.0
# ...                                        ...       ...
# yellow squash                             11.0    2427.0
# yogurt                                     2.0     691.0
# yukon gold potato                          9.0     108.0
# zesty italian dressing                    16.0      85.0
# zucchini                                  85.0     384.0
#
# [668 rows x 668 columns]

# %% [markdown]
# run a quick estimate through the pairwise system to see how things look

# %%
mf.recommend_ingredients_pairwise('agave nectar', pair_counts)
# Out:
# ['vanilla', 'coconut', 'cinnamon', 'egg', 'almond']

# %% [markdown]
# Create our cosine similarity matrix, we are using this so ingredients that are underrepresented in our database are still there going to be returned in our final product.

# %%
sim_pd = mf.calculate_similarity_matrix(cooccurrence_df)
sim_pd
# Out:
#                        acorn squash     adobo agave nectar   alfredo  \
# acorn squash                    1.0  0.744209     0.540016  0.635689
# adobo                      0.744209       1.0     0.468725  0.588941
# agave nectar               0.540016  0.468725          1.0  0.317279
# alfredo                    0.635689  0.588941     0.317279       1.0
# allspice                   0.769578  0.556575     0.664001  0.409239
# ...                             ...       ...          ...       ...
# yellow squash              0.800319  0.747791     0.417243  0.700477
# yogurt                     0.799187  0.773211     0.704245  0.587151
# yukon gold potato          0.878897  0.789514     0.458637  0.690301
# zesty italian dressing     0.552551  0.676702     0.320832  0.702206
# zucchini                   0.866625  0.787814     0.586262  0.763547
#
#                         allspice allspice berry    almond almond milk  \
# acorn squash            0.769578       0.712248  0.499702    0.455304
# adobo                   0.556575       0.601306  0.381168    0.275082
# agave nectar            0.664001       0.468007  0.783807    0.871487
# alfredo                 0.409239       0.404986  0.368298     0.22067
# allspice                     1.0       0.802473  0.677057    0.631316
# ...                          ...            ...       ...         ...
# yellow squash           0.532894        0.52188  0.456078    0.285971
# yogurt                  0.774257        0.67759  0.699825    0.572797
# yukon gold potato       0.591575       0.634531  0.461528    0.297825
# zesty italian dressing  0.404165       0.448439   0.33479    0.196439
# zucchini                0.708632       0.652367  0.603196     0.45417
#
#                         amaretto american cheese  ... yellow bell pepper  \
# acorn squash            0.255527        0.663565  ...           0.721735
# adobo                   0.163075         0.64103  ...           0.785333
# agave nectar            0.628965        0.324905  ...           0.443225
# alfredo                 0.189879        0.591571  ...           0.635611
# allspice                0.478366        0.489801  ...           0.478854
# ...                          ...             ...  ...                ...
# yellow squash           0.227099        0.769053  ...           0.766991
# yogurt                  0.457868        0.651178  ...           0.696751
# yukon gold potato       0.242969        0.705274  ...           0.782612
# zesty italian dressing  0.146174        0.594222  ...           0.609401
# zucchini                0.346403        0.727907  ...           0.795524
#
#                        yellow corn yellow mustard yellow onion yellow pepper  \
# acorn squash              0.575941       0.711208     0.815414      0.726399
# adobo                     0.590537        0.72012     0.812409      0.754515
# agave nectar              0.453812        0.37488     0.484954      0.430772
# alfredo                   0.524478       0.534964     0.681652      0.649729
# allspice                  0.578114       0.531017     0.600413      0.489591
# ...                            ...            ...          ...           ...
# yellow squash             0.669115       0.756272     0.748811      0.777525
# yogurt                    0.691386       0.708076     0.776999       0.69587
# yukon gold potato         0.653935       0.747422     0.912525      0.775725
# zesty italian dressing    0.484091       0.553607     0.578677      0.739956
# zucchini                  0.711931       0.736824     0.835707      0.808415
#
#                        yellow squash    yogurt yukon gold potato  \
# acorn squash                0.800319  0.799187          0.878897
# adobo                       0.747791  0.773211          0.789514
# agave nectar                0.417243  0.704245          0.458637
# alfredo                     0.700477  0.587151          0.690301
# allspice                    0.532894  0.774257          0.591575
# ...                              ...       ...               ...
# yellow squash                    1.0  0.724123          0.847315
# yogurt                      0.724123       1.0          0.784429
# yukon gold potato           0.847315  0.784429               1.0
# zesty italian dressing      0.654127  0.613194          0.566642
# zucchini                    0.882374  0.833546          0.877198
#
#                        zesty italian dressing  zucchini
# acorn squash                         0.552551  0.866625
# adobo                                0.676702  0.787814
# agave nectar                         0.320832  0.586262
# alfredo                              0.702206  0.763547
# allspice                             0.404165  0.708632
# ...                                       ...       ...
# yellow squash                        0.654127  0.882374
# yogurt                               0.613194  0.833546
# yukon gold potato                    0.566642  0.877198
# zesty italian dressing                    1.0  0.683783
# zucchini                             0.683783       1.0
#
# [668 rows x 668 columns]

# %% [markdown]
# Test out our recommendations

# %%
reccomendations, error_codes = mf.recommend_items(sim_matrix=sim_pd, near_items="Squirrel", far_items="", top_n=20)

# %%
list(reccomendations.index)
# Out:
# ['chicken thigh',
#  'basmati rice',
#  'green peas',
#  'cashew nut',
#  'chicken',
#  'long grain rice',
#  'cayenne',
#  'vegetables',
#  'cayenne pepper',
#  'cashew',
#  'red lentil',
#  'chicken leg',
#  'coriander',
#  'red chili',
#  'turmeric',
#  'rice',
#  'chicken breast',
#  'peas',
#  'carrot',
#  'paprika']

# %%
sim_pd.to_csv('../data/similarity_matrix.csv')

# %%
mf.recommend_items(sim_matrix=sim_pd, near_items="apple", far_items="blackberry")
# Out:
# (tart apples            0.30899
#  allspice              0.306519
#  apple cider           0.289216
#  granny smith apple    0.258214
#  pumpkin               0.256363
#  dtype: object,
#  [])
